# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/diogoflim/MGP/blob/main/modelagem_1.ipynb)

# %% [markdown]
# # Modelagem e Gestão de Processos
#
#
# **Prof. Diogo Ferreira de Lima Silva (TEP-UFF)**
#
# Tema da aula - Modelagem de Processos no SimPy

# %% [markdown]
# # SimPy
#
# A biblioteca SimPy apresenta um framework útil para simular o funcionamento de processos em Python.
#
# O usuário ganha grande liberdade para modelar processos específicos de sua organização.
#
# Além disso, pode integrar ao modelo as inúmeras bibliotecas existentes em python para Estatística, Ciência de Dados, Aprendeizado de Máquina, Otimização, etc.

# %% [markdown]
# ## Importando o SimPy
#
# Se estiver trabalhando localmente, uma vez instalado o Python, você deverá instalar a biblioteca SimPy antes de importá-la.
#
# - Isso pode ser feito com o comando: **pip install simpy**
#
# No caso do Googlo Colab: **!pip install simpy**
#
# Uma vez instalada, podemos importar a biblioteca normalmente simplesmente com: **import simpy**.

# %%
#!pip install simpy
import simpy

# %% [markdown]
# Além do SimPy, vamos importar a biblioteca random para usar suas distribuições de probabilidades.

# %%
import random

# Seu computador não gera números verdadeiramente aleatórios, mas sim, pseudoaleatórios.
# Vamos "travar" a semente de geração desses números. Assim, resultados poderão ser reproduzidos no futuro.
random.seed(10)

# %% [markdown]
# # Um exemplo simples: Pomodoro
#
# Com o intuito de aumentar sua produtividade, um estudante/trabalhador resolve seguir a recomendação de uma colega sobre a metodologia Pomodoro.
#
# - Ele fará alternadamente intervalos de trabalho e pausa (descanso, café, água, banheiro) durante o dia.
#
#     - O tempo até a próxima parada para descanso (tempo de trabalho) segue uma distribuição uniforme que varia entre 24 e 26 minutos.
#     - As pausas seguem uma exponencial de média 5 minutos.
#
# Vamos modelar o funcionamento desse processo por 8 horas de trabalho e imprimir em nossa tela sempre que um evento (pausa ou trabalho) for iniciado.

# %% [markdown]
# ## Criando um ambiente de simulação
#
#
# O primeiro passo será criar um ambiente (environment) no SimPy.

# %%
# Criando uma instância de ambiente do simpy e armazenando em env

env = simpy.Environment()

# %% [markdown]
# Nosso processo possui duas atividades (subprocessos): **trabalhar** e **descansar**.
#
# A próxima etapa é criar um **generator** (tipo especial de função) para simular o funcionamento dessas atividades.

# %% [markdown]
# ### Modelando o Processo

# %%
# Criaremos um gerador de nome pomodoro 

def pomodoro ():
    pass

# %% [markdown]
# Por enquanto, não passamos nada para nosso gerador.
#
# Os parâmetros que ele irá receber devem incluir o ambiente criado no simpy.
#
# Vamos também passar como parâmetro o nome do colaborador.

# %%
def Pomodoro (env, nome):
    pass

# %% [markdown]
# Agora, podemos trabalhar nas atividades que farão parte do nosso processo: **trabalhar** e **descansar**.
#
# Para isso, usaremos o **yield** e os métodos **now** e **timeout** do simpy.
#
# - O **yield** é usado em uma função geradora (em detrimento do return numa função normal). No caso do yield, guardamos um iterador (no nosso caso será o tempo de início de cada evento) que poderá ser retomado no futuro e usado em outro chamado da função geradora.
#
# - O método **now** do SimPy retorna o tempo de simulação no nosso ambiente enquanto o **timeout** avisa à simulação para percorrer um tempo.

# %%
def pomodoro (env, nome):
    
    # enquanto a simulação estiver ocorrendo
    while True:
        
        # imprima na tela o tempo de início do evento e depois percorra um tempo random.uniform(24, 26)
        print (f"{nome} inicia trabalho no tempo {env.now}")
        yield env.timeout(random.uniform(24,26))

        # imprima na tela o tempo de início do evento e depois percorra um tempo random.expovariate(1/média)
        print (f"{nome} inicia descanso no tempo {env.now}")
        yield env.timeout(random.expovariate(1/5))

# %% [markdown]
# Nosso gerador "pomodoro" ainda não é visto como um processo do nosso environment no SimPy.
#
# O próximo passo é instanciar nosso processo usando o simpy.Environment.process.
#
# No nosso caso, fica simplesmente **env.process**.

# %%
# Instância do processo
env.process(pomodoro(env, "Will_Smith"))
# Out:
# <Process(pomodoro) object at 0x201579357f0>

# %% [markdown]
# Agora, vamos rodar o nosso processo até o minuto 480, ou seja, simularemos 8h de trabalho.

# %%
env.run (until = 480)
# Out:
# Will_Smith inicia trabalho no tempo 0
# Will_Smith inicia descanso no tempo 25.14280518937983
# Will_Smith inicia trabalho no tempo 27.943664130161597
# Will_Smith inicia descanso no tempo 53.099846732430535
# Will_Smith inicia trabalho no tempo 54.253824449673225
# Will_Smith inicia descanso no tempo 79.88046695238786
# Will_Smith inicia trabalho no tempo 88.55515723500187
# Will_Smith inicia descanso no tempo 113.86210230280423
# Will_Smith inicia trabalho no tempo 114.7352358331193
# Will_Smith inicia descanso no tempo 139.77657455239915
# Will_Smith inicia trabalho no tempo 141.76236914065487
# Will_Smith inicia descanso no tempo 166.26236249402768
# Will_Smith inicia trabalho no tempo 181.53096096998934
# Will_Smith inicia descanso no tempo 207.52407495506824
# Will_Smith inicia trabalho no tempo 207.75197258188612
# Will_Smith inicia descanso no tempo 233.4722946564587
# Will_Smith inicia trabalho no tempo 238.09379086634283
# Will_Smith inicia descanso no tempo 262.8570028381811
# Will_Smith inicia trabalho no tempo 264.5247130327617
# Will_Smith inicia descanso no tempo 289.87464272703164
# Will_Smith inicia trabalho no tempo 292.9263179854875
# Will_Smith inicia descanso no tempo 318.2980409564367
# Will_Smith inicia trabalho no tempo 323.7193150185911
# Will_Smith inicia descanso no tempo 347.9852713080155
# Will_Smith inicia trabalho no tempo 355.28686667666193
# Will_Smith inicia descanso no tempo 381.2516931746843
# Will_Smith inicia trabalho no tempo 398.6835353246049
# Will_Smith inicia descanso no tempo 423.91018896569835
# Will_Smith inicia trabalho no tempo 424.13653912379897
# Will_Smith inicia descanso no tempo 448.14464941211577
# Will_Smith inicia trabalho no tempo 448.86384264692157
# Will_Smith inicia descanso no tempo 474.74584718971323
# Will_Smith inicia trabalho no tempo 476.54969635847414

# %% [markdown]
# # Modelando um Processo com Várias Atividades

# %% [markdown]
# Agora vamos modelar um processo um pouco mais complexo. Teremos chegadas de clientes em um serviço composto por três atividades: A, B e C.
#
# -  Um processo de chegadas inicializa a cada chegada de um cliente. O tempo entre chegadas segue uma distribuição Exponencial com média de 5 minutos.
#     - $\frac{1}{\lambda}=5 \rightarrow \lambda = 0,2$
#
# - Cada cliente segue o seguinte percurso:
#     - Serviço A (tempo de processamento 3 min)
#     - Serviço B (tempo de processamento de 8 min)
#     - Serviço C (tempo de processamento segue uma distribuição exponencial com média 5min)

# %% [markdown]
# Para a realização dos serviços, precisamos de recursos. Por exemplo, atendentes, caixas, etc.
#
# Chamaremos os recursos de:
#
# - colaborador_A
# - colaborador_B
# - colaborador_C
#
# Para isso, utilizaremos **recursos** do SimPy, criados com **resource_name = env.Resource (env, capacity)**.

# %% [markdown]
# Um cliente deve esperar até que o recurso esteja disponível. Para modelar isso, usaremos o **resource_name.request()**

# %% [markdown]
# ### Função Geradora

# %%
# Função geradora receberá, além do ambiente e do nome do cliente, os recursos.

def salao (env, nome, colaborador_A, colaborador_B, colaborador_C):
    
    # imprimimos na tela quando um cliente chega no estabelecimento       
    print (f"{nome} chega no estabelecimento em {env.now}")
    
    # Serviço A
    # Ao chegar, o cliente deve esperar o recurso do primeiro serviso

    with colaborador_A.request() as req_A:
        yield req_A # o cliente deve esperar um recurso do tipo colaborador_A
        print (f"{nome} inicia A em {env.now}") # imprima na tela o tempo de início
        yield env.timeout(3) # O serviço demora exatamente 3 minutos.
        print (f"{nome} finaliza A em {env.now}")

    
    # Serviço B
    with colab_B.request() as req_B:
        yield req_B
        print (f"{nome} inicia B em {env.now}")
        yield env.timeout(8) # O serviço B demora exatamente 8 minutos.
        print (f"{nome} finaliza B em {env.now}")
    
    # Serviço C
    with colab_C.request() as req_C:
        yield req_C
        print (f"{nome} inicia C em {env.now}")
        yield env.timeout(random.expovariate(1/5)) # O tempo de serviço em C segue uma exponencial de média 5.
    
    print (f"{nome} sai do estabelecimento em {env.now}")

# %% [markdown]
# ### Definindo o ambiente

# %%
env = simpy.Environment()

# %% [markdown]
# ### Instanciando os tipos de recurso em nosso ambiente e suas capacidades

# %%
colab_A = simpy.Resource(env, capacity=1)
colab_B = simpy.Resource(env, capacity=1)
colab_C = simpy.Resource(env, capacity=1)

# %% [markdown]
# ## Processo de Chegadas

# %% [markdown]
# Vamos considerar que o nosso processo de chegadas é um processo de Poisson, com $\lambda = 0,2$ clientes/minuto;
#
# Assim, o tempo entre chegadas segue uma distribuição exponencial de média $1/\lambda = 5$ minutos.
#
# Vamos criar nosso processo de chegadas:

# %%
def chegadas (env):
    i=1 # número que será usado na contagem e nomeação dos clientes
    
    # Enquanto a simulação ocorrer
    while True:
        # gere um número de nossa distribuição 
        yield env.timeout(random.expovariate(1/5))

        # Um cliente entra no processo! Seu nome será "Cliente i"
        env.process(salao (env, 'Cliente %d' % i, colab_A, colab_B, colab_C))
        
        i+=1 # i = i+1


# Instanciando o processo com a função de chegadas.
env.process(chegadas(env))
# Out:
# <Process(chegadas) object at 0x20157942c10>

# %% [markdown]
# Pronto, agora basta rodar nossa simulação.

# %%
env.run(until=480)
# Out:
# Cliente 1 chega no estabelecimento em 11.423541424842186
# Cliente 1 inicia A em 11.423541424842186
# Cliente 2 chega no estabelecimento em 13.310582024115678
# Cliente 1 finaliza A em 14.423541424842186
# Cliente 1 inicia B em 14.423541424842186
# Cliente 2 inicia A em 14.423541424842186
# Cliente 3 chega no estabelecimento em 17.291824208921966
# Cliente 2 finaliza A em 17.423541424842185
# Cliente 3 inicia A em 17.423541424842185
# Cliente 4 chega no estabelecimento em 20.155603800897108
# Cliente 3 finaliza A em 20.423541424842185
# Cliente 4 inicia A em 20.423541424842185
# Cliente 5 chega no estabelecimento em 20.49161640575467
# Cliente 1 finaliza B em 22.423541424842185
# Cliente 1 inicia C em 22.423541424842185
# Cliente 2 inicia B em 22.423541424842185
# Cliente 4 finaliza A em 23.423541424842185
# Cliente 5 inicia A em 23.423541424842185
# Cliente 6 chega no estabelecimento em 24.88353602610119
# Cliente 7 chega no estabelecimento em 25.73403230814252
# Cliente 5 finaliza A em 26.423541424842185
# Cliente 6 inicia A em 26.423541424842185
# Cliente 8 chega no estabelecimento em 27.003972817939367
# Cliente 6 finaliza A em 29.423541424842185
# Cliente 7 inicia A em 29.423541424842185
# Cliente 9 chega no estabelecimento em 29.666519679825335
# Cliente 10 chega no estabelecimento em 29.854638943000033
# Cliente 2 finaliza B em 30.423541424842185
# Cliente 3 inicia B em 30.423541424842185
# Cliente 1 sai do estabelecimento em 31.715214464342633
# Cliente 2 inicia C em 31.715214464342633
# Cliente 7 finaliza A em 32.423541424842185
# Cliente 8 inicia A em 32.423541424842185
# Cliente 11 chega no estabelecimento em 33.286524674391785
# Cliente 8 finaliza A em 35.423541424842185
# Cliente 9 inicia A em 35.423541424842185
# Cliente 3 finaliza B em 38.423541424842185
# Cliente 9 finaliza A em 38.423541424842185
# Cliente 4 inicia B em 38.423541424842185
# Cliente 10 inicia A em 38.423541424842185
# Cliente 12 chega no estabelecimento em 38.649653175580376
# Cliente 2 sai do estabelecimento em 40.23348668860151
# Cliente 3 inicia C em 40.23348668860151
# Cliente 10 finaliza A em 41.423541424842185
# Cliente 11 inicia A em 41.423541424842185
# Cliente 13 chega no estabelecimento em 42.46196514897144
# Cliente 14 chega no estabelecimento em 43.27272563274888
# Cliente 11 finaliza A em 44.423541424842185
# Cliente 12 inicia A em 44.423541424842185
# Cliente 4 finaliza B em 46.423541424842185
# Cliente 5 inicia B em 46.423541424842185
# Cliente 12 finaliza A em 47.423541424842185
# Cliente 13 inicia A em 47.423541424842185
# Cliente 15 chega no estabelecimento em 47.460533259652
# Cliente 16 chega no estabelecimento em 49.80395430195816
# Cliente 3 sai do estabelecimento em 49.89293214123484
# Cliente 4 inicia C em 49.89293214123484
# Cliente 13 finaliza A em 50.423541424842185
# Cliente 14 inicia A em 50.423541424842185
# Cliente 4 sai do estabelecimento em 50.492008460561074
# Cliente 14 finaliza A em 53.423541424842185
# Cliente 15 inicia A em 53.423541424842185
# Cliente 17 chega no estabelecimento em 54.40174144950678
# Cliente 5 finaliza B em 54.423541424842185
# Cliente 5 inicia C em 54.423541424842185
# Cliente 6 inicia B em 54.423541424842185
# Cliente 5 sai do estabelecimento em 54.93152298837021
# Cliente 15 finaliza A em 56.423541424842185
# Cliente 16 inicia A em 56.423541424842185
# Cliente 16 finaliza A em 59.423541424842185
# Cliente 17 inicia A em 59.423541424842185
# Cliente 18 chega no estabelecimento em 61.87142219118125
# Cliente 6 finaliza B em 62.423541424842185
# Cliente 17 finaliza A em 62.423541424842185
# Cliente 6 inicia C em 62.423541424842185
# Cliente 7 inicia B em 62.423541424842185
# Cliente 18 inicia A em 62.423541424842185
# Cliente 19 chega no estabelecimento em 62.78121278017028
# Cliente 18 finaliza A em 65.42354142484218
# Cliente 19 inicia A em 65.42354142484218
# Cliente 19 finaliza A em 68.42354142484218
# Cliente 7 finaliza B em 70.42354142484218
# Cliente 8 inicia B em 70.42354142484218
# Cliente 6 sai do estabelecimento em 70.66053207920952
# Cliente 7 inicia C em 70.66053207920952
# Cliente 7 sai do estabelecimento em 73.49955384106235
# Cliente 20 chega no estabelecimento em 77.5344264952887
# Cliente 20 inicia A em 77.5344264952887
# Cliente 8 finaliza B em 78.42354142484218
# Cliente 8 inicia C em 78.42354142484218
# Cliente 9 inicia B em 78.42354142484218
# Cliente 8 sai do estabelecimento em 79.83192132505813
# Cliente 21 chega no estabelecimento em 80.20729368057118
# Cliente 20 finaliza A em 80.5344264952887
# Cliente 21 inicia A em 80.5344264952887
# Cliente 22 chega no estabelecimento em 81.81316664687996
# Cliente 21 finaliza A em 83.5344264952887
# Cliente 22 inicia A em 83.5344264952887
# Cliente 9 finaliza B em 86.42354142484218
# Cliente 9 inicia C em 86.42354142484218
# Cliente 10 inicia B em 86.42354142484218
# Cliente 22 finaliza A em 86.5344264952887
# Cliente 23 chega no estabelecimento em 86.61506906745826
# Cliente 23 inicia A em 86.61506906745826
# Cliente 24 chega no estabelecimento em 87.2512964729125
# Cliente 9 sai do estabelecimento em 87.40641718090325
# Cliente 23 finaliza A em 89.61506906745826
# Cliente 24 inicia A em 89.61506906745826
# Cliente 25 chega no estabelecimento em 90.29289026657608
# Cliente 26 chega no estabelecimento em 91.19413563541032
# Cliente 24 finaliza A em 92.61506906745826
# Cliente 25 inicia A em 92.61506906745826
# Cliente 10 finaliza B em 94.42354142484218
# Cliente 10 inicia C em 94.42354142484218
# Cliente 11 inicia B em 94.42354142484218
# Cliente 25 finaliza A em 95.61506906745826
# Cliente 26 inicia A em 95.61506906745826
# Cliente 27 chega no estabelecimento em 96.42506266541457
# Cliente 26 finaliza A em 98.61506906745826
# Cliente 27 inicia A em 98.61506906745826
# Cliente 27 finaliza A em 101.61506906745826
# Cliente 11 finaliza B em 102.42354142484218
# Cliente 12 inicia B em 102.42354142484218
# Cliente 10 sai do estabelecimento em 103.02694418221081
# Cliente 11 inicia C em 103.02694418221081
# Cliente 28 chega no estabelecimento em 103.9394594998648
# Cliente 28 inicia A em 103.9394594998648
# Cliente 29 chega no estabelecimento em 106.07472625328829
# Cliente 11 sai do estabelecimento em 106.29785928208915
# Cliente 28 finaliza A em 106.9394594998648
# Cliente 29 inicia A em 106.9394594998648
# Cliente 30 chega no estabelecimento em 108.92681313505422
# Cliente 31 chega no estabelecimento em 108.95191893435434
# Cliente 29 finaliza A em 109.9394594998648
# Cliente 30 inicia A em 109.9394594998648
# Cliente 12 finaliza B em 110.42354142484218
# Cliente 12 inicia C em 110.42354142484218
# Cliente 13 inicia B em 110.42354142484218
# Cliente 12 sai do estabelecimento em 112.43831191128947
# Cliente 30 finaliza A em 112.9394594998648
# Cliente 31 inicia A em 112.9394594998648
# Cliente 32 chega no estabelecimento em 115.18585424738407
# Cliente 31 finaliza A em 115.9394594998648
# Cliente 32 inicia A em 115.9394594998648
# Cliente 33 chega no estabelecimento em 117.10992755013034
# Cliente 34 chega no estabelecimento em 117.52642817892597
# Cliente 13 finaliza B em 118.42354142484218
# Cliente 13 inicia C em 118.42354142484218
# Cliente 14 inicia B em 118.42354142484218
# Cliente 32 finaliza A em 118.9394594998648
# Cliente 33 inicia A em 118.9394594998648
# Cliente 35 chega no estabelecimento em 120.497970944211
# Cliente 33 finaliza A em 121.9394594998648
# Cliente 34 inicia A em 121.9394594998648
# Cliente 13 sai do estabelecimento em 122.79507609499342
# Cliente 36 chega no estabelecimento em 122.97426586805372
# Cliente 34 finaliza A em 124.9394594998648
# Cliente 35 inicia A em 124.9394594998648
# Cliente 14 finaliza B em 126.42354142484218
# Cliente 14 inicia C em 126.42354142484218
# Cliente 15 inicia B em 126.42354142484218
# Cliente 35 finaliza A em 127.9394594998648
# Cliente 36 inicia A em 127.9394594998648
# Cliente 36 finaliza A em 130.9394594998648
# Cliente 14 sai do estabelecimento em 132.0179207520203
# Cliente 37 chega no estabelecimento em 133.1579214681193
# Cliente 37 inicia A em 133.1579214681193
# Cliente 15 finaliza B em 134.4235414248422
# Cliente 15 inicia C em 134.4235414248422
# Cliente 16 inicia B em 134.4235414248422
# Cliente 38 chega no estabelecimento em 134.53937903955836
# Cliente 37 finaliza A em 136.1579214681193
# Cliente 38 inicia A em 136.1579214681193
# Cliente 15 sai do estabelecimento em 138.14946991264344
# Cliente 38 finaliza A em 139.1579214681193
# Cliente 16 finaliza B em 142.4235414248422
# Cliente 16 inicia C em 142.4235414248422
# Cliente 17 inicia B em 142.4235414248422
# Cliente 16 sai do estabelecimento em 146.0945300800092
# Cliente 39 chega no estabelecimento em 146.60885191908287
# Cliente 39 inicia A em 146.60885191908287
# Cliente 39 finaliza A em 149.60885191908287
# Cliente 17 finaliza B em 150.4235414248422
# Cliente 17 inicia C em 150.4235414248422
# Cliente 18 inicia B em 150.4235414248422
# Cliente 17 sai do estabelecimento em 150.7476935705298
# Cliente 40 chega no estabelecimento em 151.21668590763758
# Cliente 40 inicia A em 151.21668590763758
# Cliente 40 finaliza A em 154.21668590763758
# Cliente 41 chega no estabelecimento em 154.5773938277721
# Cliente 41 inicia A em 154.5773938277721
# Cliente 41 finaliza A em 157.5773938277721
# Cliente 42 chega no estabelecimento em 157.67168739150745
# Cliente 42 inicia A em 157.67168739150745
# Cliente 18 finaliza B em 158.4235414248422
# Cliente 18 inicia C em 158.4235414248422
# Cliente 19 inicia B em 158.4235414248422
# Cliente 43 chega no estabelecimento em 160.23524005420288
# Cliente 42 finaliza A em 160.67168739150745
# Cliente 43 inicia A em 160.67168739150745
# Cliente 18 sai do estabelecimento em 161.15093179879239
# Cliente 43 finaliza A em 163.67168739150745
# Cliente 44 chega no estabelecimento em 164.63184137105046
# Cliente 44 inicia A em 164.63184137105046
# Cliente 19 finaliza B em 166.4235414248422
# Cliente 19 inicia C em 166.4235414248422
# Cliente 20 inicia B em 166.4235414248422
# Cliente 44 finaliza A em 167.63184137105046
# Cliente 45 chega no estabelecimento em 168.5000176659494
# Cliente 45 inicia A em 168.5000176659494
# Cliente 46 chega no estabelecimento em 169.40640681747263
# Cliente 19 sai do estabelecimento em 169.78924232295174
# Cliente 45 finaliza A em 171.5000176659494
# Cliente 46 inicia A em 171.5000176659494
# Cliente 47 chega no estabelecimento em 172.31753893323733
# Cliente 20 finaliza B em 174.4235414248422
# Cliente 20 inicia C em 174.4235414248422
# Cliente 21 inicia B em 174.4235414248422
# Cliente 46 finaliza A em 174.5000176659494
# Cliente 47 inicia A em 174.5000176659494
# Cliente 20 sai do estabelecimento em 177.1057433614457
# Cliente 47 finaliza A em 177.5000176659494
# Cliente 21 finaliza B em 182.4235414248422
# Cliente 21 inicia C em 182.4235414248422
# Cliente 22 inicia B em 182.4235414248422
# Cliente 21 sai do estabelecimento em 182.60332437077352
# Cliente 48 chega no estabelecimento em 189.63474339474882
# Cliente 48 inicia A em 189.63474339474882
# Cliente 49 chega no estabelecimento em 189.6489155943215
# Cliente 22 finaliza B em 190.4235414248422
# Cliente 22 inicia C em 190.4235414248422
# Cliente 23 inicia B em 190.4235414248422
# Cliente 22 sai do estabelecimento em 190.68302428973385
# Cliente 48 finaliza A em 192.63474339474882
# Cliente 49 inicia A em 192.63474339474882
# Cliente 50 chega no estabelecimento em 193.4820064635581
# Cliente 51 chega no estabelecimento em 193.96865628391998
# Cliente 52 chega no estabelecimento em 194.54434379578444
# Cliente 49 finaliza A em 195.63474339474882
# Cliente 50 inicia A em 195.63474339474882
# Cliente 53 chega no estabelecimento em 197.57074267431565
# Cliente 23 finaliza B em 198.4235414248422
# Cliente 23 inicia C em 198.4235414248422
# Cliente 24 inicia B em 198.4235414248422
# Cliente 50 finaliza A em 198.63474339474882
# Cliente 51 inicia A em 198.63474339474882
# Cliente 51 finaliza A em 201.63474339474882
# Cliente 52 inicia A em 201.63474339474882
# Cliente 23 sai do estabelecimento em 201.7420207317717
# Cliente 52 finaliza A em 204.63474339474882
# Cliente 53 inicia A em 204.63474339474882
# Cliente 24 finaliza B em 206.4235414248422
# Cliente 24 inicia C em 206.4235414248422
# Cliente 25 inicia B em 206.4235414248422
# Cliente 53 finaliza A em 207.63474339474882
# Cliente 24 sai do estabelecimento em 209.49189798138747
# Cliente 25 finaliza B em 214.4235414248422
# Cliente 25 inicia C em 214.4235414248422
# Cliente 26 inicia B em 214.4235414248422
# Cliente 25 sai do estabelecimento em 217.29157711190027
# Cliente 54 chega no estabelecimento em 222.16197986841343
# Cliente 54 inicia A em 222.16197986841343
# Cliente 26 finaliza B em 222.4235414248422
# Cliente 26 inicia C em 222.4235414248422
# Cliente 27 inicia B em 222.4235414248422
# Cliente 54 finaliza A em 225.16197986841343
# Cliente 26 sai do estabelecimento em 225.38631873612277
# Cliente 55 chega no estabelecimento em 225.63885000756056
# Cliente 55 inicia A em 225.63885000756056
# Cliente 55 finaliza A em 228.63885000756056
# Cliente 27 finaliza B em 230.4235414248422
# Cliente 27 inicia C em 230.4235414248422
# Cliente 28 inicia B em 230.4235414248422
# Cliente 56 chega no estabelecimento em 232.1159144311254
# Cliente 56 inicia A em 232.1159144311254
# Cliente 56 finaliza A em 235.1159144311254
# Cliente 57 chega no estabelecimento em 238.10040963254949
# Cliente 57 inicia A em 238.10040963254949
# Cliente 28 finaliza B em 238.4235414248422
# Cliente 29 inicia B em 238.4235414248422
# Cliente 58 chega no estabelecimento em 240.8526669505299
# Cliente 57 finaliza A em 241.10040963254949
# Cliente 58 inicia A em 241.10040963254949
# Cliente 27 sai do estabelecimento em 241.83458867373483
# Cliente 28 inicia C em 241.83458867373483
# Cliente 58 finaliza A em 244.10040963254949
# Cliente 59 chega no estabelecimento em 246.09505521174012
# Cliente 59 inicia A em 246.09505521174012
# Cliente 29 finaliza B em 246.4235414248422
# Cliente 30 inicia B em 246.4235414248422
# Cliente 60 chega no estabelecimento em 246.92903282037457
# Cliente 61 chega no estabelecimento em 248.2837637100781
# Cliente 59 finaliza A em 249.09505521174012
# Cliente 60 inicia A em 249.09505521174012
# Cliente 60 finaliza A em 252.09505521174012
# Cliente 61 inicia A em 252.09505521174012
# Cliente 62 chega no estabelecimento em 253.11001326320923
# Cliente 28 sai do estabelecimento em 253.84885927546102
# Cliente 29 inicia C em 253.84885927546102
# Cliente 30 finaliza B em 254.4235414248422
# Cliente 31 inicia B em 254.4235414248422
# Cliente 61 finaliza A em 255.09505521174012
# Cliente 62 inicia A em 255.09505521174012
# Cliente 62 finaliza A em 258.09505521174015
# Cliente 63 chega no estabelecimento em 258.91809233614896
# Cliente 63 inicia A em 258.91809233614896
# Cliente 29 sai do estabelecimento em 258.9933607724676
# Cliente 30 inicia C em 258.9933607724676
# Cliente 63 finaliza A em 261.91809233614896
# Cliente 31 finaliza B em 262.4235414248422
# Cliente 32 inicia B em 262.4235414248422
# Cliente 64 chega no estabelecimento em 263.3581707008224
# Cliente 64 inicia A em 263.3581707008224
# Cliente 64 finaliza A em 266.3581707008224
# Cliente 65 chega no estabelecimento em 266.61764944319094
# Cliente 65 inicia A em 266.61764944319094
# Cliente 30 sai do estabelecimento em 267.8362088110285
# Cliente 31 inicia C em 267.8362088110285
# Cliente 65 finaliza A em 269.61764944319094
# Cliente 32 finaliza B em 270.4235414248422
# Cliente 33 inicia B em 270.4235414248422
# Cliente 66 chega no estabelecimento em 274.85825368701785
# Cliente 66 inicia A em 274.85825368701785
# Cliente 67 chega no estabelecimento em 277.71605890897894
# Cliente 66 finaliza A em 277.85825368701785
# Cliente 67 inicia A em 277.85825368701785
# Cliente 33 finaliza B em 278.4235414248422
# Cliente 34 inicia B em 278.4235414248422
# Cliente 67 finaliza A em 280.85825368701785
# Cliente 31 sai do estabelecimento em 284.23409697362086
# Cliente 32 inicia C em 284.23409697362086
# Cliente 34 finaliza B em 286.4235414248422
# Cliente 35 inicia B em 286.4235414248422
# Cliente 68 chega no estabelecimento em 287.5055629080069
# Cliente 68 inicia A em 287.5055629080069
# Cliente 68 finaliza A em 290.5055629080069
# Cliente 32 sai do estabelecimento em 290.56763736526966
# Cliente 33 inicia C em 290.56763736526966
# Cliente 33 sai do estabelecimento em 290.80433185662383
# Cliente 34 inicia C em 290.80433185662383
# Cliente 35 finaliza B em 294.4235414248422
# Cliente 36 inicia B em 294.4235414248422
# Cliente 69 chega no estabelecimento em 298.4823617402287
# Cliente 69 inicia A em 298.4823617402287
# Cliente 69 finaliza A em 301.4823617402287
# Cliente 36 finaliza B em 302.4235414248422
# Cliente 37 inicia B em 302.4235414248422
# Cliente 34 sai do estabelecimento em 303.0192401185397
# Cliente 35 inicia C em 303.0192401185397
# Cliente 70 chega no estabelecimento em 305.76248216484066
# Cliente 70 inicia A em 305.76248216484066
# Cliente 70 finaliza A em 308.76248216484066
# Cliente 37 finaliza B em 310.4235414248422
# Cliente 38 inicia B em 310.4235414248422
# Cliente 38 finaliza B em 318.4235414248422
# Cliente 39 inicia B em 318.4235414248422
# Cliente 35 sai do estabelecimento em 319.420194833916
# Cliente 36 inicia C em 319.420194833916
# Cliente 36 sai do estabelecimento em 321.10095638843865
# Cliente 37 inicia C em 321.10095638843865
# Cliente 71 chega no estabelecimento em 325.6638198433965
# Cliente 71 inicia A em 325.6638198433965
# Cliente 39 finaliza B em 326.4235414248422
# Cliente 40 inicia B em 326.4235414248422
# Cliente 72 chega no estabelecimento em 326.42534402993687
# Cliente 37 sai do estabelecimento em 326.6442894602786
# Cliente 38 inicia C em 326.6442894602786
# Cliente 71 finaliza A em 328.6638198433965
# Cliente 72 inicia A em 328.6638198433965
# Cliente 73 chega no estabelecimento em 330.9463244159109
# Cliente 72 finaliza A em 331.6638198433965
# Cliente 73 inicia A em 331.6638198433965
# Cliente 74 chega no estabelecimento em 332.0121254283329
# Cliente 75 chega no estabelecimento em 334.1650300059446
# Cliente 40 finaliza B em 334.4235414248422
# Cliente 41 inicia B em 334.4235414248422
# Cliente 76 chega no estabelecimento em 334.5805560517039
# Cliente 73 finaliza A em 334.6638198433965
# Cliente 74 inicia A em 334.6638198433965
# Cliente 77 chega no estabelecimento em 335.6629868296466
# Cliente 78 chega no estabelecimento em 336.82707951180777
# Cliente 79 chega no estabelecimento em 337.3317142474895
# Cliente 74 finaliza A em 337.6638198433965
# Cliente 75 inicia A em 337.6638198433965
# Cliente 38 sai do estabelecimento em 339.24673118472043
# Cliente 39 inicia C em 339.24673118472043
# Cliente 75 finaliza A em 340.6638198433965
# Cliente 76 inicia A em 340.6638198433965
# Cliente 41 finaliza B em 342.4235414248422
# Cliente 42 inicia B em 342.4235414248422
# Cliente 76 finaliza A em 343.6638198433965
# Cliente 77 inicia A em 343.6638198433965
# Cliente 77 finaliza A em 346.6638198433965
# Cliente 78 inicia A em 346.6638198433965
# Cliente 78 finaliza A em 349.6638198433965
# Cliente 79 inicia A em 349.6638198433965
# Cliente 39 sai do estabelecimento em 350.1722508100587
# Cliente 40 inicia C em 350.1722508100587
# Cliente 42 finaliza B em 350.4235414248422
# Cliente 43 inicia B em 350.4235414248422
# Cliente 79 finaliza A em 352.6638198433965
# Cliente 40 sai do estabelecimento em 353.2881178394785
# Cliente 41 inicia C em 353.2881178394785
# Cliente 43 finaliza B em 358.4235414248422
# Cliente 44 inicia B em 358.4235414248422
# Cliente 41 sai do estabelecimento em 360.0951988058159
# Cliente 42 inicia C em 360.0951988058159
# Cliente 42 sai do estabelecimento em 366.03629968378056
# Cliente 43 inicia C em 366.03629968378056
# Cliente 44 finaliza B em 366.4235414248422
# Cliente 45 inicia B em 366.4235414248422
# Cliente 43 sai do estabelecimento em 369.73178001255906
# Cliente 44 inicia C em 369.73178001255906
# Cliente 44 sai do estabelecimento em 372.48556518192845
# Cliente 45 finaliza B em 374.4235414248422
# Cliente 45 inicia C em 374.4235414248422
# Cliente 46 inicia B em 374.4235414248422
# Cliente 80 chega no estabelecimento em 377.85775645168997
# Cliente 80 inicia A em 377.85775645168997
# Cliente 45 sai do estabelecimento em 379.8778532667203
# Cliente 80 finaliza A em 380.85775645168997
# Cliente 81 chega no estabelecimento em 381.9120061197663
# Cliente 81 inicia A em 381.9120061197663
# Cliente 46 finaliza B em 382.4235414248422
# Cliente 46 inicia C em 382.4235414248422
# Cliente 47 inicia B em 382.4235414248422
# Cliente 82 chega no estabelecimento em 383.457486936701
# Cliente 46 sai do estabelecimento em 384.6888849868451
# Cliente 81 finaliza A em 384.9120061197663
# Cliente 82 inicia A em 384.9120061197663
# Cliente 82 finaliza A em 387.9120061197663
# Cliente 83 chega no estabelecimento em 388.39194842454395
# Cliente 83 inicia A em 388.39194842454395
# Cliente 47 finaliza B em 390.4235414248422
# Cliente 47 inicia C em 390.4235414248422
# Cliente 48 inicia B em 390.4235414248422
# Cliente 83 finaliza A em 391.39194842454395
# Cliente 47 sai do estabelecimento em 391.5995826213003
# Cliente 84 chega no estabelecimento em 393.32456079066253
# Cliente 84 inicia A em 393.32456079066253
# Cliente 84 finaliza A em 396.32456079066253
# Cliente 85 chega no estabelecimento em 398.02969396110393
# Cliente 85 inicia A em 398.02969396110393
# Cliente 48 finaliza B em 398.4235414248422
# Cliente 48 inicia C em 398.4235414248422
# Cliente 49 inicia B em 398.4235414248422
# Cliente 85 finaliza A em 401.02969396110393
# Cliente 49 finaliza B em 406.4235414248422
# Cliente 50 inicia B em 406.4235414248422
# Cliente 86 chega no estabelecimento em 408.42405289693903
# Cliente 86 inicia A em 408.42405289693903
# Cliente 48 sai do estabelecimento em 408.6763523784662
# Cliente 49 inicia C em 408.6763523784662
# Cliente 49 sai do estabelecimento em 409.0401342796801
# Cliente 86 finaliza A em 411.42405289693903
# Cliente 87 chega no estabelecimento em 413.70560147965955
# Cliente 87 inicia A em 413.70560147965955
# Cliente 50 finaliza B em 414.4235414248422
# Cliente 50 inicia C em 414.4235414248422
# Cliente 51 inicia B em 414.4235414248422
# Cliente 50 sai do estabelecimento em 414.88972564518036
# Cliente 88 chega no estabelecimento em 416.4596580729236
# Cliente 87 finaliza A em 416.70560147965955
# Cliente 88 inicia A em 416.70560147965955
# Cliente 89 chega no estabelecimento em 416.7438316871468
# Cliente 90 chega no estabelecimento em 418.2136611287376
# Cliente 88 finaliza A em 419.70560147965955
# Cliente 89 inicia A em 419.70560147965955
# Cliente 91 chega no estabelecimento em 421.26572865380615
# Cliente 51 finaliza B em 422.4235414248422
# Cliente 51 inicia C em 422.4235414248422
# Cliente 52 inicia B em 422.4235414248422
# Cliente 89 finaliza A em 422.70560147965955
# Cliente 90 inicia A em 422.70560147965955
# Cliente 90 finaliza A em 425.70560147965955
# Cliente 91 inicia A em 425.70560147965955
# Cliente 51 sai do estabelecimento em 427.37917238099567
# Cliente 92 chega no estabelecimento em 428.3888157424137
# Cliente 91 finaliza A em 428.70560147965955
# Cliente 92 inicia A em 428.70560147965955
# Cliente 93 chega no estabelecimento em 430.04862009671706
# Cliente 52 finaliza B em 430.4235414248422
# Cliente 52 inicia C em 430.4235414248422
# Cliente 53 inicia B em 430.4235414248422
# Cliente 92 finaliza A em 431.70560147965955
# Cliente 93 inicia A em 431.70560147965955
# Cliente 52 sai do estabelecimento em 433.9547740510548
# Cliente 93 finaliza A em 434.70560147965955
# Cliente 94 chega no estabelecimento em 435.98696989941317
# Cliente 94 inicia A em 435.98696989941317
# Cliente 53 finaliza B em 438.4235414248422
# Cliente 53 inicia C em 438.4235414248422
# Cliente 54 inicia B em 438.4235414248422
# Cliente 94 finaliza A em 438.98696989941317
# Cliente 95 chega no estabelecimento em 439.5285746670113
# Cliente 95 inicia A em 439.5285746670113
# Cliente 53 sai do estabelecimento em 439.9536003812341
# Cliente 96 chega no estabelecimento em 442.44238240650577
# Cliente 95 finaliza A em 442.5285746670113
# Cliente 96 inicia A em 442.5285746670113
# Cliente 97 chega no estabelecimento em 444.53153263201955
# Cliente 96 finaliza A em 445.5285746670113
# Cliente 97 inicia A em 445.5285746670113
# Cliente 54 finaliza B em 446.4235414248422
# Cliente 54 inicia C em 446.4235414248422
# Cliente 55 inicia B em 446.4235414248422
# Cliente 97 finaliza A em 448.5285746670113
# Cliente 54 sai do estabelecimento em 449.71820294588264
# Cliente 98 chega no estabelecimento em 451.0146491414659
# Cliente 98 inicia A em 451.0146491414659
# Cliente 99 chega no estabelecimento em 453.97451643168364
# Cliente 98 finaliza A em 454.0146491414659
# Cliente 99 inicia A em 454.0146491414659
# Cliente 55 finaliza B em 454.4235414248422
# Cliente 55 inicia C em 454.4235414248422
# Cliente 56 inicia B em 454.4235414248422
# Cliente 99 finaliza A em 457.0146491414659
# Cliente 100 chega no estabelecimento em 457.2154628854351
# Cliente 100 inicia A em 457.2154628854351
# Cliente 55 sai do estabelecimento em 457.692321648826
# Cliente 100 finaliza A em 460.2154628854351
# Cliente 56 finaliza B em 462.4235414248422
# Cliente 56 inicia C em 462.4235414248422
# Cliente 57 inicia B em 462.4235414248422
# Cliente 101 chega no estabelecimento em 463.065553777035
# Cliente 101 inicia A em 463.065553777035
# Cliente 101 finaliza A em 466.065553777035
# Cliente 56 sai do estabelecimento em 468.78565070987474
# Cliente 57 finaliza B em 470.4235414248422
# Cliente 57 inicia C em 470.4235414248422
# Cliente 58 inicia B em 470.4235414248422
# Cliente 102 chega no estabelecimento em 471.14024316812856
# Cliente 102 inicia A em 471.14024316812856
# Cliente 57 sai do estabelecimento em 473.0216699274375
# Cliente 102 finaliza A em 474.14024316812856
# Cliente 58 finaliza B em 478.4235414248422
# Cliente 58 inicia C em 478.4235414248422
# Cliente 59 inicia B em 478.4235414248422
# Cliente 103 chega no estabelecimento em 479.02848274213846
# Cliente 103 inicia A em 479.02848274213846

# %% [markdown]
# Ótimo, já modelamos 2 processos!
#
# Porém, não estamos guardando informações para calcular estatísticas que nos interessem.

# %% [markdown]
# ---

# %% [markdown]
# # Monitorando o Processo

# %% [markdown]
# Ao analisar um processo, um gestor pode estar interessado em algumas métricas, tais como:
# - Tempo de ciclo médio;
# - Tempo de espera médio em fila;
# - Uso dos recursos
# - Trabalho em processo médio;
#
# Para fazer tais cálculos, precisamos colher algumas informações durante a simulação.

# %% [markdown]
# ### Vamos incrementar nosso código para guardar o tempo gasto na atividade C

# %%
#criando uma lista vazia
tempo_gasto_C = []

tempo_esperando_C =[]

# %%
def salao (env, nome, colaborador_A, colaborador_B, colaborador_C):
    #print (f"{nome} chega no estabelecimento em {env.now}")
    # Serviço A
    with colaborador_A.request() as req_A:
        yield req_A # o cliente deve esperar um recurso do tipo colaborador_A
        #print (f"{nome} inicia A em {env.now}") # imprima na tela o tempo de início
        yield env.timeout(3) # O serviço demora exatamente 3 minutos.
        #print (f"{nome} finaliza A em {env.now}")
    
    # Serviço B
    with colab_B.request() as req_B:
        yield req_B
        #print (f"{nome} inicia B em {env.now}")
        yield env.timeout(8) # O serviço B demora exatamente 8 minutos.
        #print (f"{nome} finaliza B em {env.now}")

        acaba_B = env.now

    # Serviço C
    with colab_C.request() as req_C:
        yield req_C
        #print (f"{nome} inicia C em {env.now}")
        
        p_inicio = env.now
        yield env.timeout(random.expovariate(1/5)) # O tempo de serviço em C segue uma exponencial de média 5.
        p_fim = env.now

        tempo_gasto_C.append(p_fim - p_inicio)
        tempo_esperando_C.append(p_inicio - acaba_B)
        
    #print (f"{nome} sai do estabelecimento em {env.now}")
    print (f"{nome} esperou {p_inicio - acaba_B} na fila da atividade C")
    print (f"{nome} gastou {p_fim - p_inicio} na atividade C")

# %%
env = simpy.Environment()
colab_A = simpy.Resource(env, capacity=1)
colab_B = simpy.Resource(env, capacity=1)
colab_C = simpy.Resource(env, capacity=1)
env.process(chegadas(env))
env.run(until = 60000)
# Out:
# Cliente 1 esperou 0.0 na fila da atividade C
# Cliente 1 gastou 0.08226210443761772 na atividade C
# Cliente 2 esperou 0.0 na fila da atividade C
# Cliente 2 gastou 1.943756968837853 na atividade C
# Cliente 3 esperou 0.0 na fila da atividade C
# Cliente 3 gastou 4.711971012669444 na atividade C
# Cliente 4 esperou 0.0 na fila da atividade C
# Cliente 4 gastou 13.723758764044732 na atividade C
# Cliente 5 esperou 5.723758764044732 na fila da atividade C
# Cliente 5 gastou 1.0642784246346366 na atividade C
# Cliente 6 esperou 0.0 na fila da atividade C
# Cliente 6 gastou 4.241927529946544 na atividade C
# Cliente 7 esperou 0.0 na fila da atividade C
# Cliente 7 gastou 2.8929594617060417 na atividade C
# Cliente 8 esperou 0.0 na fila da atividade C
# Cliente 8 gastou 10.185432999406473 na atividade C
# Cliente 9 esperou 2.1854329994064727 na fila da atividade C
# Cliente 9 gastou 0.08089139705820969 na atividade C
# Cliente 10 esperou 0.0 na fila da atividade C
# Cliente 10 gastou 4.26940996401423 na atividade C
# Cliente 11 esperou 0.0 na fila da atividade C
# Cliente 11 gastou 3.6993003512353226 na atividade C
# Cliente 12 esperou 0.0 na fila da atividade C
# Cliente 12 gastou 7.220501032859147 na atividade C
# Cliente 13 esperou 0.0 na fila da atividade C
# Cliente 13 gastou 1.9778083669061175 na atividade C
# Cliente 14 esperou 0.0 na fila da atividade C
# Cliente 14 gastou 0.24413448254132675 na atividade C
# Cliente 15 esperou 0.0 na fila da atividade C
# Cliente 15 gastou 9.821157160949895 na atividade C
# Cliente 16 esperou 1.8211571609498947 na fila da atividade C
# Cliente 16 gastou 0.8583071296440039 na atividade C
# Cliente 17 esperou 0.0 na fila da atividade C
# Cliente 17 gastou 43.63852175279973 na atividade C
# Cliente 18 esperou 35.63852175279973 na fila da atividade C
# Cliente 18 gastou 6.1292083012305625 na atividade C
# Cliente 19 esperou 33.767730054030295 na fila da atividade C
# Cliente 19 gastou 6.410735457731391 na atividade C
# Cliente 20 esperou 32.17846551176169 na fila da atividade C
# Cliente 20 gastou 0.9624225309717644 na atividade C
# Cliente 21 esperou 25.14088804273345 na fila da atividade C
# Cliente 21 gastou 8.691153242966521 na atividade C
# Cliente 22 esperou 25.832041285699972 na fila da atividade C
# Cliente 22 gastou 8.638413911071837 na atividade C
# Cliente 23 esperou 26.47045519677181 na fila da atividade C
# Cliente 23 gastou 4.091019677977755 na atividade C
# Cliente 24 esperou 22.561474874749564 na fila da atividade C
# Cliente 24 gastou 1.0804440890773606 na atividade C
# Cliente 25 esperou 15.641918963826924 na fila da atividade C
# Cliente 25 gastou 0.8276695317728411 na atividade C
# Cliente 26 esperou 8.469588495599766 na fila da atividade C
# Cliente 26 gastou 13.456195546524071 na atividade C
# Cliente 27 esperou 13.925784042123837 na fila da atividade C
# Cliente 27 gastou 7.889650195231411 na atividade C
# Cliente 28 esperou 13.815434237355248 na fila da atividade C
# Cliente 28 gastou 2.2329268690721165 na atividade C
# Cliente 29 esperou 8.048361106427365 na fila da atividade C
# Cliente 29 gastou 2.3589560359647237 na atividade C
# Cliente 30 esperou 2.4073171423920883 na fila da atividade C
# Cliente 30 gastou 0.25593030221975255 na atividade C
# Cliente 31 esperou 0.0 na fila da atividade C
# Cliente 31 gastou 14.961764186840696 na atividade C
# Cliente 32 esperou 6.961764186840696 na fila da atividade C
# Cliente 32 gastou 0.21855449198966426 na atividade C
# Cliente 33 esperou 0.0 na fila da atividade C
# Cliente 33 gastou 4.557257675005985 na atividade C
# Cliente 34 esperou 0.0 na fila da atividade C
# Cliente 34 gastou 2.7998073404246497 na atividade C
# Cliente 35 esperou 0.0 na fila da atividade C
# Cliente 35 gastou 3.1576899768126623 na atividade C
# Cliente 36 esperou 0.0 na fila da atividade C
# Cliente 36 gastou 10.54589023213606 na atividade C
# Cliente 37 esperou 2.5458902321360597 na fila da atividade C
# Cliente 37 gastou 4.354240297738272 na atividade C
# Cliente 38 esperou 0.0 na fila da atividade C
# Cliente 38 gastou 2.729136620669351 na atividade C
# Cliente 39 esperou 0.0 na fila da atividade C
# Cliente 39 gastou 2.4876168732913015 na atividade C
# Cliente 40 esperou 0.0 na fila da atividade C
# Cliente 40 gastou 0.49519758346184517 na atividade C
# Cliente 41 esperou 0.0 na fila da atividade C
# Cliente 41 gastou 0.6299629397593662 na atividade C
# Cliente 42 esperou 0.0 na fila da atividade C
# Cliente 42 gastou 0.5648766991583329 na atividade C
# Cliente 43 esperou 0.0 na fila da atividade C
# Cliente 43 gastou 1.7122114221481866 na atividade C
# Cliente 44 esperou 0.0 na fila da atividade C
# Cliente 44 gastou 2.1200470435241527 na atividade C
# Cliente 45 esperou 0.0 na fila da atividade C
# Cliente 45 gastou 11.88737610864689 na atividade C
# Cliente 46 esperou 3.8873761086468903 na fila da atividade C
# Cliente 46 gastou 0.061478164110894795 na atividade C
# Cliente 47 esperou 0.0 na fila da atividade C
# Cliente 47 gastou 5.911203174814773 na atividade C
# Cliente 48 esperou 0.0 na fila da atividade C
# Cliente 48 gastou 3.2151795262473115 na atividade C
# Cliente 49 esperou 0.0 na fila da atividade C
# Cliente 49 gastou 1.2285201401987251 na atividade C
# Cliente 50 esperou 0.0 na fila da atividade C
# Cliente 50 gastou 1.0443645087643176 na atividade C
# Cliente 51 esperou 0.0 na fila da atividade C
# Cliente 51 gastou 9.913262405990906 na atividade C
# Cliente 52 esperou 1.9132624059909062 na fila da atividade C
# Cliente 52 gastou 0.08719191555786665 na atividade C
# Cliente 53 esperou 0.0 na fila da atividade C
# Cliente 53 gastou 9.076448691728103 na atividade C
# Cliente 54 esperou 1.0764486917281033 na fila da atividade C
# Cliente 54 gastou 6.491311909967521 na atividade C
# Cliente 55 esperou 0.0 na fila da atividade C
# Cliente 55 gastou 4.908561289586316 na atividade C
# Cliente 56 esperou 0.0 na fila da atividade C
# Cliente 56 gastou 0.9382446248071687 na atividade C
# Cliente 57 esperou 0.0 na fila da atividade C
# Cliente 57 gastou 1.1506452972225816 na atividade C
# Cliente 58 esperou 0.0 na fila da atividade C
# Cliente 58 gastou 8.592426582136056 na atividade C
# Cliente 59 esperou 0.5924265821360564 na fila da atividade C
# Cliente 59 gastou 4.392272859305933 na atividade C
# Cliente 60 esperou 0.0 na fila da atividade C
# Cliente 60 gastou 7.3641359363207926 na atividade C
# Cliente 61 esperou 0.0 na fila da atividade C
# Cliente 61 gastou 0.6655915648660198 na atividade C
# Cliente 62 esperou 0.0 na fila da atividade C
# Cliente 62 gastou 2.4328709619617825 na atividade C
# Cliente 63 esperou 0.0 na fila da atividade C
# Cliente 63 gastou 4.892618359068479 na atividade C
# Cliente 64 esperou 0.0 na fila da atividade C
# Cliente 64 gastou 4.011368211324907 na atividade C
# Cliente 65 esperou 0.0 na fila da atividade C
# Cliente 65 gastou 3.0726468313068835 na atividade C
# Cliente 66 esperou 0.0 na fila da atividade C
# Cliente 66 gastou 3.355231498419471 na atividade C
# Cliente 67 esperou 0.0 na fila da atividade C
# Cliente 67 gastou 0.3658448928904363 na atividade C
# Cliente 68 esperou 0.0 na fila da atividade C
# Cliente 68 gastou 0.40917638185146643 na atividade C
# Cliente 69 esperou 0.0 na fila da atividade C
# Cliente 69 gastou 8.216405615956774 na atividade C
# Cliente 70 esperou 0.21640561595677354 na fila da atividade C
# Cliente 70 gastou 4.287666305728408 na atividade C
# Cliente 71 esperou 0.0 na fila da atividade C
# Cliente 71 gastou 7.005795416606588 na atividade C
# Cliente 72 esperou 0.0 na fila da atividade C
# Cliente 72 gastou 5.024054865026187 na atividade C
# Cliente 73 esperou 0.0 na fila da atividade C
# Cliente 73 gastou 5.196666635968654 na atividade C
# Cliente 74 esperou 0.0 na fila da atividade C
# Cliente 74 gastou 5.876914003039815 na atividade C
# Cliente 75 esperou 0.0 na fila da atividade C
# Cliente 75 gastou 2.3429986991800433 na atividade C
# Cliente 76 esperou 0.0 na fila da atividade C
# Cliente 76 gastou 0.6140429782873298 na atividade C
# Cliente 77 esperou 0.0 na fila da atividade C
# Cliente 77 gastou 0.965151739476255 na atividade C
# Cliente 78 esperou 0.0 na fila da atividade C
# Cliente 78 gastou 0.14085895151015393 na atividade C
# Cliente 79 esperou 0.0 na fila da atividade C
# Cliente 79 gastou 3.0021338686467516 na atividade C
# Cliente 80 esperou 0.0 na fila da atividade C
# Cliente 80 gastou 8.72788995216979 na atividade C
# Cliente 81 esperou 0.7278899521697895 na fila da atividade C
# Cliente 81 gastou 2.0676866537639853 na atividade C
# Cliente 82 esperou 0.0 na fila da atividade C
# Cliente 82 gastou 0.8407239144526102 na atividade C
# Cliente 83 esperou 0.0 na fila da atividade C
# Cliente 83 gastou 1.6016604561950771 na atividade C
# Cliente 84 esperou 0.0 na fila da atividade C
# Cliente 84 gastou 4.136451159057287 na atividade C
# Cliente 85 esperou 0.0 na fila da atividade C
# Cliente 85 gastou 4.064715458518094 na atividade C
# Cliente 86 esperou 0.0 na fila da atividade C
# Cliente 86 gastou 0.8081709027758279 na atividade C
# Cliente 87 esperou 0.0 na fila da atividade C
# Cliente 87 gastou 1.9032055542768376 na atividade C
# Cliente 88 esperou 0.0 na fila da atividade C
# Cliente 88 gastou 0.6957369923505894 na atividade C
# Cliente 89 esperou 0.0 na fila da atividade C
# Cliente 89 gastou 5.60024731553176 na atividade C
# Cliente 90 esperou 0.0 na fila da atividade C
# Cliente 90 gastou 3.6896862297375037 na atividade C
# Cliente 91 esperou 0.0 na fila da atividade C
# Cliente 91 gastou 2.3911975529440497 na atividade C
# Cliente 92 esperou 0.0 na fila da atividade C
# Cliente 92 gastou 7.731381732967748 na atividade C
# Cliente 93 esperou 0.0 na fila da atividade C
# Cliente 93 gastou 6.390542596011983 na atividade C
# Cliente 94 esperou 0.0 na fila da atividade C
# Cliente 94 gastou 13.345256467434979 na atividade C
# Cliente 95 esperou 5.345256467434979 na fila da atividade C
# Cliente 95 gastou 2.857011024498547 na atividade C
# Cliente 96 esperou 0.2022674919335259 na fila da atividade C
# Cliente 96 gastou 5.3837286239428295 na atividade C
# Cliente 97 esperou 0.0 na fila da atividade C
# Cliente 97 gastou 12.43758416134392 na atividade C
# Cliente 98 esperou 4.437584161343921 na fila da atividade C
# Cliente 98 gastou 0.4748152602173832 na atividade C
# Cliente 99 esperou 0.0 na fila da atividade C
# Cliente 99 gastou 3.0439835577233225 na atividade C
# Cliente 100 esperou 0.0 na fila da atividade C
# Cliente 100 gastou 7.213121975336435 na atividade C
# Cliente 101 esperou 0.0 na fila da atividade C
# Cliente 101 gastou 1.0692431217773901 na atividade C
# Cliente 102 esperou 0.0 na fila da atividade C
# Cliente 102 gastou 1.381920729343733 na atividade C
# Cliente 103 esperou 0.0 na fila da atividade C
# Cliente 103 gastou 0.8493508915307757 na atividade C
# Cliente 104 esperou 0.0 na fila da atividade C
# Cliente 104 gastou 4.559451744152511 na atividade C
# Cliente 105 esperou 0.0 na fila da atividade C
# Cliente 105 gastou 8.526438155528467 na atividade C
# Cliente 106 esperou 0.5264381555284672 na fila da atividade C
# Cliente 106 gastou 21.841000068082053 na atividade C
# Cliente 107 esperou 14.36743822361052 na fila da atividade C
# Cliente 107 gastou 9.612621072420097 na atividade C
# Cliente 108 esperou 15.980059296030618 na fila da atividade C
# Cliente 108 gastou 3.041296320513652 na atividade C
# Cliente 109 esperou 11.02135561654427 na fila da atividade C
# Cliente 109 gastou 9.62924550911464 na atividade C
# Cliente 110 esperou 12.650601125658909 na fila da atividade C
# Cliente 110 gastou 0.8417979425641988 na atividade C
# Cliente 111 esperou 5.492399068223108 na fila da atividade C
# Cliente 111 gastou 3.313913787544493 na atividade C
# Cliente 112 esperou 0.8063128557676009 na fila da atividade C
# Cliente 112 gastou 0.024609542869256984 na atividade C
# Cliente 113 esperou 0.0 na fila da atividade C
# Cliente 113 gastou 3.4808674282551237 na atividade C
# Cliente 114 esperou 0.0 na fila da atividade C
# Cliente 114 gastou 10.471888365760265 na atividade C
# Cliente 115 esperou 2.4718883657602646 na fila da atividade C
# Cliente 115 gastou 0.613706926205623 na atividade C
# Cliente 116 esperou 0.0 na fila da atividade C
# Cliente 116 gastou 9.124863513718992 na atividade C
# Cliente 117 esperou 1.1248635137189922 na fila da atividade C
# Cliente 117 gastou 10.482950969485614 na atividade C
# Cliente 118 esperou 3.6078144832046064 na fila da atividade C
# Cliente 118 gastou 4.000800037660838 na atividade C
# Cliente 119 esperou 0.0 na fila da atividade C
# Cliente 119 gastou 11.477213279938155 na atividade C
# Cliente 120 esperou 3.477213279938155 na fila da atividade C
# Cliente 120 gastou 6.993670881437879 na atividade C
# Cliente 121 esperou 2.470884161376034 na fila da atividade C
# Cliente 121 gastou 8.442777810177859 na atividade C
# Cliente 122 esperou 2.9136619715538927 na fila da atividade C
# Cliente 122 gastou 2.5027431402171487 na atividade C
# Cliente 123 esperou 0.0 na fila da atividade C
# Cliente 123 gastou 5.010681409049539 na atividade C
# Cliente 124 esperou 0.0 na fila da atividade C
# Cliente 124 gastou 6.218377829148267 na atividade C
# Cliente 125 esperou 0.0 na fila da atividade C
# Cliente 125 gastou 5.947702849472648 na atividade C
# Cliente 126 esperou 0.0 na fila da atividade C
# Cliente 126 gastou 1.7744551371744137 na atividade C
# Cliente 127 esperou 0.0 na fila da atividade C
# Cliente 127 gastou 1.2859885411544383 na atividade C
# Cliente 128 esperou 0.0 na fila da atividade C
# Cliente 128 gastou 1.7971896855058276 na atividade C
# Cliente 129 esperou 0.0 na fila da atividade C
# Cliente 129 gastou 4.557152573628855 na atividade C
# Cliente 130 esperou 0.0 na fila da atividade C
# Cliente 130 gastou 0.11734451661664025 na atividade C
# Cliente 131 esperou 0.0 na fila da atividade C
# Cliente 131 gastou 8.450348425387801 na atividade C
# Cliente 132 esperou 0.4503484253878014 na fila da atividade C
# Cliente 132 gastou 0.8754135527008202 na atividade C
# Cliente 133 esperou 0.0 na fila da atividade C
# Cliente 133 gastou 0.13740327881782832 na atividade C
# Cliente 134 esperou 0.0 na fila da atividade C
# Cliente 134 gastou 0.16467813803842546 na atividade C
# Cliente 135 esperou 0.0 na fila da atividade C
# Cliente 135 gastou 1.8376001513761366 na atividade C
# Cliente 136 esperou 0.0 na fila da atividade C
# Cliente 136 gastou 7.302527465031062 na atividade C
# Cliente 137 esperou 0.0 na fila da atividade C
# Cliente 137 gastou 0.14412728890511062 na atividade C
# Cliente 138 esperou 0.0 na fila da atividade C
# Cliente 138 gastou 0.21935645299868156 na atividade C
# Cliente 139 esperou 0.0 na fila da atividade C
# Cliente 139 gastou 3.0263574536591022 na atividade C
# Cliente 140 esperou 0.0 na fila da atividade C
# Cliente 140 gastou 1.497954900952891 na atividade C
# Cliente 141 esperou 0.0 na fila da atividade C
# Cliente 141 gastou 5.460544766793646 na atividade C
# Cliente 142 esperou 0.0 na fila da atividade C
# Cliente 142 gastou 3.2063481285915714 na atividade C
# Cliente 143 esperou 0.0 na fila da atividade C
# Cliente 143 gastou 7.264933334399302 na atividade C
# Cliente 144 esperou 0.0 na fila da atividade C
# Cliente 144 gastou 2.157960249792268 na atividade C
# Cliente 145 esperou 0.0 na fila da atividade C
# Cliente 145 gastou 5.985437910858536 na atividade C
# Cliente 146 esperou 0.0 na fila da atividade C
# Cliente 146 gastou 1.745427618660642 na atividade C
# Cliente 147 esperou 0.0 na fila da atividade C
# Cliente 147 gastou 2.22914343707248 na atividade C
# Cliente 148 esperou 0.0 na fila da atividade C
# Cliente 148 gastou 3.183540901842207 na atividade C
# Cliente 149 esperou 0.0 na fila da atividade C
# Cliente 149 gastou 1.9410485782484557 na atividade C
# Cliente 150 esperou 0.0 na fila da atividade C
# Cliente 150 gastou 4.405034347966875 na atividade C
# Cliente 151 esperou 0.0 na fila da atividade C
# Cliente 151 gastou 6.444760107044431 na atividade C
# Cliente 152 esperou 0.0 na fila da atividade C
# Cliente 152 gastou 0.21555857165890302 na atividade C
# Cliente 153 esperou 0.0 na fila da atividade C
# Cliente 153 gastou 2.502023771224458 na atividade C
# Cliente 154 esperou 0.0 na fila da atividade C
# Cliente 154 gastou 1.1321514384369493 na atividade C
# Cliente 155 esperou 0.0 na fila da atividade C
# Cliente 155 gastou 9.483964361728567 na atividade C
# Cliente 156 esperou 1.4839643617285674 na fila da atividade C
# Cliente 156 gastou 3.3805881541993585 na atividade C
# Cliente 157 esperou 0.0 na fila da atividade C
# Cliente 157 gastou 3.9897239008823817 na atividade C
# Cliente 158 esperou 0.0 na fila da atividade C
# Cliente 158 gastou 3.352075098647674 na atividade C
# Cliente 159 esperou 0.0 na fila da atividade C
# Cliente 159 gastou 18.99626948743753 na atividade C
# Cliente 160 esperou 10.99626948743753 na fila da atividade C
# Cliente 160 gastou 5.9453707092654895 na atividade C
# Cliente 161 esperou 8.94164019670302 na fila da atividade C
# Cliente 161 gastou 1.4048283810016073 na atividade C
# Cliente 162 esperou 2.346468577704627 na fila da atividade C
# Cliente 162 gastou 5.2107170829435745 na atividade C
# Cliente 163 esperou 0.0 na fila da atividade C
# Cliente 163 gastou 0.9299534712447439 na atividade C
# Cliente 164 esperou 0.0 na fila da atividade C
# Cliente 164 gastou 2.5938507866826512 na atividade C
# Cliente 165 esperou 0.0 na fila da atividade C
# Cliente 165 gastou 1.3027350755367024 na atividade C
# Cliente 166 esperou 0.0 na fila da atividade C
# Cliente 166 gastou 8.998131962163825 na atividade C
# Cliente 167 esperou 0.9981319621638249 na fila da atividade C
# Cliente 167 gastou 7.029097887123953 na atividade C
# Cliente 168 esperou 0.027229849287778052 na fila da atividade C
# Cliente 168 gastou 8.101009896827009 na atividade C
# Cliente 169 esperou 0.1282397461147866 na fila da atividade C
# Cliente 169 gastou 6.7104417065690996 na atividade C
# Cliente 170 esperou 0.0 na fila da atividade C
# Cliente 170 gastou 3.7005194473836127 na atividade C
# Cliente 171 esperou 0.0 na fila da atividade C
# Cliente 171 gastou 1.0487427413311252 na atividade C
# Cliente 172 esperou 0.0 na fila da atividade C
# Cliente 172 gastou 5.085400170612047 na atividade C
# Cliente 173 esperou 0.0 na fila da atividade C
# Cliente 173 gastou 12.523432794601604 na atividade C
# Cliente 174 esperou 4.523432794601604 na fila da atividade C
# Cliente 174 gastou 11.551459472180795 na atividade C
# Cliente 175 esperou 8.074892266782399 na fila da atividade C
# Cliente 175 gastou 1.9846269326310448 na atividade C
# Cliente 176 esperou 2.059519199413444 na fila da atividade C
# Cliente 176 gastou 10.862662712127758 na atividade C
# Cliente 177 esperou 4.922181911541202 na fila da atividade C
# Cliente 177 gastou 12.97659351733455 na atividade C
# Cliente 178 esperou 9.898775428875751 na fila da atividade C
# Cliente 178 gastou 3.5462688049387907 na atividade C
# Cliente 179 esperou 5.445044233814542 na fila da atividade C
# Cliente 179 gastou 3.636861695311609 na atividade C
# Cliente 180 esperou 1.081905929126151 na fila da atividade C
# Cliente 180 gastou 1.5760430769291816 na atividade C
# Cliente 181 esperou 0.0 na fila da atividade C
# Cliente 181 gastou 7.066076524631853 na atividade C
# Cliente 182 esperou 0.0 na fila da atividade C
# Cliente 182 gastou 8.511539843010496 na atividade C
# Cliente 183 esperou 0.511539843010496 na fila da atividade C
# Cliente 183 gastou 5.083784242211323 na atividade C
# Cliente 184 esperou 0.0 na fila da atividade C
# Cliente 184 gastou 8.407504171901792 na atividade C
# Cliente 185 esperou 0.4075041719017918 na fila da atividade C
# Cliente 185 gastou 12.895375233921186 na atividade C
# Cliente 186 esperou 5.302879405822978 na fila da atividade C
# Cliente 186 gastou 2.9910975303125724 na atividade C
# Cliente 187 esperou 0.2939769361355502 na fila da atividade C
# Cliente 187 gastou 4.756435398089252 na atividade C
# Cliente 188 esperou 0.0 na fila da atividade C
# Cliente 188 gastou 0.3426373099182456 na atividade C
# Cliente 189 esperou 0.0 na fila da atividade C
# Cliente 189 gastou 1.5684921991744432 na atividade C
# Cliente 190 esperou 0.0 na fila da atividade C
# Cliente 190 gastou 0.2942108362615272 na atividade C
# Cliente 191 esperou 0.0 na fila da atividade C
# Cliente 191 gastou 8.659431621774957 na atividade C
# Cliente 192 esperou 0.6594316217749565 na fila da atividade C
# Cliente 192 gastou 5.383179486479776 na atividade C
# Cliente 193 esperou 0.0 na fila da atividade C
# Cliente 193 gastou 10.377744350237208 na atividade C
# Cliente 194 esperou 2.377744350237208 na fila da atividade C
# Cliente 194 gastou 4.302365339945936 na atividade C
# Cliente 195 esperou 0.0 na fila da atividade C
# Cliente 195 gastou 3.12249390032639 na atividade C
# Cliente 196 esperou 0.0 na fila da atividade C
# Cliente 196 gastou 26.584705547820022 na atividade C
# Cliente 197 esperou 18.584705547820022 na fila da atividade C
# Cliente 197 gastou 3.11893916743702 na atividade C
# Cliente 198 esperou 13.703644715257042 na fila da atividade C
# Cliente 198 gastou 1.6046112550811813 na atividade C
# Cliente 199 esperou 7.308255970338223 na fila da atividade C
# Cliente 199 gastou 4.0530847632435325 na atividade C
# Cliente 200 esperou 3.3613407335817556 na fila da atividade C
# Cliente 200 gastou 7.211903721919498 na atividade C
# Cliente 201 esperou 2.5732444555012535 na fila da atividade C
# Cliente 201 gastou 0.8675352818997908 na atividade C
# Cliente 202 esperou 0.0 na fila da atividade C
# Cliente 202 gastou 11.561859641526098 na atividade C
# Cliente 203 esperou 3.561859641526098 na fila da atividade C
# Cliente 203 gastou 0.2566337855080292 na atividade C
# Cliente 204 esperou 0.0 na fila da atividade C
# Cliente 204 gastou 0.9260248694890834 na atividade C
# Cliente 205 esperou 0.0 na fila da atividade C
# Cliente 205 gastou 3.9950646798115486 na atividade C
# Cliente 206 esperou 0.0 na fila da atividade C
# Cliente 206 gastou 7.112431101976654 na atividade C
# Cliente 207 esperou 0.0 na fila da atividade C
# Cliente 207 gastou 1.83982719900132 na atividade C
# Cliente 208 esperou 0.0 na fila da atividade C
# Cliente 208 gastou 0.37390884934234236 na atividade C
# Cliente 209 esperou 0.0 na fila da atividade C
# Cliente 209 gastou 5.286042951298668 na atividade C
# Cliente 210 esperou 0.0 na fila da atividade C
# Cliente 210 gastou 9.407006607076255 na atividade C
# Cliente 211 esperou 1.407006607076255 na fila da atividade C
# Cliente 211 gastou 6.723997100303677 na atividade C
# Cliente 212 esperou 0.13100370737993217 na fila da atividade C
# Cliente 212 gastou 5.706911377745428 na atividade C
# Cliente 213 esperou 0.0 na fila da atividade C
# Cliente 213 gastou 5.57520403919284 na atividade C
# Cliente 214 esperou 0.0 na fila da atividade C
# Cliente 214 gastou 2.0662674492682527 na atividade C
# Cliente 215 esperou 0.0 na fila da atividade C
# Cliente 215 gastou 3.375680434766764 na atividade C
# Cliente 216 esperou 0.0 na fila da atividade C
# Cliente 216 gastou 3.8462618549638137 na atividade C
# Cliente 217 esperou 0.0 na fila da atividade C
# Cliente 217 gastou 2.335930322406057 na atividade C
# Cliente 218 esperou 0.0 na fila da atividade C
# Cliente 218 gastou 4.360032312695239 na atividade C
# Cliente 219 esperou 0.0 na fila da atividade C
# Cliente 219 gastou 3.1771299033459854 na atividade C
# Cliente 220 esperou 0.0 na fila da atividade C
# Cliente 220 gastou 7.929631292973227 na atividade C
# Cliente 221 esperou 0.0 na fila da atividade C
# Cliente 221 gastou 2.0787720289038134 na atividade C
# Cliente 222 esperou 0.0 na fila da atividade C
# Cliente 222 gastou 2.865674719539129 na atividade C
# Cliente 223 esperou 0.0 na fila da atividade C
# Cliente 223 gastou 0.9643023317321422 na atividade C
# Cliente 224 esperou 0.0 na fila da atividade C
# Cliente 224 gastou 0.021961977679893607 na atividade C
# Cliente 225 esperou 0.0 na fila da atividade C
# Cliente 225 gastou 5.115539643886677 na atividade C
# Cliente 226 esperou 0.0 na fila da atividade C
# Cliente 226 gastou 4.48148908886219 na atividade C
# Cliente 227 esperou 0.0 na fila da atividade C
# Cliente 227 gastou 0.9079911937851648 na atividade C
# Cliente 228 esperou 0.0 na fila da atividade C
# Cliente 228 gastou 1.0417658685605602 na atividade C
# Cliente 229 esperou 0.0 na fila da atividade C
# Cliente 229 gastou 0.28234839769538667 na atividade C
# Cliente 230 esperou 0.0 na fila da atividade C
# Cliente 230 gastou 4.179108356975576 na atividade C
# Cliente 231 esperou 0.0 na fila da atividade C
# Cliente 231 gastou 12.824921684500396 na atividade C
# Cliente 232 esperou 4.824921684500396 na fila da atividade C
# Cliente 232 gastou 17.14873785445957 na atividade C
# Cliente 233 esperou 13.973659538959964 na fila da atividade C
# Cliente 233 gastou 0.7707581465817839 na atividade C
# Cliente 234 esperou 6.744417685541748 na fila da atividade C
# Cliente 234 gastou 5.2899041136181495 na atividade C
# Cliente 235 esperou 4.034321799159898 na fila da atividade C
# Cliente 235 gastou 9.688179616746993 na atividade C
# Cliente 236 esperou 5.7225014159068905 na fila da atividade C
# Cliente 236 gastou 2.6142060915371985 na atividade C
# Cliente 237 esperou 0.33670750744408906 na fila da atividade C
# Cliente 237 gastou 4.2036956070778615 na atividade C
# Cliente 238 esperou 0.0 na fila da atividade C
# Cliente 238 gastou 9.579251843924112 na atividade C
# Cliente 239 esperou 1.579251843924112 na fila da atividade C
# Cliente 239 gastou 9.349171325611223 na atividade C
# Cliente 240 esperou 2.9284231695353355 na fila da atividade C
# Cliente 240 gastou 1.6139596789112147 na atividade C
# Cliente 241 esperou 0.0 na fila da atividade C
# Cliente 241 gastou 1.065352749469639 na atividade C
# Cliente 242 esperou 0.0 na fila da atividade C
# Cliente 242 gastou 2.3952194346234137 na atividade C
# Cliente 243 esperou 0.0 na fila da atividade C
# Cliente 243 gastou 4.3754420376603775 na atividade C
# Cliente 244 esperou 0.0 na fila da atividade C
# Cliente 244 gastou 8.990373525308087 na atividade C
# Cliente 245 esperou 0.9903735253080868 na fila da atividade C
# Cliente 245 gastou 3.3596939732940427 na atividade C
# Cliente 246 esperou 0.0 na fila da atividade C
# Cliente 246 gastou 9.202790816284278 na atividade C
# Cliente 247 esperou 1.2027908162842778 na fila da atividade C
# Cliente 247 gastou 4.254651456902138 na atividade C
# Cliente 248 esperou 0.0 na fila da atividade C
# Cliente 248 gastou 0.14697153381644057 na atividade C
# Cliente 249 esperou 0.0 na fila da atividade C
# Cliente 249 gastou 4.638770906400623 na atividade C
# Cliente 250 esperou 0.0 na fila da atividade C
# Cliente 250 gastou 2.422713786424765 na atividade C
# Cliente 251 esperou 0.0 na fila da atividade C
# Cliente 251 gastou 3.1959601483476945 na atividade C
# Cliente 252 esperou 0.0 na fila da atividade C
# Cliente 252 gastou 3.4233191098635416 na atividade C
# Cliente 253 esperou 0.0 na fila da atividade C
# Cliente 253 gastou 6.143717207499776 na atividade C
# Cliente 254 esperou 0.0 na fila da atividade C
# Cliente 254 gastou 10.798638564308021 na atividade C
# Cliente 255 esperou 2.798638564308021 na fila da atividade C
# Cliente 255 gastou 4.067982278543695 na atividade C
# Cliente 256 esperou 0.0 na fila da atividade C
# Cliente 256 gastou 14.772839068401026 na atividade C
# Cliente 257 esperou 6.7728390684010265 na fila da atividade C
# Cliente 257 gastou 0.9343150738291115 na atividade C
# Cliente 258 esperou 0.0 na fila da atividade C
# Cliente 258 gastou 0.22527175866935067 na atividade C
# Cliente 259 esperou 0.0 na fila da atividade C
# Cliente 259 gastou 1.775353607174111 na atividade C
# Cliente 260 esperou 0.0 na fila da atividade C
# Cliente 260 gastou 7.862572960998023 na atividade C
# Cliente 261 esperou 0.0 na fila da atividade C
# Cliente 261 gastou 2.026787242365117 na atividade C
# Cliente 262 esperou 0.0 na fila da atividade C
# Cliente 262 gastou 4.718176379548822 na atividade C
# Cliente 263 esperou 0.0 na fila da atividade C
# Cliente 263 gastou 4.061391327680212 na atividade C
# Cliente 264 esperou 0.0 na fila da atividade C
# Cliente 264 gastou 6.0284878963720985 na atividade C
# Cliente 265 esperou 0.0 na fila da atividade C
# Cliente 265 gastou 5.536718718104112 na atividade C
# Cliente 266 esperou 0.0 na fila da atividade C
# Cliente 266 gastou 3.142070782000701 na atividade C
# Cliente 267 esperou 0.0 na fila da atividade C
# Cliente 267 gastou 1.942444370289195 na atividade C
# Cliente 268 esperou 0.0 na fila da atividade C
# Cliente 268 gastou 0.4929254040516753 na atividade C
# Cliente 269 esperou 0.0 na fila da atividade C
# Cliente 269 gastou 1.8995060871866372 na atividade C
# Cliente 270 esperou 0.0 na fila da atividade C
# Cliente 270 gastou 6.7333056120705805 na atividade C
# Cliente 271 esperou 0.0 na fila da atividade C
# Cliente 271 gastou 16.88209306218323 na atividade C
# Cliente 272 esperou 8.88209306218323 na fila da atividade C
# Cliente 272 gastou 0.273144450640757 na atividade C
# Cliente 273 esperou 1.1552375128239873 na fila da atividade C
# Cliente 273 gastou 4.265027010319955 na atividade C
# Cliente 274 esperou 0.0 na fila da atividade C
# Cliente 274 gastou 0.15377705705986955 na atividade C
# Cliente 275 esperou 0.0 na fila da atividade C
# Cliente 275 gastou 4.682728892564228 na atividade C
# Cliente 276 esperou 0.0 na fila da atividade C
# Cliente 276 gastou 2.3841083826046088 na atividade C
# Cliente 277 esperou 0.0 na fila da atividade C
# Cliente 277 gastou 3.9345528102694516 na atividade C
# Cliente 278 esperou 0.0 na fila da atividade C
# Cliente 278 gastou 2.4787563877785033 na atividade C
# Cliente 279 esperou 0.0 na fila da atividade C
# Cliente 279 gastou 9.400540701949467 na atividade C
# Cliente 280 esperou 1.400540701949467 na fila da atividade C
# Cliente 280 gastou 6.420595804756431 na atividade C
# Cliente 281 esperou 0.0 na fila da atividade C
# Cliente 281 gastou 5.437316722092419 na atividade C
# Cliente 282 esperou 0.0 na fila da atividade C
# Cliente 282 gastou 16.007258585296768 na atividade C
# Cliente 283 esperou 8.007258585296768 na fila da atividade C
# Cliente 283 gastou 2.675341912825843 na atividade C
# Cliente 284 esperou 2.6826004981226106 na fila da atividade C
# Cliente 284 gastou 13.506014768870045 na atividade C
# Cliente 285 esperou 8.188615266992656 na fila da atividade C
# Cliente 285 gastou 2.995255732208534 na atividade C
# Cliente 286 esperou 3.18387099920119 na fila da atividade C
# Cliente 286 gastou 1.2768780594092277 na atividade C
# Cliente 287 esperou 0.0 na fila da atividade C
# Cliente 287 gastou 3.835292398654019 na atividade C
# Cliente 288 esperou 0.0 na fila da atividade C
# Cliente 288 gastou 4.420883105982739 na atividade C
# Cliente 289 esperou 0.0 na fila da atividade C
# Cliente 289 gastou 0.8616904543882811 na atividade C
# Cliente 290 esperou 0.0 na fila da atividade C
# Cliente 290 gastou 2.2549329189018863 na atividade C
# Cliente 291 esperou 0.0 na fila da atividade C
# Cliente 291 gastou 0.5703225097590803 na atividade C
# Cliente 292 esperou 0.0 na fila da atividade C
# Cliente 292 gastou 9.326819723230983 na atividade C
# Cliente 293 esperou 1.326819723230983 na fila da atividade C
# Cliente 293 gastou 5.4248188570713864 na atividade C
# Cliente 294 esperou 0.0 na fila da atividade C
# Cliente 294 gastou 0.11630625060024613 na atividade C
# Cliente 295 esperou 0.0 na fila da atividade C
# Cliente 295 gastou 1.514520048598115 na atividade C
# Cliente 296 esperou 0.0 na fila da atividade C
# Cliente 296 gastou 3.908116252464424 na atividade C
# Cliente 297 esperou 0.0 na fila da atividade C
# Cliente 297 gastou 9.469687239908126 na atividade C
# Cliente 298 esperou 1.4696872399081258 na fila da atividade C
# Cliente 298 gastou 1.0951488351256558 na atividade C
# Cliente 299 esperou 0.0 na fila da atividade C
# Cliente 299 gastou 7.955438550705821 na atividade C
# Cliente 300 esperou 0.0 na fila da atividade C
# Cliente 300 gastou 0.4063647973202933 na atividade C
# Cliente 301 esperou 0.0 na fila da atividade C
# Cliente 301 gastou 2.373827173186328 na atividade C
# Cliente 302 esperou 0.0 na fila da atividade C
# Cliente 302 gastou 0.38954495950383716 na atividade C
# Cliente 303 esperou 0.0 na fila da atividade C
# Cliente 303 gastou 2.978975894557152 na atividade C
# Cliente 304 esperou 0.0 na fila da atividade C
# Cliente 304 gastou 1.739574524490763 na atividade C
# Cliente 305 esperou 0.0 na fila da atividade C
# Cliente 305 gastou 1.4645811547570702 na atividade C
# Cliente 306 esperou 0.0 na fila da atividade C
# Cliente 306 gastou 4.1665219879005235 na atividade C
# Cliente 307 esperou 0.0 na fila da atividade C
# Cliente 307 gastou 6.393510288472953 na atividade C
# Cliente 308 esperou 0.0 na fila da atividade C
# Cliente 308 gastou 1.6834141999802341 na atividade C
# Cliente 309 esperou 0.0 na fila da atividade C
# Cliente 309 gastou 4.21273151240257 na atividade C
# Cliente 310 esperou 0.0 na fila da atividade C
# Cliente 310 gastou 4.026995171431281 na atividade C
# Cliente 311 esperou 0.0 na fila da atividade C
# Cliente 311 gastou 3.3859978317964305 na atividade C
# Cliente 312 esperou 0.0 na fila da atividade C
# Cliente 312 gastou 1.5008505868313478 na atividade C
# Cliente 313 esperou 0.0 na fila da atividade C
# Cliente 313 gastou 8.709219076539739 na atividade C
# Cliente 314 esperou 0.709219076539739 na fila da atividade C
# Cliente 314 gastou 0.5908392023943634 na atividade C
# Cliente 315 esperou 0.0 na fila da atividade C
# Cliente 315 gastou 0.29884487432536844 na atividade C
# Cliente 316 esperou 0.0 na fila da atividade C
# Cliente 316 gastou 6.061074967019977 na atividade C
# Cliente 317 esperou 0.0 na fila da atividade C
# Cliente 317 gastou 0.5238167438992605 na atividade C
# Cliente 318 esperou 0.0 na fila da atividade C
# Cliente 318 gastou 11.290597297405839 na atividade C
# Cliente 319 esperou 3.2905972974058386 na fila da atividade C
# Cliente 319 gastou 2.8083613389885613 na atividade C
# Cliente 320 esperou 0.0 na fila da atividade C
# Cliente 320 gastou 13.182123476326069 na atividade C
# Cliente 321 esperou 5.182123476326069 na fila da atividade C
# Cliente 321 gastou 0.3695566311330367 na atividade C
# Cliente 322 esperou 0.0 na fila da atividade C
# Cliente 322 gastou 14.137155539845025 na atividade C
# Cliente 323 esperou 6.1371555398450255 na fila da atividade C
# Cliente 323 gastou 9.445724465415424 na atividade C
# Cliente 324 esperou 7.582880005260449 na fila da atividade C
# Cliente 324 gastou 7.163798410122581 na atividade C
# Cliente 325 esperou 6.74667841538303 na fila da atividade C
# Cliente 325 gastou 2.8962146555513755 na atividade C
# Cliente 326 esperou 1.6428930709344058 na fila da atividade C
# Cliente 326 gastou 1.9576558944863791 na atividade C
# Cliente 327 esperou 0.0 na fila da atividade C
# Cliente 327 gastou 9.437560562483668 na atividade C
# Cliente 328 esperou 1.437560562483668 na fila da atividade C
# Cliente 328 gastou 8.969213272249817 na atividade C
# Cliente 329 esperou 2.4067738347334853 na fila da atividade C
# Cliente 329 gastou 5.937871250934677 na atividade C
# Cliente 330 esperou 0.3446450856681622 na fila da atividade C
# Cliente 330 gastou 2.976961576217036 na atividade C
# Cliente 331 esperou 0.0 na fila da atividade C
# Cliente 331 gastou 1.3841395514009491 na atividade C
# Cliente 332 esperou 0.0 na fila da atividade C
# Cliente 332 gastou 5.337814657459603 na atividade C
# Cliente 333 esperou 0.0 na fila da atividade C
# Cliente 333 gastou 7.388615975949051 na atividade C
# Cliente 334 esperou 0.0 na fila da atividade C
# Cliente 334 gastou 4.6932629636471574 na atividade C
# Cliente 335 esperou 0.0 na fila da atividade C
# Cliente 335 gastou 6.236821995520131 na atividade C
# Cliente 336 esperou 0.0 na fila da atividade C
# Cliente 336 gastou 3.6340931296176677 na atividade C
# Cliente 337 esperou 0.0 na fila da atividade C
# Cliente 337 gastou 5.134680729082447 na atividade C
# Cliente 338 esperou 0.0 na fila da atividade C
# Cliente 338 gastou 5.2082245934889215 na atividade C
# Cliente 339 esperou 0.0 na fila da atividade C
# Cliente 339 gastou 0.2977149947264479 na atividade C
# Cliente 340 esperou 0.0 na fila da atividade C
# Cliente 340 gastou 0.7212546527007362 na atividade C
# Cliente 341 esperou 0.0 na fila da atividade C
# Cliente 341 gastou 25.782486674766915 na atividade C
# Cliente 342 esperou 17.782486674766915 na fila da atividade C
# Cliente 342 gastou 16.242558342583834 na atividade C
# Cliente 343 esperou 26.02504501735075 na fila da atividade C
# Cliente 343 gastou 4.380604129161384 na atividade C
# Cliente 344 esperou 22.405649146512133 na fila da atividade C
# Cliente 344 gastou 10.091024738447231 na atividade C
# Cliente 345 esperou 24.496673884959364 na fila da atividade C
# Cliente 345 gastou 6.189651926711576 na atividade C
# Cliente 346 esperou 22.68632581167094 na fila da atividade C
# Cliente 346 gastou 12.204330549261158 na atividade C
# Cliente 347 esperou 26.8906563609321 na fila da atividade C
# Cliente 347 gastou 1.1170583857679048 na atividade C
# Cliente 348 esperou 20.007714746700003 na fila da atividade C
# Cliente 348 gastou 2.953098083669829 na atividade C
# Cliente 349 esperou 14.960812830369832 na fila da atividade C
# Cliente 349 gastou 3.1486121799371176 na atividade C
# Cliente 350 esperou 10.10942501030695 na fila da atividade C
# Cliente 350 gastou 3.952826012642163 na atividade C
# Cliente 351 esperou 6.062251022949113 na fila da atividade C
# Cliente 351 gastou 1.7809031352917373 na atividade C
# Cliente 352 esperou 0.0 na fila da atividade C
# Cliente 352 gastou 2.956805822419483 na atividade C
# Cliente 353 esperou 0.0 na fila da atividade C
# Cliente 353 gastou 2.64501066994535 na atividade C
# Cliente 354 esperou 0.0 na fila da atividade C
# Cliente 354 gastou 9.929938648067491 na atividade C
# Cliente 355 esperou 1.9299386480674912 na fila da atividade C
# Cliente 355 gastou 0.34176201304717324 na atividade C
# Cliente 356 esperou 0.0 na fila da atividade C
# Cliente 356 gastou 1.022645251085578 na atividade C
# Cliente 357 esperou 0.0 na fila da atividade C
# Cliente 357 gastou 0.22568471994645734 na atividade C
# Cliente 358 esperou 0.0 na fila da atividade C
# Cliente 358 gastou 7.280407936193114 na atividade C
# Cliente 359 esperou 0.0 na fila da atividade C
# Cliente 359 gastou 0.3316912933005369 na atividade C
# Cliente 360 esperou 0.0 na fila da atividade C
# Cliente 360 gastou 7.8358547203970375 na atividade C
# Cliente 361 esperou 0.0 na fila da atividade C
# Cliente 361 gastou 8.609715585516824 na atividade C
# Cliente 362 esperou 0.6097155855168239 na fila da atividade C
# Cliente 362 gastou 11.68120523111429 na atividade C
# Cliente 363 esperou 4.290920816631115 na fila da atividade C
# Cliente 363 gastou 0.9603569651508224 na atividade C
# Cliente 364 esperou 0.0 na fila da atividade C
# Cliente 364 gastou 0.04291402367516639 na atividade C
# Cliente 365 esperou 0.0 na fila da atividade C
# Cliente 365 gastou 2.161491606785603 na atividade C
# Cliente 366 esperou 0.0 na fila da atividade C
# Cliente 366 gastou 10.013418117836864 na atividade C
# Cliente 367 esperou 2.0134181178368635 na fila da atividade C
# Cliente 367 gastou 22.118264408417872 na atividade C
# Cliente 368 esperou 16.131682526254735 na fila da atividade C
# Cliente 368 gastou 5.81562009818208 na atividade C
# Cliente 369 esperou 13.947302624436816 na fila da atividade C
# Cliente 369 gastou 9.602641597187812 na atividade C
# Cliente 370 esperou 15.549944221624628 na fila da atividade C
# Cliente 370 gastou 9.308487073022206 na atividade C
# Cliente 371 esperou 16.858431294646834 na fila da atividade C
# Cliente 371 gastou 6.496045347368636 na atividade C
# Cliente 372 esperou 15.35447664201547 na fila da atividade C
# Cliente 372 gastou 9.067505345743484 na atividade C
# Cliente 373 esperou 16.421981987758954 na fila da atividade C
# Cliente 373 gastou 3.465239016346459 na atividade C
# Cliente 374 esperou 11.887221004105413 na fila da atividade C
# Cliente 374 gastou 0.39849899563478175 na atividade C
# Cliente 375 esperou 4.285719999740195 na fila da atividade C
# Cliente 375 gastou 17.238436173900936 na atividade C
# Cliente 376 esperou 13.524156173641131 na fila da atividade C
# Cliente 376 gastou 9.864192359707431 na atividade C
# Cliente 377 esperou 15.388348533348562 na fila da atividade C
# Cliente 377 gastou 3.797493590938302 na atividade C
# Cliente 378 esperou 11.185842124286864 na fila da atividade C
# Cliente 378 gastou 2.7802655738069006 na atividade C
# Cliente 379 esperou 5.966107698093765 na fila da atividade C
# Cliente 379 gastou 12.98960487165914 na atividade C
# Cliente 380 esperou 10.955712569752905 na fila da atividade C
# Cliente 380 gastou 4.263446781413222 na atividade C
# Cliente 381 esperou 7.219159351166127 na fila da atividade C
# Cliente 381 gastou 0.08650215961961294 na atividade C
# Cliente 382 esperou 0.0 na fila da atividade C
# Cliente 382 gastou 3.7878911967623026 na atividade C
# Cliente 383 esperou 0.0 na fila da atividade C
# Cliente 383 gastou 1.5100190181501603 na atividade C
# Cliente 384 esperou 0.0 na fila da atividade C
# Cliente 384 gastou 0.31342393143540903 na atividade C
# Cliente 385 esperou 0.0 na fila da atividade C
# Cliente 385 gastou 4.23839726992037 na atividade C
# Cliente 386 esperou 0.0 na fila da atividade C
# Cliente 386 gastou 8.551560792431246 na atividade C
# Cliente 387 esperou 0.5515607924312462 na fila da atividade C
# Cliente 387 gastou 3.0888071020885945 na atividade C
# Cliente 388 esperou 0.0 na fila da atividade C
# Cliente 388 gastou 3.219219562699436 na atividade C
# Cliente 389 esperou 0.0 na fila da atividade C
# Cliente 389 gastou 0.828548991074058 na atividade C
# Cliente 390 esperou 0.0 na fila da atividade C
# Cliente 390 gastou 8.112061747532607 na atividade C
# Cliente 391 esperou 0.11206174753260711 na fila da atividade C
# Cliente 391 gastou 7.8104053906522495 na atividade C
# Cliente 392 esperou 0.0 na fila da atividade C
# Cliente 392 gastou 0.6517734987501171 na atividade C
# Cliente 393 esperou 0.0 na fila da atividade C
# Cliente 393 gastou 0.8752895174898185 na atividade C
# Cliente 394 esperou 0.0 na fila da atividade C
# Cliente 394 gastou 5.406958009592017 na atividade C
# Cliente 395 esperou 0.0 na fila da atividade C
# Cliente 395 gastou 1.5073719282204365 na atividade C
# Cliente 396 esperou 0.0 na fila da atividade C
# Cliente 396 gastou 1.8300620386994524 na atividade C
# Cliente 397 esperou 0.0 na fila da atividade C
# Cliente 397 gastou 0.44170026034134935 na atividade C
# Cliente 398 esperou 0.0 na fila da atividade C
# Cliente 398 gastou 1.749821907079422 na atividade C
# Cliente 399 esperou 0.0 na fila da atividade C
# Cliente 399 gastou 8.641154916123014 na atividade C
# Cliente 400 esperou 0.6411549161230141 na fila da atividade C
# Cliente 400 gastou 2.6043914187939663 na atividade C
# Cliente 401 esperou 0.0 na fila da atividade C
# Cliente 401 gastou 1.309055785680357 na atividade C
# Cliente 402 esperou 0.0 na fila da atividade C
# Cliente 402 gastou 27.585400959561866 na atividade C
# Cliente 403 esperou 19.585400959561866 na fila da atividade C
# Cliente 403 gastou 19.54473266455898 na atividade C
# Cliente 404 esperou 31.130133624120845 na fila da atividade C
# Cliente 404 gastou 3.3874974484515405 na atividade C
# Cliente 405 esperou 26.517631072572385 na fila da atividade C
# Cliente 405 gastou 0.06470266800261015 na atividade C
# Cliente 406 esperou 18.582333740574995 na fila da atividade C
# Cliente 406 gastou 2.7346235617847015 na atividade C
# Cliente 407 esperou 13.316957302359697 na fila da atividade C
# Cliente 407 gastou 0.40355455021699527 na atividade C
# Cliente 408 esperou 5.720511852576692 na fila da atividade C
# Cliente 408 gastou 1.6496595717098899 na atividade C
# Cliente 409 esperou 0.0 na fila da atividade C
# Cliente 409 gastou 2.363642048323527 na atividade C
# Cliente 410 esperou 0.0 na fila da atividade C
# Cliente 410 gastou 5.964442078883621 na atividade C
# Cliente 411 esperou 0.0 na fila da atividade C
# Cliente 411 gastou 3.6895187492209516 na atividade C
# Cliente 412 esperou 0.0 na fila da atividade C
# Cliente 412 gastou 5.9464964161247735 na atividade C
# Cliente 413 esperou 0.0 na fila da atividade C
# Cliente 413 gastou 8.401153462173625 na atividade C
# Cliente 414 esperou 0.4011534621736246 na fila da atividade C
# Cliente 414 gastou 5.219520536344135 na atividade C
# Cliente 415 esperou 0.0 na fila da atividade C
# Cliente 415 gastou 26.15310257834153 na atividade C
# Cliente 416 esperou 18.15310257834153 na fila da atividade C
# Cliente 416 gastou 3.070260581997445 na atividade C
# Cliente 417 esperou 13.223363160338977 na fila da atividade C
# Cliente 417 gastou 4.761151004038311 na atividade C
# Cliente 418 esperou 9.984514164377288 na fila da atividade C
# Cliente 418 gastou 2.0265129479516872 na atividade C
# Cliente 419 esperou 4.011027112328975 na fila da atividade C
# Cliente 419 gastou 7.498635689788443 na atividade C
# Cliente 420 esperou 3.5096628021174183 na fila da atividade C
# Cliente 420 gastou 7.015461075825442 na atividade C
# Cliente 421 esperou 2.5251238779428604 na fila da atividade C
# Cliente 421 gastou 2.9929232634212894 na atividade C
# Cliente 422 esperou 0.0 na fila da atividade C
# Cliente 422 gastou 2.7722785058940644 na atividade C
# Cliente 423 esperou 0.0 na fila da atividade C
# Cliente 423 gastou 4.789791003167011 na atividade C
# Cliente 424 esperou 0.0 na fila da atividade C
# Cliente 424 gastou 1.3385663227309124 na atividade C
# Cliente 425 esperou 0.0 na fila da atividade C
# Cliente 425 gastou 0.7566650262347139 na atividade C
# Cliente 426 esperou 0.0 na fila da atividade C
# Cliente 426 gastou 1.3984226435927667 na atividade C
# Cliente 427 esperou 0.0 na fila da atividade C
# Cliente 427 gastou 13.029603467039124 na atividade C
# Cliente 428 esperou 5.029603467039124 na fila da atividade C
# Cliente 428 gastou 2.556151292913455 na atividade C
# Cliente 429 esperou 0.0 na fila da atividade C
# Cliente 429 gastou 3.0129398506446705 na atividade C
# Cliente 430 esperou 0.0 na fila da atividade C
# Cliente 430 gastou 6.818010409620911 na atividade C
# Cliente 431 esperou 0.0 na fila da atividade C
# Cliente 431 gastou 8.900217156994586 na atividade C
# Cliente 432 esperou 0.9002171569945858 na fila da atividade C
# Cliente 432 gastou 1.4099883886838143 na atividade C
# Cliente 433 esperou 0.0 na fila da atividade C
# Cliente 433 gastou 7.107603291497071 na atividade C
# Cliente 434 esperou 0.0 na fila da atividade C
# Cliente 434 gastou 14.829633954404017 na atividade C
# Cliente 435 esperou 6.8296339544040165 na fila da atividade C
# Cliente 435 gastou 4.611007476159102 na atividade C
# Cliente 436 esperou 3.4406414305631188 na fila da atividade C
# Cliente 436 gastou 3.1246660599531424 na atividade C
# Cliente 437 esperou 0.0 na fila da atividade C
# Cliente 437 gastou 10.24929747956594 na atividade C
# Cliente 438 esperou 2.2492974795659393 na fila da atividade C
# Cliente 438 gastou 2.837600360689976 na atividade C
# Cliente 439 esperou 0.0 na fila da atividade C
# Cliente 439 gastou 2.0358492528603165 na atividade C
# Cliente 440 esperou 0.0 na fila da atividade C
# Cliente 440 gastou 8.812766027540874 na atividade C
# Cliente 441 esperou 0.8127660275408743 na fila da atividade C
# Cliente 441 gastou 3.936436884977411 na atividade C
# Cliente 442 esperou 0.0 na fila da atividade C
# Cliente 442 gastou 0.3393253874178299 na atividade C
# Cliente 443 esperou 0.0 na fila da atividade C
# Cliente 443 gastou 13.232438808349798 na atividade C
# Cliente 444 esperou 5.232438808349798 na fila da atividade C
# Cliente 444 gastou 0.40399639646284413 na atividade C
# Cliente 445 esperou 0.0 na fila da atividade C
# Cliente 445 gastou 1.98223065277989 na atividade C
# Cliente 446 esperou 0.0 na fila da atividade C
# Cliente 446 gastou 3.0232709902984425 na atividade C
# Cliente 447 esperou 0.0 na fila da atividade C
# Cliente 447 gastou 2.3895385281944073 na atividade C
# Cliente 448 esperou 0.0 na fila da atividade C
# Cliente 448 gastou 1.3451467624245197 na atividade C
# Cliente 449 esperou 0.0 na fila da atividade C
# Cliente 449 gastou 1.3408468095290118 na atividade C
# Cliente 450 esperou 0.0 na fila da atividade C
# Cliente 450 gastou 2.5538451002921647 na atividade C
# Cliente 451 esperou 0.0 na fila da atividade C
# Cliente 451 gastou 1.4544258819728384 na atividade C
# Cliente 452 esperou 0.0 na fila da atividade C
# Cliente 452 gastou 2.956636082197747 na atividade C
# Cliente 453 esperou 0.0 na fila da atividade C
# Cliente 453 gastou 12.434032689397554 na atividade C
# Cliente 454 esperou 4.434032689397554 na fila da atividade C
# Cliente 454 gastou 0.12512486003515733 na atividade C
# Cliente 455 esperou 0.0 na fila da atividade C
# Cliente 455 gastou 3.9626900506746097 na atividade C
# Cliente 456 esperou 0.0 na fila da atividade C
# Cliente 456 gastou 1.0237442746547458 na atividade C
# Cliente 457 esperou 0.0 na fila da atividade C
# Cliente 457 gastou 0.10219904600944574 na atividade C
# Cliente 458 esperou 0.0 na fila da atividade C
# Cliente 458 gastou 0.7843221037355761 na atividade C
# Cliente 459 esperou 0.0 na fila da atividade C
# Cliente 459 gastou 5.905852944161779 na atividade C
# Cliente 460 esperou 0.0 na fila da atividade C
# Cliente 460 gastou 3.2974086413250916 na atividade C
# Cliente 461 esperou 0.0 na fila da atividade C
# Cliente 461 gastou 5.226669403964479 na atividade C
# Cliente 462 esperou 0.0 na fila da atividade C
# ...
# Cliente 7349 gastou 0.07147632660053205 na atividade C
# Cliente 7350 esperou 0.0 na fila da atividade C
# Cliente 7350 gastou 6.135050533222966 na atividade C
# Cliente 7351 esperou 0.0 na fila da atividade C
# Cliente 7351 gastou 16.857706157337816 na atividade C
# Cliente 7352 esperou 8.857706157337816 na fila da atividade C
# Cliente 7352 gastou 2.4922001203303807 na atividade C
# Cliente 7353 esperou 3.3499062776681967 na fila da atividade C
# Cliente 7353 gastou 3.7248302702137153 na atividade C
# Cliente 7354 esperou 0.0 na fila da atividade C
# Cliente 7354 gastou 3.8211680586537113 na atividade C
# Cliente 7355 esperou 0.0 na fila da atividade C
# Cliente 7355 gastou 1.1116725088722887 na atividade C
# Cliente 7356 esperou 0.0 na fila da atividade C
# Cliente 7356 gastou 3.5837307724214043 na atividade C
# Cliente 7357 esperou 0.0 na fila da atividade C
# Cliente 7357 gastou 4.008657855287311 na atividade C
# Cliente 7358 esperou 0.0 na fila da atividade C
# Cliente 7358 gastou 2.9610350149378064 na atividade C
# Cliente 7359 esperou 0.0 na fila da atividade C
# Cliente 7359 gastou 12.44901993995154 na atividade C
# Cliente 7360 esperou 4.44901993995154 na fila da atividade C
# Cliente 7360 gastou 8.409541693865322 na atividade C
# Cliente 7361 esperou 4.858561633816862 na fila da atividade C
# Cliente 7361 gastou 0.2186798424081644 na atividade C
# Cliente 7362 esperou 0.0 na fila da atividade C
# Cliente 7362 gastou 11.94836731092073 na atividade C
# Cliente 7363 esperou 3.9483673109207302 na fila da atividade C
# Cliente 7363 gastou 25.238680548412958 na atividade C
# Cliente 7364 esperou 21.18704785933369 na fila da atividade C
# Cliente 7364 gastou 13.16006168081367 na atividade C
# Cliente 7365 esperou 26.347109540147358 na fila da atividade C
# Cliente 7365 gastou 1.0420601362056914 na atividade C
# Cliente 7366 esperou 19.38916967635305 na fila da atividade C
# Cliente 7366 gastou 5.670753291218716 na atividade C
# Cliente 7367 esperou 17.059922967571765 na fila da atividade C
# Cliente 7367 gastou 4.009063884579518 na atividade C
# Cliente 7368 esperou 13.068986852151284 na fila da atividade C
# Cliente 7368 gastou 3.1220310178468935 na atividade C
# Cliente 7369 esperou 8.191017869998177 na fila da atividade C
# Cliente 7369 gastou 2.8324381804995937 na atividade C
# Cliente 7370 esperou 3.0234560504977708 na fila da atividade C
# Cliente 7370 gastou 11.94697615892801 na atividade C
# Cliente 7371 esperou 6.9704322094257805 na fila da atividade C
# Cliente 7371 gastou 14.401234629294777 na atividade C
# Cliente 7372 esperou 13.371666838720557 na fila da atividade C
# Cliente 7372 gastou 0.7128706466464791 na atividade C
# Cliente 7373 esperou 6.084537485367036 na fila da atividade C
# Cliente 7373 gastou 2.843541216403537 na atividade C
# Cliente 7374 esperou 0.9280787017705734 na fila da atividade C
# Cliente 7374 gastou 6.656881129318208 na atividade C
# Cliente 7375 esperou 0.0 na fila da atividade C
# Cliente 7375 gastou 1.1947488931764383 na atividade C
# Cliente 7376 esperou 0.0 na fila da atividade C
# Cliente 7376 gastou 6.919058532163035 na atividade C
# Cliente 7377 esperou 0.0 na fila da atividade C
# Cliente 7377 gastou 5.0555651209142525 na atividade C
# Cliente 7378 esperou 0.0 na fila da atividade C
# Cliente 7378 gastou 4.984904180142621 na atividade C
# Cliente 7379 esperou 0.0 na fila da atividade C
# Cliente 7379 gastou 2.0679398462816607 na atividade C
# Cliente 7380 esperou 0.0 na fila da atividade C
# Cliente 7380 gastou 0.03422331643378129 na atividade C
# Cliente 7381 esperou 0.0 na fila da atividade C
# Cliente 7381 gastou 0.4892601250758162 na atividade C
# Cliente 7382 esperou 0.0 na fila da atividade C
# Cliente 7382 gastou 8.817674614387215 na atividade C
# Cliente 7383 esperou 0.8176746143872151 na fila da atividade C
# Cliente 7383 gastou 6.658141513245937 na atividade C
# Cliente 7384 esperou 0.0 na fila da atividade C
# Cliente 7384 gastou 6.950440405140398 na atividade C
# Cliente 7385 esperou 0.0 na fila da atividade C
# Cliente 7385 gastou 14.010461315730936 na atividade C
# Cliente 7386 esperou 6.010461315730936 na fila da atividade C
# Cliente 7386 gastou 1.665519508831494 na atividade C
# Cliente 7387 esperou 0.0 na fila da atividade C
# Cliente 7387 gastou 4.022391202954168 na atividade C
# Cliente 7388 esperou 0.0 na fila da atividade C
# Cliente 7388 gastou 3.662041851122922 na atividade C
# Cliente 7389 esperou 0.0 na fila da atividade C
# Cliente 7389 gastou 11.192247947561555 na atividade C
# Cliente 7390 esperou 3.1922479475615546 na fila da atividade C
# Cliente 7390 gastou 4.197223513416247 na atividade C
# Cliente 7391 esperou 0.0 na fila da atividade C
# Cliente 7391 gastou 0.07480562271666713 na atividade C
# Cliente 7392 esperou 0.0 na fila da atividade C
# Cliente 7392 gastou 2.9084230976659455 na atividade C
# Cliente 7393 esperou 0.0 na fila da atividade C
# Cliente 7393 gastou 3.244256218604278 na atividade C
# Cliente 7394 esperou 0.0 na fila da atividade C
# Cliente 7394 gastou 2.1959443251398625 na atividade C
# Cliente 7395 esperou 0.0 na fila da atividade C
# Cliente 7395 gastou 1.2276112330509932 na atividade C
# Cliente 7396 esperou 0.0 na fila da atividade C
# Cliente 7396 gastou 0.687931541026046 na atividade C
# Cliente 7397 esperou 0.0 na fila da atividade C
# Cliente 7397 gastou 4.048187680600677 na atividade C
# Cliente 7398 esperou 0.0 na fila da atividade C
# Cliente 7398 gastou 10.836452057097631 na atividade C
# Cliente 7399 esperou 2.836452057097631 na fila da atividade C
# Cliente 7399 gastou 7.662091119083925 na atividade C
# Cliente 7400 esperou 2.498543176181556 na fila da atividade C
# Cliente 7400 gastou 12.442380881700956 na atividade C
# Cliente 7401 esperou 6.940924057882512 na fila da atividade C
# Cliente 7401 gastou 6.308190606272547 na atividade C
# Cliente 7402 esperou 5.249114664155059 na fila da atividade C
# Cliente 7402 gastou 3.3582147910710773 na atividade C
# Cliente 7403 esperou 0.6073294552261359 na fila da atividade C
# Cliente 7403 gastou 4.63244590551767 na atividade C
# Cliente 7404 esperou 0.0 na fila da atividade C
# Cliente 7404 gastou 6.6397337439411785 na atividade C
# Cliente 7405 esperou 0.0 na fila da atividade C
# Cliente 7405 gastou 0.5333546987094451 na atividade C
# Cliente 7406 esperou 0.0 na fila da atividade C
# Cliente 7406 gastou 0.3449195957146003 na atividade C
# Cliente 7407 esperou 0.0 na fila da atividade C
# Cliente 7407 gastou 1.1493754192561028 na atividade C
# Cliente 7408 esperou 0.0 na fila da atividade C
# Cliente 7408 gastou 2.4117554279000615 na atividade C
# Cliente 7409 esperou 0.0 na fila da atividade C
# Cliente 7409 gastou 4.668331368426152 na atividade C
# Cliente 7410 esperou 0.0 na fila da atividade C
# Cliente 7410 gastou 3.786917373421602 na atividade C
# Cliente 7411 esperou 0.0 na fila da atividade C
# Cliente 7411 gastou 1.302906237600837 na atividade C
# Cliente 7412 esperou 0.0 na fila da atividade C
# Cliente 7412 gastou 0.5491314510290977 na atividade C
# Cliente 7413 esperou 0.0 na fila da atividade C
# Cliente 7413 gastou 1.5754311218843213 na atividade C
# Cliente 7414 esperou 0.0 na fila da atividade C
# Cliente 7414 gastou 1.3047738706954988 na atividade C
# Cliente 7415 esperou 0.0 na fila da atividade C
# Cliente 7415 gastou 3.663056825113017 na atividade C
# Cliente 7416 esperou 0.0 na fila da atividade C
# Cliente 7416 gastou 5.454487493989291 na atividade C
# Cliente 7417 esperou 0.0 na fila da atividade C
# Cliente 7417 gastou 1.2932817816763418 na atividade C
# Cliente 7418 esperou 0.0 na fila da atividade C
# Cliente 7418 gastou 2.880226110733929 na atividade C
# Cliente 7419 esperou 0.0 na fila da atividade C
# Cliente 7419 gastou 4.499613580905134 na atividade C
# Cliente 7420 esperou 0.0 na fila da atividade C
# Cliente 7420 gastou 14.662934046122245 na atividade C
# Cliente 7421 esperou 6.6629340461222455 na fila da atividade C
# Cliente 7421 gastou 14.562536959332647 na atividade C
# Cliente 7422 esperou 13.225471005454892 na fila da atividade C
# Cliente 7422 gastou 2.9855919611727586 na atividade C
# Cliente 7423 esperou 8.211062966627651 na fila da atividade C
# Cliente 7423 gastou 0.30011384680256015 na atividade C
# Cliente 7424 esperou 0.511176813430211 na fila da atividade C
# Cliente 7424 gastou 12.549573224649066 na atividade C
# Cliente 7425 esperou 5.060750038079277 na fila da atividade C
# Cliente 7425 gastou 9.168579285578744 na atividade C
# Cliente 7426 esperou 6.229329323658021 na fila da atividade C
# Cliente 7426 gastou 0.8737731538858498 na atividade C
# Cliente 7427 esperou 0.0 na fila da atividade C
# Cliente 7427 gastou 1.3018469258095138 na atividade C
# Cliente 7428 esperou 0.0 na fila da atividade C
# Cliente 7428 gastou 2.155312231530843 na atividade C
# Cliente 7429 esperou 0.0 na fila da atividade C
# Cliente 7429 gastou 5.408502573191072 na atividade C
# Cliente 7430 esperou 0.0 na fila da atividade C
# Cliente 7430 gastou 1.5619763422146207 na atividade C
# Cliente 7431 esperou 0.0 na fila da atividade C
# Cliente 7431 gastou 12.103665287322656 na atividade C
# Cliente 7432 esperou 4.103665287322656 na fila da atividade C
# Cliente 7432 gastou 8.318650753462862 na atividade C
# Cliente 7433 esperou 4.4223160407855175 na fila da atividade C
# Cliente 7433 gastou 4.310729543598427 na atividade C
# Cliente 7434 esperou 0.7330455843839445 na fila da atividade C
# Cliente 7434 gastou 2.8623394173337147 na atividade C
# Cliente 7435 esperou 0.0 na fila da atividade C
# Cliente 7435 gastou 1.0216426098704687 na atividade C
# Cliente 7436 esperou 0.0 na fila da atividade C
# Cliente 7436 gastou 16.679256520495983 na atividade C
# Cliente 7437 esperou 8.679256520495983 na fila da atividade C
# Cliente 7437 gastou 1.405382156241103 na atividade C
# Cliente 7438 esperou 2.084638676737086 na fila da atividade C
# Cliente 7438 gastou 6.942948344025353 na atividade C
# Cliente 7439 esperou 1.0275870207624394 na fila da atividade C
# Cliente 7439 gastou 4.964993273279106 na atividade C
# Cliente 7440 esperou 0.0 na fila da atividade C
# Cliente 7440 gastou 7.022988383512711 na atividade C
# Cliente 7441 esperou 0.0 na fila da atividade C
# Cliente 7441 gastou 1.6526279532627086 na atividade C
# Cliente 7442 esperou 0.0 na fila da atividade C
# Cliente 7442 gastou 2.0256015200793627 na atividade C
# Cliente 7443 esperou 0.0 na fila da atividade C
# Cliente 7443 gastou 1.4740681877738098 na atividade C
# Cliente 7444 esperou 0.0 na fila da atividade C
# Cliente 7444 gastou 1.9948129248514306 na atividade C
# Cliente 7445 esperou 0.0 na fila da atividade C
# Cliente 7445 gastou 1.492473474376311 na atividade C
# Cliente 7446 esperou 0.0 na fila da atividade C
# Cliente 7446 gastou 8.854812136822147 na atividade C
# Cliente 7447 esperou 0.8548121368221473 na fila da atividade C
# Cliente 7447 gastou 4.257263954743394 na atividade C
# Cliente 7448 esperou 0.0 na fila da atividade C
# Cliente 7448 gastou 5.682681168829731 na atividade C
# Cliente 7449 esperou 0.0 na fila da atividade C
# Cliente 7449 gastou 4.965870945386996 na atividade C
# Cliente 7450 esperou 0.0 na fila da atividade C
# Cliente 7450 gastou 0.7896658011813997 na atividade C
# Cliente 7451 esperou 0.0 na fila da atividade C
# Cliente 7451 gastou 14.175791694084182 na atividade C
# Cliente 7452 esperou 6.175791694084182 na fila da atividade C
# Cliente 7452 gastou 12.489667893387377 na atividade C
# Cliente 7453 esperou 10.66545958747156 na fila da atividade C
# Cliente 7453 gastou 0.42242293152958155 na atividade C
# Cliente 7454 esperou 3.087882519001141 na fila da atividade C
# Cliente 7454 gastou 2.2218654295793385 na atividade C
# Cliente 7455 esperou 0.0 na fila da atividade C
# Cliente 7455 gastou 10.097493756868062 na atividade C
# Cliente 7456 esperou 2.0974937568680616 na fila da atividade C
# Cliente 7456 gastou 0.4016506110710907 na atividade C
# Cliente 7457 esperou 0.0 na fila da atividade C
# Cliente 7457 gastou 2.867752929829294 na atividade C
# Cliente 7458 esperou 0.0 na fila da atividade C
# Cliente 7458 gastou 5.853736068995204 na atividade C
# Cliente 7459 esperou 0.0 na fila da atividade C
# Cliente 7459 gastou 1.9228194165116292 na atividade C
# Cliente 7460 esperou 0.0 na fila da atividade C
# Cliente 7460 gastou 7.551963881291158 na atividade C
# Cliente 7461 esperou 0.0 na fila da atividade C
# Cliente 7461 gastou 0.6437387561236392 na atividade C
# Cliente 7462 esperou 0.0 na fila da atividade C
# Cliente 7462 gastou 6.083038176053378 na atividade C
# Cliente 7463 esperou 0.0 na fila da atividade C
# Cliente 7463 gastou 4.795476789222448 na atividade C
# Cliente 7464 esperou 0.0 na fila da atividade C
# Cliente 7464 gastou 7.231620181890321 na atividade C
# Cliente 7465 esperou 0.0 na fila da atividade C
# Cliente 7465 gastou 3.7188458781820373 na atividade C
# Cliente 7466 esperou 0.0 na fila da atividade C
# Cliente 7466 gastou 6.959735290445678 na atividade C
# Cliente 7467 esperou 0.0 na fila da atividade C
# Cliente 7467 gastou 0.24810797323152656 na atividade C
# Cliente 7468 esperou 0.0 na fila da atividade C
# Cliente 7468 gastou 24.9877710519213 na atividade C
# Cliente 7469 esperou 16.9877710519213 na fila da atividade C
# Cliente 7469 gastou 5.733662004095095 na atividade C
# Cliente 7470 esperou 14.721433056016394 na fila da atividade C
# Cliente 7470 gastou 12.05776848354435 na atividade C
# Cliente 7471 esperou 18.779201539560745 na fila da atividade C
# Cliente 7471 gastou 4.150411776943656 na atividade C
# Cliente 7472 esperou 14.929613316504401 na fila da atividade C
# Cliente 7472 gastou 4.199969240013161 na atividade C
# Cliente 7473 esperou 11.129582556517562 na fila da atividade C
# Cliente 7473 gastou 0.6391678600630257 na atividade C
# Cliente 7474 esperou 3.7687504165805876 na fila da atividade C
# Cliente 7474 gastou 1.8126918679117807 na atividade C
# Cliente 7475 esperou 0.0 na fila da atividade C
# Cliente 7475 gastou 4.3445162642528885 na atividade C
# Cliente 7476 esperou 0.0 na fila da atividade C
# Cliente 7476 gastou 26.421645226408145 na atividade C
# Cliente 7477 esperou 18.421645226408145 na fila da atividade C
# Cliente 7477 gastou 0.5829636860653409 na atividade C
# Cliente 7478 esperou 11.004608912473486 na fila da atividade C
# Cliente 7478 gastou 1.6370086703827837 na atividade C
# Cliente 7479 esperou 4.64161758285627 na fila da atividade C
# Cliente 7479 gastou 1.3971863118640613 na atividade C
# Cliente 7480 esperou 0.0 na fila da atividade C
# Cliente 7480 gastou 1.3979417499067495 na atividade C
# Cliente 7481 esperou 0.0 na fila da atividade C
# Cliente 7481 gastou 10.80413690918067 na atividade C
# Cliente 7482 esperou 2.80413690918067 na fila da atividade C
# Cliente 7482 gastou 2.2727928844615235 na atividade C
# Cliente 7483 esperou 0.0 na fila da atividade C
# Cliente 7483 gastou 11.240893109657918 na atividade C
# Cliente 7484 esperou 3.240893109657918 na fila da atividade C
# Cliente 7484 gastou 1.5999828702915693 na atividade C
# Cliente 7485 esperou 0.0 na fila da atividade C
# Cliente 7485 gastou 0.8194690264499513 na atividade C
# Cliente 7486 esperou 0.0 na fila da atividade C
# Cliente 7486 gastou 5.557764400371525 na atividade C
# Cliente 7487 esperou 0.0 na fila da atividade C
# Cliente 7487 gastou 5.947023120999802 na atividade C
# Cliente 7488 esperou 0.0 na fila da atividade C
# Cliente 7488 gastou 2.3806469583214493 na atividade C
# Cliente 7489 esperou 0.0 na fila da atividade C
# Cliente 7489 gastou 5.12109674718522 na atividade C
# Cliente 7490 esperou 0.0 na fila da atividade C
# Cliente 7490 gastou 8.249335233114834 na atividade C
# Cliente 7491 esperou 0.2493352331148344 na fila da atividade C
# Cliente 7491 gastou 3.5349683987515164 na atividade C
# Cliente 7492 esperou 0.0 na fila da atividade C
# Cliente 7492 gastou 10.510332595134969 na atividade C
# Cliente 7493 esperou 2.510332595134969 na fila da atividade C
# Cliente 7493 gastou 1.1822912660427392 na atividade C
# Cliente 7494 esperou 0.0 na fila da atividade C
# Cliente 7494 gastou 6.880956246670394 na atividade C
# Cliente 7495 esperou 0.0 na fila da atividade C
# Cliente 7495 gastou 1.085520231143164 na atividade C
# Cliente 7496 esperou 0.0 na fila da atividade C
# Cliente 7496 gastou 5.236261880520033 na atividade C
# Cliente 7497 esperou 0.0 na fila da atividade C
# Cliente 7497 gastou 0.11853911400976358 na atividade C
# Cliente 7498 esperou 0.0 na fila da atividade C
# Cliente 7498 gastou 2.286896338999213 na atividade C

# %%
import numpy as np

print(f"Em média, um cliente o serviço C dura {np.mean(tempo_gasto_C)} minutos")
print(f"Em média, um cliente espera {np.mean(tempo_esperando_C)} minutos pelo serviço C")
# Out:
# Em média, um cliente o serviço C dura 5.019555734043165 minutos
# Em média, um cliente espera 2.8508108161566366 minutos pelo serviço C

# %% [markdown]
# # Exercício Prático 2

# %% [markdown]
# ### Modelo M/M/1
#
# Vamos modelar um sistema faz parte do curso de Pesquisa Operacional III, o sistema de filas M/M/1.
#
# - Taxa de chegadas $\lambda = 0,5$
# - Taxa de atendimento $\mu = 1$
#
# Guarde o valor do tempo de espera em fila e do tempo no sistema (tempo de ciclo).
#
# Simule por 60000 minutos.
#
# Os resultados batem com o esperado? Faça os cálculos com as fórmulas clássicas de Teoria das Filas?

# %%
def fila_MM1 (env, nome, atendente):
    pass
