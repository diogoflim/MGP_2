# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/diogoflim/MGP/blob/main/modelagem_1.ipynb)

# %% [markdown]
# # Modelagem e Gestão de Processos
#
#
# **Prof. Diogo Ferreira de Lima Silva (TEP-UFF)**
#
# **Modelagem de Processos no SimPy**

# %% [markdown]
# # SimPy
#
# A biblioteca SimPy apresenta um framework útil para simular o funcionamento de processos em Python.
#
# O usuário ganha grande liberdade para modelar processos específicos de sua organização.
#
# Além disso, pode integrar ao modelo as inúmeras bibliotecas existentes em python para Estatística, Ciência de Dados, Aprendeizado de Máquina, Otimização, etc.

# %% [markdown]
# ## Importando o SimPy
#
# Se estiver trabalhando localmente, uma vez instalado o Python, você deverá instalar a biblioteca SimPy antes de importá-la.
#
# - Isso pode ser feito com o comando: **pip install simpy**
#
# No caso do Googlo Colab: **!pip install simpy**
#
# Uma vez instalada, podemos importar a biblioteca normalmente simplesmente com: **import simpy**.

# %%
#!pip install simpy
import simpy

# %% [markdown]
# Além do SimPy, vamos importar a biblioteca random para usar suas distribuições de probabilidades.

# %%
import random

# Seu computador não gera números verdadeiramente aleatórios, mas sim, pseudoaleatórios.
# Vamos "travar" a semente de geração desses números. Assim, resultados poderão ser reproduzidos no futuro.
random.seed(10)

# %% [markdown]
# # Um exemplo simples: Pomodoro
#
# Com o intuito de aumentar sua produtividade, um estudante/trabalhador resolve seguir a recomendação de uma colega sobre a metodologia Pomodoro.
#
# - Ele fará alternadamente intervalos de trabalho e pausa (descanso, café, água, banheiro) durante o dia.
#
#     - O tempo até a próxima parada para descanso (tempo de trabalho) segue uma distribuição uniforme que varia entre 24 e 26 minutos.
#     - As pausas seguem uma exponencial de média 5 minutos.
#
# Vamos modelar o funcionamento desse processo por 8 horas de trabalho e imprimir em nossa tela sempre que um evento (pausa ou trabalho) for iniciado.

# %% [markdown]
# ## Criando um ambiente de simulação
#
#
# O primeiro passo será criar um ambiente (environment) no SimPy.

# %%
# Criando uma instância de ambiente do simpy e armazenando em env

env = simpy.Environment()

# %% [markdown]
# Nosso processo possui duas atividades (subprocessos): **trabalhar** e **descansar**.
#
# A próxima etapa é criar um **generator** (tipo especial de função) para simular o funcionamento dessas atividades.

# %% [markdown]
# ### Modelando o Processo

# %%
# Criaremos um gerador de nome pomodoro 

def pomodoro ():
    pass

# %% [markdown]
# Por enquanto, não passamos nada para nosso gerador.
#
# Os parâmetros que ele irá receber devem incluir o ambiente criado no simpy.
#
# Vamos também passar como parâmetro o nome do colaborador.

# %%
def Pomodoro (env, nome):
    pass

# %% [markdown]
# Agora, podemos trabalhar nas atividades que farão parte do nosso processo: **trabalhar** e **descansar**.
#
# Para isso, usaremos o **yield** e os métodos **now** e **timeout** do simpy.
#
# - O **yield** é usado em uma função geradora (em detrimento do return numa função normal). No caso do yield, guardamos um iterador (no nosso caso será o tempo de início de cada evento) que poderá ser retomado no futuro.
#
# - O método **now** do SimPy retorna o tempo de simulação no nosso ambiente enquanto o **timeout** avisa à simulação para percorrer um tempo.

# %%
def pomodoro (env, nome):
    
    # enquanto a simulação estiver ocorrendo
    while True:
        
        # imprima na tela o tempo de início do evento e depois percorra um tempo random.uniform(24, 26)
        print (f"{nome} inicia trabalho no tempo {env.now}")
        yield env.timeout(random.uniform(24,26))

        # imprima na tela o tempo de início do evento e depois percorra um tempo random.expovariate(1/média)
        print (f"{nome} inicia descanso no tempo {env.now}")
        yield env.timeout(random.expovariate(1/5))

# %% [markdown]
# Nosso gerador ainda não é visto como um processo do nosso environment no SimPy.
#
# O próximo passo é instanciar nosso processo com o método simpy.Environment.process. No nosso caso, fica simplesmente **env.process**.

# %%
# Instância do processo
env.process(pomodoro(env, "Will_Smith"))
# Out:
# <Process(pomodoro) object at 0x17511a9ea90>

# %% [markdown]
# Agora, vamos rodar o nosso processo até o minuto 480, ou seja, simularemos 8h de trabalho.

# %%
env.run (until = 480)
# Out:
# Will_Smith inicia trabalho no tempo 0
# Will_Smith inicia descanso no tempo 25.14280518937983
# Will_Smith inicia trabalho no tempo 27.943664130161597
# Will_Smith inicia descanso no tempo 53.099846732430535
# Will_Smith inicia trabalho no tempo 54.253824449673225
# Will_Smith inicia descanso no tempo 79.88046695238786
# Will_Smith inicia trabalho no tempo 88.55515723500187
# Will_Smith inicia descanso no tempo 113.86210230280423
# Will_Smith inicia trabalho no tempo 114.7352358331193
# Will_Smith inicia descanso no tempo 139.77657455239915
# Will_Smith inicia trabalho no tempo 141.76236914065487
# Will_Smith inicia descanso no tempo 166.26236249402768
# Will_Smith inicia trabalho no tempo 181.53096096998934
# Will_Smith inicia descanso no tempo 207.52407495506824
# Will_Smith inicia trabalho no tempo 207.75197258188612
# Will_Smith inicia descanso no tempo 233.4722946564587
# Will_Smith inicia trabalho no tempo 238.09379086634283
# Will_Smith inicia descanso no tempo 262.8570028381811
# Will_Smith inicia trabalho no tempo 264.5247130327617
# Will_Smith inicia descanso no tempo 289.87464272703164
# Will_Smith inicia trabalho no tempo 292.9263179854875
# Will_Smith inicia descanso no tempo 318.2980409564367
# Will_Smith inicia trabalho no tempo 323.7193150185911
# Will_Smith inicia descanso no tempo 347.9852713080155
# Will_Smith inicia trabalho no tempo 355.28686667666193
# Will_Smith inicia descanso no tempo 381.2516931746843
# Will_Smith inicia trabalho no tempo 398.6835353246049
# Will_Smith inicia descanso no tempo 423.91018896569835
# Will_Smith inicia trabalho no tempo 424.13653912379897
# Will_Smith inicia descanso no tempo 448.14464941211577
# Will_Smith inicia trabalho no tempo 448.86384264692157
# Will_Smith inicia descanso no tempo 474.74584718971323
# Will_Smith inicia trabalho no tempo 476.54969635847414

# %% [markdown]
# # Modelando um Processo com Várias Atividades

# %% [markdown]
# Agora vamos modelar um processo um pouco mais complexo. Teremos chegadas de clientes em um serviço composto por três atividades: A, B e C.
#
# -  Processo inicializa a cada chegada de um cliente. O tempo entre chegadas segue uma distribuição Exponencial com média de 5 minutos.
# - Cada cliente segue o seguinte percurso:
#     - Serviço A (tempo de processamento 3 min)
#     - Serviço B (tempo de processamento de 8 min)
#     - Serviço C (tempo de processamento segue uma distribuição exponencial com média 5min)

# %% [markdown]
# Para a realização dos serviços, precisamos de recursos. Por exemplo, atendentes, caixas, etc.
#
# Chamaremos os recursos de:
#
# - colaborador_A
# - colaborador_B
# - colaborador_C
#
# Para isso, utilizaremos **recursos** do SimPy, criados com **resource_name = env.Resource (env, capacity)**.

# %% [markdown]
# Um cliente deve esperar até que o recurso esteja disponível. Para modelar isso, usaremos o **resource_name.request()**

# %% [markdown]
# ### Função Geradora

# %%
# Função geradora receberá, além do ambiente e do nome do cliente, os recursos.

def salao (env, nome, colaborador_A, colaborador_B, colaborador_C):
    
    # imprimimos na tela quando um cliente chega no estabelecimento       
    print (f"{nome} chega no estabelecimento em {env.now}")
    
    # Serviço A
    # Ao chegar, o cliente deve esperar o recurso do primeiro serviso

    with colaborador_A.request() as req_A:
        yield req_A # o cliente deve esperar um recurso do tipo colaborador_A
        print (f"{nome} inicia A em {env.now}") # imprima na tela o tempo de início
        yield env.timeout(3) # O serviço demora exatamente 3 minutos.
        print (f"{nome} finaliza A em {env.now}")

    
    # Serviço B
    with colab_B.request() as req_B:
        yield req_B
        print (f"{nome} inicia B em {env.now}")
        yield env.timeout(8) # O serviço B demora exatamente 8 minutos.
        print (f"{nome} finaliza B em {env.now}")
    
    # Serviço C
    with colab_C.request() as req_C:
        yield req_C
        print (f"{nome} inicia C em {env.now}")
        yield env.timeout(random.expovariate(1/5)) # O tempo de serviço em C segue uma exponencial de média 5.
    
    print (f"{nome} sai do estabelecimento em {env.now}")

# %% [markdown]
# ### Definindo o ambiente

# %%
env = simpy.Environment()

# %% [markdown]
# ### Instanciando os tipos de recurso em nosso ambiente e suas capacidades

# %%
colab_A = simpy.Resource(env, capacity=1)
colab_B = simpy.Resource(env, capacity=1)
colab_C = simpy.Resource(env, capacity=1)

# %% [markdown]
# ## Processo de Chegadas

# %% [markdown]
# Vamos considerar que o nosso processo de chegadas é um processo de Poisson, com $\lambda = 0,2$ clientes/minuto;
#
# Assim, o tempo entre chegadas segue uma distribuição exponencial de média $1/\lambda = 5$ minutos.
#
# Vamos criar nosso processo de chegadas:

# %%
def chegadas (env):
    i=1 # número que será usado na contagem e nomeação dos clientes
    
    # Enquanto a simulação ocorrer
    while True:
        # gere um número de nossa distribuição 
        yield env.timeout(random.expovariate(1/5))

        # Um cliente entra no processo! Seu nome será "Cliente i"
        env.process(salao (env, 'Cliente %d' % i, colab_A, colab_B, colab_C))
        
        i+=1 # i = i+1


# Instanciando o processo com a função de chegadas.
env.process(chegadas(env))
# Out:
# <Process(chegadas) object at 0x17512253d60>

# %% [markdown]
# Pronto, agora basta rodar nossa simulação.

# %%
env.run(until=480)
# Out:
# Cliente 1 chega no estabelecimento em 11.423541424842186
# Cliente 1 inicia A em 11.423541424842186
# Cliente 2 chega no estabelecimento em 13.310582024115678
# Cliente 1 finaliza A em 14.423541424842186
# Cliente 1 inicia B em 14.423541424842186
# Cliente 2 inicia A em 14.423541424842186
# Cliente 3 chega no estabelecimento em 17.291824208921966
# Cliente 2 finaliza A em 17.423541424842185
# Cliente 3 inicia A em 17.423541424842185
# Cliente 4 chega no estabelecimento em 20.155603800897108
# Cliente 3 finaliza A em 20.423541424842185
# Cliente 4 inicia A em 20.423541424842185
# Cliente 5 chega no estabelecimento em 20.49161640575467
# Cliente 1 finaliza B em 22.423541424842185
# Cliente 1 inicia C em 22.423541424842185
# Cliente 2 inicia B em 22.423541424842185
# Cliente 4 finaliza A em 23.423541424842185
# Cliente 5 inicia A em 23.423541424842185
# Cliente 6 chega no estabelecimento em 24.88353602610119
# Cliente 7 chega no estabelecimento em 25.73403230814252
# Cliente 5 finaliza A em 26.423541424842185
# Cliente 6 inicia A em 26.423541424842185
# Cliente 8 chega no estabelecimento em 27.003972817939367
# Cliente 6 finaliza A em 29.423541424842185
# Cliente 7 inicia A em 29.423541424842185
# Cliente 9 chega no estabelecimento em 29.666519679825335
# Cliente 10 chega no estabelecimento em 29.854638943000033
# Cliente 2 finaliza B em 30.423541424842185
# Cliente 3 inicia B em 30.423541424842185
# Cliente 1 sai do estabelecimento em 31.715214464342633
# Cliente 2 inicia C em 31.715214464342633
# Cliente 7 finaliza A em 32.423541424842185
# Cliente 8 inicia A em 32.423541424842185
# Cliente 11 chega no estabelecimento em 33.286524674391785
# Cliente 8 finaliza A em 35.423541424842185
# Cliente 9 inicia A em 35.423541424842185
# Cliente 3 finaliza B em 38.423541424842185
# Cliente 9 finaliza A em 38.423541424842185
# Cliente 4 inicia B em 38.423541424842185
# Cliente 10 inicia A em 38.423541424842185
# Cliente 12 chega no estabelecimento em 38.649653175580376
# Cliente 2 sai do estabelecimento em 40.23348668860151
# Cliente 3 inicia C em 40.23348668860151
# Cliente 10 finaliza A em 41.423541424842185
# Cliente 11 inicia A em 41.423541424842185
# Cliente 13 chega no estabelecimento em 42.46196514897144
# Cliente 14 chega no estabelecimento em 43.27272563274888
# Cliente 11 finaliza A em 44.423541424842185
# Cliente 12 inicia A em 44.423541424842185
# Cliente 4 finaliza B em 46.423541424842185
# Cliente 5 inicia B em 46.423541424842185
# Cliente 12 finaliza A em 47.423541424842185
# Cliente 13 inicia A em 47.423541424842185
# Cliente 15 chega no estabelecimento em 47.460533259652
# Cliente 16 chega no estabelecimento em 49.80395430195816
# Cliente 3 sai do estabelecimento em 49.89293214123484
# Cliente 4 inicia C em 49.89293214123484
# Cliente 13 finaliza A em 50.423541424842185
# Cliente 14 inicia A em 50.423541424842185
# Cliente 4 sai do estabelecimento em 50.492008460561074
# Cliente 14 finaliza A em 53.423541424842185
# Cliente 15 inicia A em 53.423541424842185
# Cliente 17 chega no estabelecimento em 54.40174144950678
# Cliente 5 finaliza B em 54.423541424842185
# Cliente 5 inicia C em 54.423541424842185
# Cliente 6 inicia B em 54.423541424842185
# Cliente 5 sai do estabelecimento em 54.93152298837021
# Cliente 15 finaliza A em 56.423541424842185
# Cliente 16 inicia A em 56.423541424842185
# Cliente 16 finaliza A em 59.423541424842185
# Cliente 17 inicia A em 59.423541424842185
# Cliente 18 chega no estabelecimento em 61.87142219118125
# Cliente 6 finaliza B em 62.423541424842185
# Cliente 17 finaliza A em 62.423541424842185
# Cliente 6 inicia C em 62.423541424842185
# Cliente 7 inicia B em 62.423541424842185
# Cliente 18 inicia A em 62.423541424842185
# Cliente 19 chega no estabelecimento em 62.78121278017028
# Cliente 18 finaliza A em 65.42354142484218
# Cliente 19 inicia A em 65.42354142484218
# Cliente 19 finaliza A em 68.42354142484218
# Cliente 7 finaliza B em 70.42354142484218
# Cliente 8 inicia B em 70.42354142484218
# Cliente 6 sai do estabelecimento em 70.66053207920952
# Cliente 7 inicia C em 70.66053207920952
# Cliente 7 sai do estabelecimento em 73.49955384106235
# Cliente 20 chega no estabelecimento em 77.5344264952887
# Cliente 20 inicia A em 77.5344264952887
# Cliente 8 finaliza B em 78.42354142484218
# Cliente 8 inicia C em 78.42354142484218
# Cliente 9 inicia B em 78.42354142484218
# Cliente 8 sai do estabelecimento em 79.83192132505813
# Cliente 21 chega no estabelecimento em 80.20729368057118
# Cliente 20 finaliza A em 80.5344264952887
# Cliente 21 inicia A em 80.5344264952887
# Cliente 22 chega no estabelecimento em 81.81316664687996
# Cliente 21 finaliza A em 83.5344264952887
# Cliente 22 inicia A em 83.5344264952887
# Cliente 9 finaliza B em 86.42354142484218
# Cliente 9 inicia C em 86.42354142484218
# Cliente 10 inicia B em 86.42354142484218
# Cliente 22 finaliza A em 86.5344264952887
# Cliente 23 chega no estabelecimento em 86.61506906745826
# Cliente 23 inicia A em 86.61506906745826
# Cliente 24 chega no estabelecimento em 87.2512964729125
# Cliente 9 sai do estabelecimento em 87.40641718090325
# Cliente 23 finaliza A em 89.61506906745826
# Cliente 24 inicia A em 89.61506906745826
# Cliente 25 chega no estabelecimento em 90.29289026657608
# Cliente 26 chega no estabelecimento em 91.19413563541032
# Cliente 24 finaliza A em 92.61506906745826
# Cliente 25 inicia A em 92.61506906745826
# Cliente 10 finaliza B em 94.42354142484218
# Cliente 10 inicia C em 94.42354142484218
# Cliente 11 inicia B em 94.42354142484218
# Cliente 25 finaliza A em 95.61506906745826
# Cliente 26 inicia A em 95.61506906745826
# Cliente 27 chega no estabelecimento em 96.42506266541457
# Cliente 26 finaliza A em 98.61506906745826
# Cliente 27 inicia A em 98.61506906745826
# Cliente 27 finaliza A em 101.61506906745826
# Cliente 11 finaliza B em 102.42354142484218
# Cliente 12 inicia B em 102.42354142484218
# Cliente 10 sai do estabelecimento em 103.02694418221081
# Cliente 11 inicia C em 103.02694418221081
# Cliente 28 chega no estabelecimento em 103.9394594998648
# Cliente 28 inicia A em 103.9394594998648
# Cliente 29 chega no estabelecimento em 106.07472625328829
# Cliente 11 sai do estabelecimento em 106.29785928208915
# Cliente 28 finaliza A em 106.9394594998648
# Cliente 29 inicia A em 106.9394594998648
# Cliente 30 chega no estabelecimento em 108.92681313505422
# Cliente 31 chega no estabelecimento em 108.95191893435434
# Cliente 29 finaliza A em 109.9394594998648
# Cliente 30 inicia A em 109.9394594998648
# Cliente 12 finaliza B em 110.42354142484218
# Cliente 12 inicia C em 110.42354142484218
# Cliente 13 inicia B em 110.42354142484218
# Cliente 12 sai do estabelecimento em 112.43831191128947
# Cliente 30 finaliza A em 112.9394594998648
# Cliente 31 inicia A em 112.9394594998648
# Cliente 32 chega no estabelecimento em 115.18585424738407
# Cliente 31 finaliza A em 115.9394594998648
# Cliente 32 inicia A em 115.9394594998648
# Cliente 33 chega no estabelecimento em 117.10992755013034
# Cliente 34 chega no estabelecimento em 117.52642817892597
# Cliente 13 finaliza B em 118.42354142484218
# Cliente 13 inicia C em 118.42354142484218
# Cliente 14 inicia B em 118.42354142484218
# Cliente 32 finaliza A em 118.9394594998648
# Cliente 33 inicia A em 118.9394594998648
# Cliente 35 chega no estabelecimento em 120.497970944211
# Cliente 33 finaliza A em 121.9394594998648
# Cliente 34 inicia A em 121.9394594998648
# Cliente 13 sai do estabelecimento em 122.79507609499342
# Cliente 36 chega no estabelecimento em 122.97426586805372
# Cliente 34 finaliza A em 124.9394594998648
# Cliente 35 inicia A em 124.9394594998648
# Cliente 14 finaliza B em 126.42354142484218
# Cliente 14 inicia C em 126.42354142484218
# Cliente 15 inicia B em 126.42354142484218
# Cliente 35 finaliza A em 127.9394594998648
# Cliente 36 inicia A em 127.9394594998648
# Cliente 36 finaliza A em 130.9394594998648
# Cliente 14 sai do estabelecimento em 132.0179207520203
# Cliente 37 chega no estabelecimento em 133.1579214681193
# Cliente 37 inicia A em 133.1579214681193
# Cliente 15 finaliza B em 134.4235414248422
# Cliente 15 inicia C em 134.4235414248422
# Cliente 16 inicia B em 134.4235414248422
# Cliente 38 chega no estabelecimento em 134.53937903955836
# Cliente 37 finaliza A em 136.1579214681193
# Cliente 38 inicia A em 136.1579214681193
# Cliente 15 sai do estabelecimento em 138.14946991264344
# Cliente 38 finaliza A em 139.1579214681193
# Cliente 16 finaliza B em 142.4235414248422
# Cliente 16 inicia C em 142.4235414248422
# Cliente 17 inicia B em 142.4235414248422
# Cliente 16 sai do estabelecimento em 146.0945300800092
# Cliente 39 chega no estabelecimento em 146.60885191908287
# Cliente 39 inicia A em 146.60885191908287
# Cliente 39 finaliza A em 149.60885191908287
# Cliente 17 finaliza B em 150.4235414248422
# Cliente 17 inicia C em 150.4235414248422
# Cliente 18 inicia B em 150.4235414248422
# Cliente 17 sai do estabelecimento em 150.7476935705298
# Cliente 40 chega no estabelecimento em 151.21668590763758
# Cliente 40 inicia A em 151.21668590763758
# Cliente 40 finaliza A em 154.21668590763758
# Cliente 41 chega no estabelecimento em 154.5773938277721
# Cliente 41 inicia A em 154.5773938277721
# Cliente 41 finaliza A em 157.5773938277721
# Cliente 42 chega no estabelecimento em 157.67168739150745
# Cliente 42 inicia A em 157.67168739150745
# Cliente 18 finaliza B em 158.4235414248422
# Cliente 18 inicia C em 158.4235414248422
# Cliente 19 inicia B em 158.4235414248422
# Cliente 43 chega no estabelecimento em 160.23524005420288
# Cliente 42 finaliza A em 160.67168739150745
# Cliente 43 inicia A em 160.67168739150745
# Cliente 18 sai do estabelecimento em 161.15093179879239
# Cliente 43 finaliza A em 163.67168739150745
# Cliente 44 chega no estabelecimento em 164.63184137105046
# Cliente 44 inicia A em 164.63184137105046
# Cliente 19 finaliza B em 166.4235414248422
# Cliente 19 inicia C em 166.4235414248422
# Cliente 20 inicia B em 166.4235414248422
# Cliente 44 finaliza A em 167.63184137105046
# Cliente 45 chega no estabelecimento em 168.5000176659494
# Cliente 45 inicia A em 168.5000176659494
# Cliente 46 chega no estabelecimento em 169.40640681747263
# Cliente 19 sai do estabelecimento em 169.78924232295174
# Cliente 45 finaliza A em 171.5000176659494
# Cliente 46 inicia A em 171.5000176659494
# Cliente 47 chega no estabelecimento em 172.31753893323733
# Cliente 20 finaliza B em 174.4235414248422
# Cliente 20 inicia C em 174.4235414248422
# Cliente 21 inicia B em 174.4235414248422
# Cliente 46 finaliza A em 174.5000176659494
# Cliente 47 inicia A em 174.5000176659494
# Cliente 20 sai do estabelecimento em 177.1057433614457
# Cliente 47 finaliza A em 177.5000176659494
# Cliente 21 finaliza B em 182.4235414248422
# Cliente 21 inicia C em 182.4235414248422
# Cliente 22 inicia B em 182.4235414248422
# Cliente 21 sai do estabelecimento em 182.60332437077352
# Cliente 48 chega no estabelecimento em 189.63474339474882
# Cliente 48 inicia A em 189.63474339474882
# Cliente 49 chega no estabelecimento em 189.6489155943215
# Cliente 22 finaliza B em 190.4235414248422
# Cliente 22 inicia C em 190.4235414248422
# Cliente 23 inicia B em 190.4235414248422
# Cliente 22 sai do estabelecimento em 190.68302428973385
# Cliente 48 finaliza A em 192.63474339474882
# Cliente 49 inicia A em 192.63474339474882
# Cliente 50 chega no estabelecimento em 193.4820064635581
# Cliente 51 chega no estabelecimento em 193.96865628391998
# Cliente 52 chega no estabelecimento em 194.54434379578444
# Cliente 49 finaliza A em 195.63474339474882
# Cliente 50 inicia A em 195.63474339474882
# Cliente 53 chega no estabelecimento em 197.57074267431565
# Cliente 23 finaliza B em 198.4235414248422
# Cliente 23 inicia C em 198.4235414248422
# Cliente 24 inicia B em 198.4235414248422
# Cliente 50 finaliza A em 198.63474339474882
# Cliente 51 inicia A em 198.63474339474882
# Cliente 51 finaliza A em 201.63474339474882
# Cliente 52 inicia A em 201.63474339474882
# Cliente 23 sai do estabelecimento em 201.7420207317717
# Cliente 52 finaliza A em 204.63474339474882
# Cliente 53 inicia A em 204.63474339474882
# Cliente 24 finaliza B em 206.4235414248422
# Cliente 24 inicia C em 206.4235414248422
# Cliente 25 inicia B em 206.4235414248422
# Cliente 53 finaliza A em 207.63474339474882
# Cliente 24 sai do estabelecimento em 209.49189798138747
# Cliente 25 finaliza B em 214.4235414248422
# Cliente 25 inicia C em 214.4235414248422
# Cliente 26 inicia B em 214.4235414248422
# Cliente 25 sai do estabelecimento em 217.29157711190027
# Cliente 54 chega no estabelecimento em 222.16197986841343
# Cliente 54 inicia A em 222.16197986841343
# Cliente 26 finaliza B em 222.4235414248422
# Cliente 26 inicia C em 222.4235414248422
# Cliente 27 inicia B em 222.4235414248422
# Cliente 54 finaliza A em 225.16197986841343
# Cliente 26 sai do estabelecimento em 225.38631873612277
# Cliente 55 chega no estabelecimento em 225.63885000756056
# Cliente 55 inicia A em 225.63885000756056
# Cliente 55 finaliza A em 228.63885000756056
# Cliente 27 finaliza B em 230.4235414248422
# Cliente 27 inicia C em 230.4235414248422
# Cliente 28 inicia B em 230.4235414248422
# Cliente 56 chega no estabelecimento em 232.1159144311254
# Cliente 56 inicia A em 232.1159144311254
# Cliente 56 finaliza A em 235.1159144311254
# Cliente 57 chega no estabelecimento em 238.10040963254949
# Cliente 57 inicia A em 238.10040963254949
# Cliente 28 finaliza B em 238.4235414248422
# Cliente 29 inicia B em 238.4235414248422
# Cliente 58 chega no estabelecimento em 240.8526669505299
# Cliente 57 finaliza A em 241.10040963254949
# Cliente 58 inicia A em 241.10040963254949
# Cliente 27 sai do estabelecimento em 241.83458867373483
# Cliente 28 inicia C em 241.83458867373483
# Cliente 58 finaliza A em 244.10040963254949
# Cliente 59 chega no estabelecimento em 246.09505521174012
# Cliente 59 inicia A em 246.09505521174012
# Cliente 29 finaliza B em 246.4235414248422
# Cliente 30 inicia B em 246.4235414248422
# Cliente 60 chega no estabelecimento em 246.92903282037457
# Cliente 61 chega no estabelecimento em 248.2837637100781
# Cliente 59 finaliza A em 249.09505521174012
# Cliente 60 inicia A em 249.09505521174012
# Cliente 60 finaliza A em 252.09505521174012
# Cliente 61 inicia A em 252.09505521174012
# Cliente 62 chega no estabelecimento em 253.11001326320923
# Cliente 28 sai do estabelecimento em 253.84885927546102
# Cliente 29 inicia C em 253.84885927546102
# Cliente 30 finaliza B em 254.4235414248422
# Cliente 31 inicia B em 254.4235414248422
# Cliente 61 finaliza A em 255.09505521174012
# Cliente 62 inicia A em 255.09505521174012
# Cliente 62 finaliza A em 258.09505521174015
# Cliente 63 chega no estabelecimento em 258.91809233614896
# Cliente 63 inicia A em 258.91809233614896
# Cliente 29 sai do estabelecimento em 258.9933607724676
# Cliente 30 inicia C em 258.9933607724676
# Cliente 63 finaliza A em 261.91809233614896
# Cliente 31 finaliza B em 262.4235414248422
# Cliente 32 inicia B em 262.4235414248422
# Cliente 64 chega no estabelecimento em 263.3581707008224
# Cliente 64 inicia A em 263.3581707008224
# Cliente 64 finaliza A em 266.3581707008224
# Cliente 65 chega no estabelecimento em 266.61764944319094
# Cliente 65 inicia A em 266.61764944319094
# Cliente 30 sai do estabelecimento em 267.8362088110285
# Cliente 31 inicia C em 267.8362088110285
# Cliente 65 finaliza A em 269.61764944319094
# Cliente 32 finaliza B em 270.4235414248422
# Cliente 33 inicia B em 270.4235414248422
# Cliente 66 chega no estabelecimento em 274.85825368701785
# Cliente 66 inicia A em 274.85825368701785
# Cliente 67 chega no estabelecimento em 277.71605890897894
# Cliente 66 finaliza A em 277.85825368701785
# Cliente 67 inicia A em 277.85825368701785
# Cliente 33 finaliza B em 278.4235414248422
# Cliente 34 inicia B em 278.4235414248422
# Cliente 67 finaliza A em 280.85825368701785
# Cliente 31 sai do estabelecimento em 284.23409697362086
# Cliente 32 inicia C em 284.23409697362086
# Cliente 34 finaliza B em 286.4235414248422
# Cliente 35 inicia B em 286.4235414248422
# Cliente 68 chega no estabelecimento em 287.5055629080069
# Cliente 68 inicia A em 287.5055629080069
# Cliente 68 finaliza A em 290.5055629080069
# Cliente 32 sai do estabelecimento em 290.56763736526966
# Cliente 33 inicia C em 290.56763736526966
# Cliente 33 sai do estabelecimento em 290.80433185662383
# Cliente 34 inicia C em 290.80433185662383
# Cliente 35 finaliza B em 294.4235414248422
# Cliente 36 inicia B em 294.4235414248422
# Cliente 69 chega no estabelecimento em 298.4823617402287
# Cliente 69 inicia A em 298.4823617402287
# Cliente 69 finaliza A em 301.4823617402287
# Cliente 36 finaliza B em 302.4235414248422
# Cliente 37 inicia B em 302.4235414248422
# Cliente 34 sai do estabelecimento em 303.0192401185397
# Cliente 35 inicia C em 303.0192401185397
# Cliente 70 chega no estabelecimento em 305.76248216484066
# Cliente 70 inicia A em 305.76248216484066
# Cliente 70 finaliza A em 308.76248216484066
# Cliente 37 finaliza B em 310.4235414248422
# Cliente 38 inicia B em 310.4235414248422
# Cliente 38 finaliza B em 318.4235414248422
# Cliente 39 inicia B em 318.4235414248422
# Cliente 35 sai do estabelecimento em 319.420194833916
# Cliente 36 inicia C em 319.420194833916
# Cliente 36 sai do estabelecimento em 321.10095638843865
# Cliente 37 inicia C em 321.10095638843865
# Cliente 71 chega no estabelecimento em 325.6638198433965
# Cliente 71 inicia A em 325.6638198433965
# Cliente 39 finaliza B em 326.4235414248422
# Cliente 40 inicia B em 326.4235414248422
# Cliente 72 chega no estabelecimento em 326.42534402993687
# Cliente 37 sai do estabelecimento em 326.6442894602786
# Cliente 38 inicia C em 326.6442894602786
# Cliente 71 finaliza A em 328.6638198433965
# Cliente 72 inicia A em 328.6638198433965
# Cliente 73 chega no estabelecimento em 330.9463244159109
# Cliente 72 finaliza A em 331.6638198433965
# Cliente 73 inicia A em 331.6638198433965
# Cliente 74 chega no estabelecimento em 332.0121254283329
# Cliente 75 chega no estabelecimento em 334.1650300059446
# Cliente 40 finaliza B em 334.4235414248422
# Cliente 41 inicia B em 334.4235414248422
# Cliente 76 chega no estabelecimento em 334.5805560517039
# Cliente 73 finaliza A em 334.6638198433965
# Cliente 74 inicia A em 334.6638198433965
# Cliente 77 chega no estabelecimento em 335.6629868296466
# Cliente 78 chega no estabelecimento em 336.82707951180777
# Cliente 79 chega no estabelecimento em 337.3317142474895
# Cliente 74 finaliza A em 337.6638198433965
# Cliente 75 inicia A em 337.6638198433965
# Cliente 38 sai do estabelecimento em 339.24673118472043
# Cliente 39 inicia C em 339.24673118472043
# Cliente 75 finaliza A em 340.6638198433965
# Cliente 76 inicia A em 340.6638198433965
# Cliente 41 finaliza B em 342.4235414248422
# Cliente 42 inicia B em 342.4235414248422
# Cliente 76 finaliza A em 343.6638198433965
# Cliente 77 inicia A em 343.6638198433965
# Cliente 77 finaliza A em 346.6638198433965
# Cliente 78 inicia A em 346.6638198433965
# Cliente 78 finaliza A em 349.6638198433965
# Cliente 79 inicia A em 349.6638198433965
# Cliente 39 sai do estabelecimento em 350.1722508100587
# Cliente 40 inicia C em 350.1722508100587
# Cliente 42 finaliza B em 350.4235414248422
# Cliente 43 inicia B em 350.4235414248422
# Cliente 79 finaliza A em 352.6638198433965
# Cliente 40 sai do estabelecimento em 353.2881178394785
# Cliente 41 inicia C em 353.2881178394785
# Cliente 43 finaliza B em 358.4235414248422
# Cliente 44 inicia B em 358.4235414248422
# Cliente 41 sai do estabelecimento em 360.0951988058159
# Cliente 42 inicia C em 360.0951988058159
# Cliente 42 sai do estabelecimento em 366.03629968378056
# Cliente 43 inicia C em 366.03629968378056
# Cliente 44 finaliza B em 366.4235414248422
# Cliente 45 inicia B em 366.4235414248422
# Cliente 43 sai do estabelecimento em 369.73178001255906
# Cliente 44 inicia C em 369.73178001255906
# Cliente 44 sai do estabelecimento em 372.48556518192845
# Cliente 45 finaliza B em 374.4235414248422
# Cliente 45 inicia C em 374.4235414248422
# Cliente 46 inicia B em 374.4235414248422
# Cliente 80 chega no estabelecimento em 377.85775645168997
# Cliente 80 inicia A em 377.85775645168997
# Cliente 45 sai do estabelecimento em 379.8778532667203
# Cliente 80 finaliza A em 380.85775645168997
# Cliente 81 chega no estabelecimento em 381.9120061197663
# Cliente 81 inicia A em 381.9120061197663
# Cliente 46 finaliza B em 382.4235414248422
# Cliente 46 inicia C em 382.4235414248422
# Cliente 47 inicia B em 382.4235414248422
# Cliente 82 chega no estabelecimento em 383.457486936701
# Cliente 46 sai do estabelecimento em 384.6888849868451
# Cliente 81 finaliza A em 384.9120061197663
# Cliente 82 inicia A em 384.9120061197663
# Cliente 82 finaliza A em 387.9120061197663
# Cliente 83 chega no estabelecimento em 388.39194842454395
# Cliente 83 inicia A em 388.39194842454395
# Cliente 47 finaliza B em 390.4235414248422
# Cliente 47 inicia C em 390.4235414248422
# Cliente 48 inicia B em 390.4235414248422
# Cliente 83 finaliza A em 391.39194842454395
# Cliente 47 sai do estabelecimento em 391.5995826213003
# Cliente 84 chega no estabelecimento em 393.32456079066253
# Cliente 84 inicia A em 393.32456079066253
# Cliente 84 finaliza A em 396.32456079066253
# Cliente 85 chega no estabelecimento em 398.02969396110393
# Cliente 85 inicia A em 398.02969396110393
# Cliente 48 finaliza B em 398.4235414248422
# Cliente 48 inicia C em 398.4235414248422
# Cliente 49 inicia B em 398.4235414248422
# Cliente 85 finaliza A em 401.02969396110393
# Cliente 49 finaliza B em 406.4235414248422
# Cliente 50 inicia B em 406.4235414248422
# Cliente 86 chega no estabelecimento em 408.42405289693903
# Cliente 86 inicia A em 408.42405289693903
# Cliente 48 sai do estabelecimento em 408.6763523784662
# Cliente 49 inicia C em 408.6763523784662
# Cliente 49 sai do estabelecimento em 409.0401342796801
# Cliente 86 finaliza A em 411.42405289693903
# Cliente 87 chega no estabelecimento em 413.70560147965955
# Cliente 87 inicia A em 413.70560147965955
# Cliente 50 finaliza B em 414.4235414248422
# Cliente 50 inicia C em 414.4235414248422
# Cliente 51 inicia B em 414.4235414248422
# Cliente 50 sai do estabelecimento em 414.88972564518036
# Cliente 88 chega no estabelecimento em 416.4596580729236
# Cliente 87 finaliza A em 416.70560147965955
# Cliente 88 inicia A em 416.70560147965955
# Cliente 89 chega no estabelecimento em 416.7438316871468
# Cliente 90 chega no estabelecimento em 418.2136611287376
# Cliente 88 finaliza A em 419.70560147965955
# Cliente 89 inicia A em 419.70560147965955
# Cliente 91 chega no estabelecimento em 421.26572865380615
# Cliente 51 finaliza B em 422.4235414248422
# Cliente 51 inicia C em 422.4235414248422
# Cliente 52 inicia B em 422.4235414248422
# Cliente 89 finaliza A em 422.70560147965955
# Cliente 90 inicia A em 422.70560147965955
# Cliente 90 finaliza A em 425.70560147965955
# Cliente 91 inicia A em 425.70560147965955
# Cliente 51 sai do estabelecimento em 427.37917238099567
# Cliente 92 chega no estabelecimento em 428.3888157424137
# Cliente 91 finaliza A em 428.70560147965955
# Cliente 92 inicia A em 428.70560147965955
# Cliente 93 chega no estabelecimento em 430.04862009671706
# Cliente 52 finaliza B em 430.4235414248422
# Cliente 52 inicia C em 430.4235414248422
# Cliente 53 inicia B em 430.4235414248422
# Cliente 92 finaliza A em 431.70560147965955
# Cliente 93 inicia A em 431.70560147965955
# Cliente 52 sai do estabelecimento em 433.9547740510548
# Cliente 93 finaliza A em 434.70560147965955
# Cliente 94 chega no estabelecimento em 435.98696989941317
# Cliente 94 inicia A em 435.98696989941317
# Cliente 53 finaliza B em 438.4235414248422
# Cliente 53 inicia C em 438.4235414248422
# Cliente 54 inicia B em 438.4235414248422
# Cliente 94 finaliza A em 438.98696989941317
# Cliente 95 chega no estabelecimento em 439.5285746670113
# Cliente 95 inicia A em 439.5285746670113
# Cliente 53 sai do estabelecimento em 439.9536003812341
# Cliente 96 chega no estabelecimento em 442.44238240650577
# Cliente 95 finaliza A em 442.5285746670113
# Cliente 96 inicia A em 442.5285746670113
# Cliente 97 chega no estabelecimento em 444.53153263201955
# Cliente 96 finaliza A em 445.5285746670113
# Cliente 97 inicia A em 445.5285746670113
# Cliente 54 finaliza B em 446.4235414248422
# Cliente 54 inicia C em 446.4235414248422
# Cliente 55 inicia B em 446.4235414248422
# Cliente 97 finaliza A em 448.5285746670113
# Cliente 54 sai do estabelecimento em 449.71820294588264
# Cliente 98 chega no estabelecimento em 451.0146491414659
# Cliente 98 inicia A em 451.0146491414659
# Cliente 99 chega no estabelecimento em 453.97451643168364
# Cliente 98 finaliza A em 454.0146491414659
# Cliente 99 inicia A em 454.0146491414659
# Cliente 55 finaliza B em 454.4235414248422
# Cliente 55 inicia C em 454.4235414248422
# Cliente 56 inicia B em 454.4235414248422
# Cliente 99 finaliza A em 457.0146491414659
# Cliente 100 chega no estabelecimento em 457.2154628854351
# Cliente 100 inicia A em 457.2154628854351
# Cliente 55 sai do estabelecimento em 457.692321648826
# Cliente 100 finaliza A em 460.2154628854351
# Cliente 56 finaliza B em 462.4235414248422
# Cliente 56 inicia C em 462.4235414248422
# Cliente 57 inicia B em 462.4235414248422
# Cliente 101 chega no estabelecimento em 463.065553777035
# Cliente 101 inicia A em 463.065553777035
# Cliente 101 finaliza A em 466.065553777035
# Cliente 56 sai do estabelecimento em 468.78565070987474
# Cliente 57 finaliza B em 470.4235414248422
# Cliente 57 inicia C em 470.4235414248422
# Cliente 58 inicia B em 470.4235414248422
# Cliente 102 chega no estabelecimento em 471.14024316812856
# Cliente 102 inicia A em 471.14024316812856
# Cliente 57 sai do estabelecimento em 473.0216699274375
# Cliente 102 finaliza A em 474.14024316812856
# Cliente 58 finaliza B em 478.4235414248422
# Cliente 58 inicia C em 478.4235414248422
# Cliente 59 inicia B em 478.4235414248422
# Cliente 103 chega no estabelecimento em 479.02848274213846
# Cliente 103 inicia A em 479.02848274213846

# %% [markdown]
# Ótimo, já modelamos 2 processos!
#
# Porém, não estamos guardando informações para calcular estatísticas que nos interessem.

# %% [markdown]
# ---

# %% [markdown]
# # Monitorando o Processo

# %% [markdown]
# Ao analisar um processo, um gestor pode estar interessado em algumas métricas, tais como:
# - Tempo de ciclo médio;
# - Tempo de espera médio em fila;
# - Uso dos recursos
# - Trabalho em processo médio;
#
# Para fazer tais cálculos, precisamos colher algumas informações durante a simulação.

# %% [markdown]
# ### Vamos incrementar nosso código para guardar o tempo gasto na atividade C

# %%
#criando uma lista vazia
tempo_gasto_C = []

tempo_esperando_C =[]

# %%
def salao (env, nome, colaborador_A, colaborador_B, colaborador_C):
    #print (f"{nome} chega no estabelecimento em {env.now}")
    # Serviço A
    with colaborador_A.request() as req_A:
        yield req_A # o cliente deve esperar um recurso do tipo colaborador_A
        #print (f"{nome} inicia A em {env.now}") # imprima na tela o tempo de início
        yield env.timeout(3) # O serviço demora exatamente 3 minutos.
        #print (f"{nome} finaliza A em {env.now}")
    
    # Serviço B
    with colab_B.request() as req_B:
        yield req_B
        #print (f"{nome} inicia B em {env.now}")
        yield env.timeout(8) # O serviço B demora exatamente 8 minutos.
        #print (f"{nome} finaliza B em {env.now}")

        acaba_B = env.now

    # Serviço C
    with colab_C.request() as req_C:
        yield req_C
        #print (f"{nome} inicia C em {env.now}")
        
        p_inicio = env.now
        yield env.timeout(random.expovariate(1/5)) # O tempo de serviço em C segue uma exponencial de média 5.
        p_fim = env.now

        tempo_gasto_C.append(p_fim - p_inicio)
        tempo_esperando_C.append(p_inicio - acaba_B)
        
    #print (f"{nome} sai do estabelecimento em {env.now}")
    print (f"{nome} esperou {p_inicio - acaba_B} na fila da atividade C")
    print (f"{nome} gastou {p_fim - p_inicio} na atividade C")

# %%
env = simpy.Environment()
colab_A = simpy.Resource(env, capacity=1)
colab_B = simpy.Resource(env, capacity=1)
colab_C = simpy.Resource(env, capacity=1)
env.process(chegadas(env))
env.run(until = 60000)
# Out:
# Cliente 1 esperou 0.0 na fila da atividade C
# Cliente 1 gastou 4.23264758802596 na atividade C
# Cliente 2 esperou 0.0 na fila da atividade C
# Cliente 2 gastou 8.446176873146193 na atividade C
# Cliente 3 esperou 0.44617687314619303 na fila da atividade C
# Cliente 3 gastou 1.578051270518415 na atividade C
# Cliente 4 esperou 0.0 na fila da atividade C
# Cliente 4 gastou 3.614612228119441 na atividade C
# Cliente 5 esperou 0.0 na fila da atividade C
# Cliente 5 gastou 1.2205548512119577 na atividade C
# Cliente 6 esperou 0.0 na fila da atividade C
# Cliente 6 gastou 10.157438947230226 na atividade C
# Cliente 7 esperou 2.157438947230226 na fila da atividade C
# Cliente 7 gastou 1.8705657540803458 na atividade C
# Cliente 8 esperou 0.0 na fila da atividade C
# Cliente 8 gastou 14.078576702790997 na atividade C
# Cliente 9 esperou 6.078576702790997 na fila da atividade C
# Cliente 9 gastou 3.6633419364373765 na atividade C
# Cliente 10 esperou 1.7419186392283734 na fila da atividade C
# Cliente 10 gastou 0.38460437158938987 na atividade C
# Cliente 11 esperou 0.0 na fila da atividade C
# Cliente 11 gastou 6.10638757546117 na atividade C
# Cliente 12 esperou 0.0 na fila da atividade C
# Cliente 12 gastou 0.7985713653887672 na atividade C
# Cliente 13 esperou 0.0 na fila da atividade C
# Cliente 13 gastou 7.2344948247576895 na atividade C
# Cliente 14 esperou 0.0 na fila da atividade C
# Cliente 14 gastou 3.661665980476826 na atividade C
# Cliente 15 esperou 0.0 na fila da atividade C
# Cliente 15 gastou 4.332243215009498 na atividade C
# Cliente 16 esperou 0.0 na fila da atividade C
# Cliente 16 gastou 28.213529137231973 na atividade C
# Cliente 17 esperou 20.213529137231973 na fila da atividade C
# Cliente 17 gastou 4.061076815244348 na atividade C
# Cliente 18 esperou 16.27460595247632 na fila da atividade C
# Cliente 18 gastou 7.001310853302783 na atividade C
# Cliente 19 esperou 15.275916805779104 na fila da atividade C
# Cliente 19 gastou 8.418648147702498 na atividade C
# Cliente 20 esperou 15.694564953481603 na fila da atividade C
# Cliente 20 gastou 16.28506334481645 na atividade C
# Cliente 21 esperou 23.979628298298053 na fila da atividade C
# Cliente 21 gastou 20.14759963260309 na atividade C
# Cliente 22 esperou 36.12722793090114 na fila da atividade C
# Cliente 22 gastou 2.115511733553234 na atividade C
# Cliente 23 esperou 30.242739664454376 na fila da atividade C
# Cliente 23 gastou 0.9144292813601282 na atividade C
# Cliente 24 esperou 23.157168945814504 na fila da atividade C
# Cliente 24 gastou 2.756686066277581 na atividade C
# Cliente 25 esperou 17.913855012092085 na fila da atividade C
# Cliente 25 gastou 1.5300420331849693 na atividade C
# Cliente 26 esperou 11.443897045277055 na fila da atividade C
# Cliente 26 gastou 3.698122283573923 na atividade C
# Cliente 27 esperou 7.142019328850978 na fila da atividade C
# Cliente 27 gastou 2.7735366543174393 na atividade C
# Cliente 28 esperou 1.9155559831684172 na fila da atividade C
# Cliente 28 gastou 1.6441577911476202 na atividade C
# Cliente 29 esperou 0.0 na fila da atividade C
# Cliente 29 gastou 4.542158683315847 na atividade C
# Cliente 30 esperou 0.0 na fila da atividade C
# Cliente 30 gastou 21.64371006877184 na atividade C
# Cliente 31 esperou 13.643710068771838 na fila da atividade C
# Cliente 31 gastou 1.1073103158145727 na atividade C
# Cliente 32 esperou 6.751020384586411 na fila da atividade C
# Cliente 32 gastou 0.07380822447754554 na atividade C
# Cliente 33 esperou 0.0 na fila da atividade C
# Cliente 33 gastou 1.789860185200837 na atividade C
# Cliente 34 esperou 0.0 na fila da atividade C
# Cliente 34 gastou 1.3270028986707985 na atividade C
# Cliente 35 esperou 0.0 na fila da atividade C
# Cliente 35 gastou 11.075902961930183 na atividade C
# Cliente 36 esperou 3.0759029619301828 na fila da atividade C
# Cliente 36 gastou 0.4778025720167989 na atividade C
# Cliente 37 esperou 0.0 na fila da atividade C
# Cliente 37 gastou 1.1344080904236193 na atividade C
# Cliente 38 esperou 0.0 na fila da atividade C
# Cliente 38 gastou 0.6549840554973798 na atividade C
# Cliente 39 esperou 0.0 na fila da atividade C
# Cliente 39 gastou 2.4803077794722412 na atividade C
# Cliente 40 esperou 0.0 na fila da atividade C
# Cliente 40 gastou 5.366227370250044 na atividade C
# Cliente 41 esperou 0.0 na fila da atividade C
# Cliente 41 gastou 30.35547702830104 na atividade C
# Cliente 42 esperou 22.35547702830104 na fila da atividade C
# Cliente 42 gastou 1.7571786122428534 na atividade C
# Cliente 43 esperou 16.112655640543892 na fila da atividade C
# Cliente 43 gastou 0.34357926903516045 na atividade C
# Cliente 44 esperou 8.456234909579052 na fila da atividade C
# Cliente 44 gastou 11.33677228959806 na atividade C
# Cliente 45 esperou 11.793007199177111 na fila da atividade C
# Cliente 45 gastou 8.188242803723426 na atividade C
# Cliente 46 esperou 11.981250002900538 na fila da atividade C
# Cliente 46 gastou 19.496755150834304 na atividade C
# Cliente 47 esperou 23.47800515373484 na fila da atividade C
# Cliente 47 gastou 3.322277295108904 na atividade C
# Cliente 48 esperou 18.800282448843745 na fila da atividade C
# Cliente 48 gastou 10.293034734391597 na atividade C
# Cliente 49 esperou 21.093317183235342 na fila da atividade C
# Cliente 49 gastou 2.9537969081654865 na atividade C
# Cliente 50 esperou 16.04711409140083 na fila da atividade C
# Cliente 50 gastou 0.10593741064025153 na atividade C
# Cliente 51 esperou 8.15305150204108 na fila da atividade C
# Cliente 51 gastou 12.075776435252124 na atividade C
# Cliente 52 esperou 12.228827937293204 na fila da atividade C
# Cliente 52 gastou 12.434000758818229 na atividade C
# Cliente 53 esperou 16.662828696111433 na fila da atividade C
# Cliente 53 gastou 8.032757290379038 na atividade C
# Cliente 54 esperou 16.69558598649047 na fila da atividade C
# Cliente 54 gastou 7.493307564186864 na atividade C
# Cliente 55 esperou 16.188893550677335 na fila da atividade C
# Cliente 55 gastou 3.04912263460119 na atividade C
# Cliente 56 esperou 11.238016185278525 na fila da atividade C
# Cliente 56 gastou 0.5631240368331873 na atividade C
# Cliente 57 esperou 3.8011402221117123 na fila da atividade C
# Cliente 57 gastou 5.074700127547487 na atividade C
# Cliente 58 esperou 0.8758403496591995 na fila da atividade C
# Cliente 58 gastou 0.2814430454319563 na atividade C
# Cliente 59 esperou 0.0 na fila da atividade C
# Cliente 59 gastou 2.509211086415519 na atividade C
# Cliente 60 esperou 0.0 na fila da atividade C
# Cliente 60 gastou 0.591435544703586 na atividade C
# Cliente 61 esperou 0.0 na fila da atividade C
# Cliente 61 gastou 7.503907678758367 na atividade C
# Cliente 62 esperou 0.0 na fila da atividade C
# Cliente 62 gastou 1.8751807877989108 na atividade C
# Cliente 63 esperou 0.0 na fila da atividade C
# Cliente 63 gastou 2.502500292503953 na atividade C
# Cliente 64 esperou 0.0 na fila da atividade C
# Cliente 64 gastou 18.94625903522069 na atividade C
# Cliente 65 esperou 10.946259035220692 na fila da atividade C
# Cliente 65 gastou 3.4477746574144703 na atividade C
# Cliente 66 esperou 6.394033692635162 na fila da atividade C
# Cliente 66 gastou 7.367283454437711 na atividade C
# Cliente 67 esperou 5.761317147072873 na fila da atividade C
# Cliente 67 gastou 4.3870292361920065 na atividade C
# Cliente 68 esperou 2.1483463832648795 na fila da atividade C
# Cliente 68 gastou 2.766578035549628 na atividade C
# Cliente 69 esperou 0.0 na fila da atividade C
# Cliente 69 gastou 3.39764893599056 na atividade C
# Cliente 70 esperou 0.0 na fila da atividade C
# Cliente 70 gastou 2.0991194407766898 na atividade C
# Cliente 71 esperou 0.0 na fila da atividade C
# Cliente 71 gastou 1.790945277627202 na atividade C
# Cliente 72 esperou 0.0 na fila da atividade C
# Cliente 72 gastou 3.7943124773393038 na atividade C
# Cliente 73 esperou 0.0 na fila da atividade C
# Cliente 73 gastou 3.333134337953311 na atividade C
# Cliente 74 esperou 0.0 na fila da atividade C
# Cliente 74 gastou 3.773505428369731 na atividade C
# Cliente 75 esperou 0.0 na fila da atividade C
# Cliente 75 gastou 13.208408376485067 na atividade C
# Cliente 76 esperou 5.2084083764850675 na fila da atividade C
# Cliente 76 gastou 1.23473962174387 na atividade C
# Cliente 77 esperou 0.0 na fila da atividade C
# Cliente 77 gastou 1.5765517461937861 na atividade C
# Cliente 78 esperou 0.0 na fila da atividade C
# Cliente 78 gastou 5.988288518953823 na atividade C
# Cliente 79 esperou 0.0 na fila da atividade C
# Cliente 79 gastou 11.398514408368555 na atividade C
# Cliente 80 esperou 3.3985144083685555 na fila da atividade C
# Cliente 80 gastou 4.747656107692819 na atividade C
# Cliente 81 esperou 0.14617051606137466 na fila da atividade C
# Cliente 81 gastou 0.26850925579788054 na atividade C
# Cliente 82 esperou 0.0 na fila da atividade C
# Cliente 82 gastou 8.451712252108905 na atividade C
# Cliente 83 esperou 0.451712252108905 na fila da atividade C
# Cliente 83 gastou 9.070272799670875 na atividade C
# Cliente 84 esperou 1.5219850517797795 na fila da atividade C
# Cliente 84 gastou 6.523471915809182 na atividade C
# Cliente 85 esperou 0.04545696758896156 na fila da atividade C
# Cliente 85 gastou 1.5963896404862226 na atividade C
# Cliente 86 esperou 0.0 na fila da atividade C
# Cliente 86 gastou 3.904828489305828 na atividade C
# Cliente 87 esperou 0.0 na fila da atividade C
# Cliente 87 gastou 2.0025922736626853 na atividade C
# Cliente 88 esperou 0.0 na fila da atividade C
# Cliente 88 gastou 4.444827310673759 na atividade C
# Cliente 89 esperou 0.0 na fila da atividade C
# Cliente 89 gastou 1.8087202789275807 na atividade C
# Cliente 90 esperou 0.0 na fila da atividade C
# Cliente 90 gastou 1.5989968758026407 na atividade C
# Cliente 91 esperou 0.0 na fila da atividade C
# Cliente 91 gastou 8.852474218860266 na atividade C
# Cliente 92 esperou 0.8524742188602659 na fila da atividade C
# Cliente 92 gastou 0.29401727166134606 na atividade C
# Cliente 93 esperou 0.0 na fila da atividade C
# Cliente 93 gastou 1.69590535905661 na atividade C
# Cliente 94 esperou 0.0 na fila da atividade C
# Cliente 94 gastou 4.102472432652576 na atividade C
# Cliente 95 esperou 0.0 na fila da atividade C
# Cliente 95 gastou 1.4968663837191798 na atividade C
# Cliente 96 esperou 0.0 na fila da atividade C
# Cliente 96 gastou 1.831951167295756 na atividade C
# Cliente 97 esperou 0.0 na fila da atividade C
# Cliente 97 gastou 8.98545930447358 na atividade C
# Cliente 98 esperou 0.9854593044735793 na fila da atividade C
# Cliente 98 gastou 15.353276652867521 na atividade C
# Cliente 99 esperou 8.3387359573411 na fila da atividade C
# Cliente 99 gastou 6.079534192442907 na atividade C
# Cliente 100 esperou 6.418270149784007 na fila da atividade C
# Cliente 100 gastou 3.0028621874678265 na atividade C
# Cliente 101 esperou 1.4211323372518336 na fila da atividade C
# Cliente 101 gastou 8.465399628957584 na atividade C
# Cliente 102 esperou 1.886531966209418 na fila da atividade C
# Cliente 102 gastou 7.376702812691519 na atividade C
# Cliente 103 esperou 1.2632347789009373 na fila da atividade C
# Cliente 103 gastou 5.177334715115876 na atividade C
# Cliente 104 esperou 0.0 na fila da atividade C
# Cliente 104 gastou 2.353343149805937 na atividade C
# Cliente 105 esperou 0.0 na fila da atividade C
# Cliente 105 gastou 0.6940447922677322 na atividade C
# Cliente 106 esperou 0.0 na fila da atividade C
# Cliente 106 gastou 8.650217414997542 na atividade C
# Cliente 107 esperou 0.6502174149975417 na fila da atividade C
# Cliente 107 gastou 6.000340176876193 na atividade C
# Cliente 108 esperou 0.0 na fila da atividade C
# Cliente 108 gastou 3.032945697320997 na atividade C
# Cliente 109 esperou 0.0 na fila da atividade C
# Cliente 109 gastou 3.308264091140586 na atividade C
# Cliente 110 esperou 0.0 na fila da atividade C
# Cliente 110 gastou 3.256886728639529 na atividade C
# Cliente 111 esperou 0.0 na fila da atividade C
# Cliente 111 gastou 1.8299029479093178 na atividade C
# Cliente 112 esperou 0.0 na fila da atividade C
# Cliente 112 gastou 30.17649533318331 na atividade C
# Cliente 113 esperou 22.17649533318331 na fila da atividade C
# Cliente 113 gastou 7.127791673982983 na atividade C
# Cliente 114 esperou 21.304287007166295 na fila da atividade C
# Cliente 114 gastou 0.9570842384142679 na atividade C
# Cliente 115 esperou 14.261371245580563 na fila da atividade C
# Cliente 115 gastou 6.375406806147453 na atividade C
# Cliente 116 esperou 12.636778051728015 na fila da atividade C
# Cliente 116 gastou 5.755194322108537 na atividade C
# Cliente 117 esperou 10.391972373836552 na fila da atividade C
# Cliente 117 gastou 1.630320068432411 na atividade C
# Cliente 118 esperou 4.022292442268963 na fila da atividade C
# Cliente 118 gastou 5.045854579994625 na atividade C
# Cliente 119 esperou 1.068147022263588 na fila da atividade C
# Cliente 119 gastou 1.9172066808357613 na atividade C
# Cliente 120 esperou 0.0 na fila da atividade C
# Cliente 120 gastou 1.1963185532915759 na atividade C
# Cliente 121 esperou 0.0 na fila da atividade C
# Cliente 121 gastou 17.264448049786438 na atividade C
# Cliente 122 esperou 9.264448049786438 na fila da atividade C
# Cliente 122 gastou 2.6758240010138934 na atividade C
# Cliente 123 esperou 3.9402720508003313 na fila da atividade C
# Cliente 123 gastou 1.298245344235056 na atividade C
# Cliente 124 esperou 0.0 na fila da atividade C
# Cliente 124 gastou 2.8886689527025737 na atividade C
# Cliente 125 esperou 0.0 na fila da atividade C
# Cliente 125 gastou 1.0836929067959318 na atividade C
# Cliente 126 esperou 0.0 na fila da atividade C
# Cliente 126 gastou 1.9233123258646856 na atividade C
# Cliente 127 esperou 0.0 na fila da atividade C
# Cliente 127 gastou 7.22426721215902 na atividade C
# Cliente 128 esperou 0.0 na fila da atividade C
# Cliente 128 gastou 0.8931577541698061 na atividade C
# Cliente 129 esperou 0.0 na fila da atividade C
# Cliente 129 gastou 3.244290528876263 na atividade C
# Cliente 130 esperou 0.0 na fila da atividade C
# Cliente 130 gastou 0.37359915917772923 na atividade C
# Cliente 131 esperou 0.0 na fila da atividade C
# Cliente 131 gastou 1.5487874517018554 na atividade C
# Cliente 132 esperou 0.0 na fila da atividade C
# Cliente 132 gastou 2.8248347372280023 na atividade C
# Cliente 133 esperou 0.0 na fila da atividade C
# Cliente 133 gastou 4.152381353832652 na atividade C
# Cliente 134 esperou 0.0 na fila da atividade C
# Cliente 134 gastou 0.838197439238229 na atividade C
# Cliente 135 esperou 0.0 na fila da atividade C
# Cliente 135 gastou 13.607922754870742 na atividade C
# Cliente 136 esperou 5.607922754870742 na fila da atividade C
# Cliente 136 gastou 2.6643874137068906 na atividade C
# Cliente 137 esperou 0.2723101685776328 na fila da atividade C
# Cliente 137 gastou 2.130474176034113 na atividade C
# Cliente 138 esperou 0.0 na fila da atividade C
# Cliente 138 gastou 0.44346586685310285 na atividade C
# Cliente 139 esperou 0.0 na fila da atividade C
# Cliente 139 gastou 12.209363563081752 na atividade C
# Cliente 140 esperou 4.209363563081752 na fila da atividade C
# Cliente 140 gastou 8.739720849636342 na atividade C
# Cliente 141 esperou 4.9490844127180935 na fila da atividade C
# Cliente 141 gastou 0.028560150681869345 na atividade C
# Cliente 142 esperou 0.0 na fila da atividade C
# Cliente 142 gastou 2.625057120609654 na atividade C
# Cliente 143 esperou 0.0 na fila da atividade C
# Cliente 143 gastou 9.534401717066885 na atividade C
# Cliente 144 esperou 1.5344017170668849 na fila da atividade C
# Cliente 144 gastou 5.90004972941756 na atividade C
# Cliente 145 esperou 0.0 na fila da atividade C
# Cliente 145 gastou 5.620989359005762 na atividade C
# Cliente 146 esperou 0.0 na fila da atividade C
# Cliente 146 gastou 1.9717077935908947 na atividade C
# Cliente 147 esperou 0.0 na fila da atividade C
# Cliente 147 gastou 5.174390423788736 na atividade C
# Cliente 148 esperou 0.0 na fila da atividade C
# Cliente 148 gastou 6.562342273315608 na atividade C
# Cliente 149 esperou 0.0 na fila da atividade C
# Cliente 149 gastou 16.961378318800826 na atividade C
# Cliente 150 esperou 8.961378318800826 na fila da atividade C
# Cliente 150 gastou 7.4564029927269075 na atividade C
# Cliente 151 esperou 8.417781311527733 na fila da atividade C
# Cliente 151 gastou 0.7629044528948725 na atividade C
# Cliente 152 esperou 1.1806857644226056 na fila da atividade C
# Cliente 152 gastou 1.0358195511676058 na atividade C
# Cliente 153 esperou 0.0 na fila da atividade C
# Cliente 153 gastou 5.480500456961408 na atividade C
# Cliente 154 esperou 0.0 na fila da atividade C
# Cliente 154 gastou 1.0367059646453072 na atividade C
# Cliente 155 esperou 0.0 na fila da atividade C
# Cliente 155 gastou 0.11757476248362764 na atividade C
# Cliente 156 esperou 0.0 na fila da atividade C
# Cliente 156 gastou 3.2357853255482496 na atividade C
# Cliente 157 esperou 0.0 na fila da atividade C
# Cliente 157 gastou 0.3913704212009179 na atividade C
# Cliente 158 esperou 0.0 na fila da atividade C
# Cliente 158 gastou 0.6669597928632811 na atividade C
# Cliente 159 esperou 0.0 na fila da atividade C
# Cliente 159 gastou 19.503232686141928 na atividade C
# Cliente 160 esperou 11.503232686141928 na fila da atividade C
# Cliente 160 gastou 0.7229695350902148 na atividade C
# Cliente 161 esperou 4.226202221232143 na fila da atividade C
# Cliente 161 gastou 3.426098595595704 na atividade C
# Cliente 162 esperou 0.0 na fila da atividade C
# Cliente 162 gastou 1.5179597017095148 na atividade C
# Cliente 163 esperou 0.0 na fila da atividade C
# Cliente 163 gastou 8.381093589407556 na atividade C
# Cliente 164 esperou 0.38109358940755556 na fila da atividade C
# Cliente 164 gastou 1.4597597870049412 na atividade C
# Cliente 165 esperou 0.0 na fila da atividade C
# Cliente 165 gastou 1.7054532577794816 na atividade C
# Cliente 166 esperou 0.0 na fila da atividade C
# Cliente 166 gastou 5.384785034716742 na atividade C
# Cliente 167 esperou 0.0 na fila da atividade C
# Cliente 167 gastou 8.937237765243253 na atividade C
# Cliente 168 esperou 0.9372377652432533 na fila da atividade C
# Cliente 168 gastou 1.6539193836638333 na atividade C
# Cliente 169 esperou 0.0 na fila da atividade C
# Cliente 169 gastou 9.286316992659522 na atividade C
# Cliente 170 esperou 1.286316992659522 na fila da atividade C
# Cliente 170 gastou 12.729449068582198 na atividade C
# Cliente 171 esperou 6.01576606124172 na fila da atividade C
# Cliente 171 gastou 17.97880895714843 na atividade C
# Cliente 172 esperou 15.994575018390151 na fila da atividade C
# Cliente 172 gastou 2.316203672301299 na atividade C
# Cliente 173 esperou 10.31077869069145 na fila da atividade C
# Cliente 173 gastou 1.8683793569502996 na atividade C
# Cliente 174 esperou 4.179158047641749 na fila da atividade C
# Cliente 174 gastou 7.548288876658717 na atividade C
# Cliente 175 esperou 3.727446924300466 na fila da atividade C
# Cliente 175 gastou 0.18064368974614808 na atividade C
# Cliente 176 esperou 0.0 na fila da atividade C
# Cliente 176 gastou 2.6047794433018225 na atividade C
# Cliente 177 esperou 0.0 na fila da atividade C
# Cliente 177 gastou 0.027501473188294767 na atividade C
# Cliente 178 esperou 0.0 na fila da atividade C
# Cliente 178 gastou 2.000447354436801 na atividade C
# Cliente 179 esperou 0.0 na fila da atividade C
# Cliente 179 gastou 6.2880843953016665 na atividade C
# Cliente 180 esperou 0.0 na fila da atividade C
# Cliente 180 gastou 13.174277820375437 na atividade C
# Cliente 181 esperou 5.174277820375437 na fila da atividade C
# Cliente 181 gastou 0.13045875122247708 na atividade C
# Cliente 182 esperou 0.0 na fila da atividade C
# Cliente 182 gastou 1.995959649191036 na atividade C
# Cliente 183 esperou 0.0 na fila da atividade C
# Cliente 183 gastou 3.466842101783868 na atividade C
# Cliente 184 esperou 0.0 na fila da atividade C
# Cliente 184 gastou 0.554433405550526 na atividade C
# Cliente 185 esperou 0.0 na fila da atividade C
# Cliente 185 gastou 1.4953896045906276 na atividade C
# Cliente 186 esperou 0.0 na fila da atividade C
# Cliente 186 gastou 9.24101637680883 na atividade C
# Cliente 187 esperou 1.2410163768088296 na fila da atividade C
# Cliente 187 gastou 16.05632116816446 na atividade C
# Cliente 188 esperou 9.297337544973288 na fila da atividade C
# Cliente 188 gastou 4.942287385029431 na atividade C
# Cliente 189 esperou 6.239624930002719 na fila da atividade C
# Cliente 189 gastou 1.4159995684071873 na atividade C
# Cliente 190 esperou 0.0 na fila da atividade C
# Cliente 190 gastou 8.01103654871622 na atividade C
# Cliente 191 esperou 0.01103654871621984 na fila da atividade C
# Cliente 191 gastou 7.607626904970857 na atividade C
# Cliente 192 esperou 0.0 na fila da atividade C
# Cliente 192 gastou 2.2609893984820246 na atividade C
# Cliente 193 esperou 0.0 na fila da atividade C
# Cliente 193 gastou 0.8091624704593414 na atividade C
# Cliente 194 esperou 0.0 na fila da atividade C
# Cliente 194 gastou 2.6345119419825096 na atividade C
# Cliente 195 esperou 0.0 na fila da atividade C
# Cliente 195 gastou 9.718094821680097 na atividade C
# Cliente 196 esperou 1.718094821680097 na fila da atividade C
# Cliente 196 gastou 5.014986700000463 na atividade C
# Cliente 197 esperou 0.0 na fila da atividade C
# Cliente 197 gastou 3.292671611593505 na atividade C
# Cliente 198 esperou 0.0 na fila da atividade C
# Cliente 198 gastou 10.995343731599405 na atividade C
# Cliente 199 esperou 2.995343731599405 na fila da atividade C
# Cliente 199 gastou 3.032044511894128 na atividade C
# Cliente 200 esperou 0.0 na fila da atividade C
# Cliente 200 gastou 7.170306214803077 na atividade C
# Cliente 201 esperou 0.0 na fila da atividade C
# Cliente 201 gastou 1.570234709652368 na atividade C
# Cliente 202 esperou 0.0 na fila da atividade C
# Cliente 202 gastou 2.4002160170168736 na atividade C
# Cliente 203 esperou 0.0 na fila da atividade C
# Cliente 203 gastou 6.221182542811675 na atividade C
# Cliente 204 esperou 0.0 na fila da atividade C
# Cliente 204 gastou 10.673849392450165 na atividade C
# Cliente 205 esperou 2.6738493924501654 na fila da atividade C
# Cliente 205 gastou 1.000583028742767 na atividade C
# Cliente 206 esperou 0.0 na fila da atividade C
# Cliente 206 gastou 5.4487031975018 na atividade C
# Cliente 207 esperou 0.0 na fila da atividade C
# Cliente 207 gastou 1.589614858153027 na atividade C
# Cliente 208 esperou 0.0 na fila da atividade C
# Cliente 208 gastou 7.606430595428037 na atividade C
# Cliente 209 esperou 0.0 na fila da atividade C
# Cliente 209 gastou 4.709075417443046 na atividade C
# Cliente 210 esperou 0.0 na fila da atividade C
# Cliente 210 gastou 0.35651621737156347 na atividade C
# Cliente 211 esperou 0.0 na fila da atividade C
# Cliente 211 gastou 6.656814865865954 na atividade C
# Cliente 212 esperou 0.0 na fila da atividade C
# Cliente 212 gastou 1.4841174738651262 na atividade C
# Cliente 213 esperou 0.0 na fila da atividade C
# Cliente 213 gastou 19.94752633774874 na atividade C
# Cliente 214 esperou 11.94752633774874 na fila da atividade C
# Cliente 214 gastou 0.8973185534816821 na atividade C
# Cliente 215 esperou 4.844844891230423 na fila da atividade C
# Cliente 215 gastou 4.09156927952904 na atividade C
# Cliente 216 esperou 0.9364141707594626 na fila da atividade C
# Cliente 216 gastou 3.06413212298321 na atividade C
# Cliente 217 esperou 0.0 na fila da atividade C
# Cliente 217 gastou 4.565483797807474 na atividade C
# Cliente 218 esperou 0.0 na fila da atividade C
# Cliente 218 gastou 11.846986031217511 na atividade C
# Cliente 219 esperou 3.8469860312175115 na fila da atividade C
# Cliente 219 gastou 0.5638830935806709 na atividade C
# Cliente 220 esperou 0.0 na fila da atividade C
# Cliente 220 gastou 0.6130204732146467 na atividade C
# Cliente 221 esperou 0.0 na fila da atividade C
# Cliente 221 gastou 8.002125721713355 na atividade C
# Cliente 222 esperou 0.002125721713355233 na fila da atividade C
# Cliente 222 gastou 8.68283670041842 na atividade C
# Cliente 223 esperou 0.6849624221317754 na fila da atividade C
# Cliente 223 gastou 10.585842218008338 na atividade C
# Cliente 224 esperou 3.2708046401401134 na fila da atividade C
# Cliente 224 gastou 4.497995108709574 na atividade C
# Cliente 225 esperou 0.0 na fila da atividade C
# Cliente 225 gastou 7.85808030116732 na atividade C
# Cliente 226 esperou 0.0 na fila da atividade C
# Cliente 226 gastou 6.184415965261223 na atividade C
# Cliente 227 esperou 0.0 na fila da atividade C
# Cliente 227 gastou 1.2496731884000383 na atividade C
# Cliente 228 esperou 0.0 na fila da atividade C
# Cliente 228 gastou 0.33723966283696427 na atividade C
# Cliente 229 esperou 0.0 na fila da atividade C
# Cliente 229 gastou 3.4682865737347583 na atividade C
# Cliente 230 esperou 0.0 na fila da atividade C
# Cliente 230 gastou 2.355727136501173 na atividade C
# Cliente 231 esperou 0.0 na fila da atividade C
# Cliente 231 gastou 3.168086726351248 na atividade C
# Cliente 232 esperou 0.0 na fila da atividade C
# Cliente 232 gastou 8.45903481323785 na atividade C
# Cliente 233 esperou 0.45903481323784945 na fila da atividade C
# Cliente 233 gastou 1.3600762979137926 na atividade C
# Cliente 234 esperou 0.0 na fila da atividade C
# Cliente 234 gastou 2.4948344830847873 na atividade C
# Cliente 235 esperou 0.0 na fila da atividade C
# Cliente 235 gastou 4.055235056735 na atividade C
# Cliente 236 esperou 0.0 na fila da atividade C
# Cliente 236 gastou 0.4385485137465821 na atividade C
# Cliente 237 esperou 0.0 na fila da atividade C
# Cliente 237 gastou 1.901922137303245 na atividade C
# Cliente 238 esperou 0.0 na fila da atividade C
# Cliente 238 gastou 6.342808798764281 na atividade C
# Cliente 239 esperou 0.0 na fila da atividade C
# Cliente 239 gastou 1.824266396678695 na atividade C
# Cliente 240 esperou 0.0 na fila da atividade C
# Cliente 240 gastou 5.174873460709932 na atividade C
# Cliente 241 esperou 0.0 na fila da atividade C
# Cliente 241 gastou 3.6987411500101643 na atividade C
# Cliente 242 esperou 0.0 na fila da atividade C
# Cliente 242 gastou 0.41475379083954067 na atividade C
# Cliente 243 esperou 0.0 na fila da atividade C
# Cliente 243 gastou 1.0651375056179404 na atividade C
# Cliente 244 esperou 0.0 na fila da atividade C
# Cliente 244 gastou 11.274942533769035 na atividade C
# Cliente 245 esperou 3.2749425337690354 na fila da atividade C
# Cliente 245 gastou 3.4856077395056673 na atividade C
# Cliente 246 esperou 0.0 na fila da atividade C
# Cliente 246 gastou 2.4818112694001684 na atividade C
# Cliente 247 esperou 0.0 na fila da atividade C
# Cliente 247 gastou 3.673692874098151 na atividade C
# Cliente 248 esperou 0.0 na fila da atividade C
# Cliente 248 gastou 2.855592077895153 na atividade C
# Cliente 249 esperou 0.0 na fila da atividade C
# Cliente 249 gastou 0.4911506330188331 na atividade C
# Cliente 250 esperou 0.0 na fila da atividade C
# Cliente 250 gastou 1.307885859713224 na atividade C
# Cliente 251 esperou 0.0 na fila da atividade C
# Cliente 251 gastou 4.217405350491617 na atividade C
# Cliente 252 esperou 0.0 na fila da atividade C
# Cliente 252 gastou 0.49497627537948574 na atividade C
# Cliente 253 esperou 0.0 na fila da atividade C
# Cliente 253 gastou 2.6694703901011962 na atividade C
# Cliente 254 esperou 0.0 na fila da atividade C
# Cliente 254 gastou 4.23202189046242 na atividade C
# Cliente 255 esperou 0.0 na fila da atividade C
# Cliente 255 gastou 1.2089628873234233 na atividade C
# Cliente 256 esperou 0.0 na fila da atividade C
# Cliente 256 gastou 1.4629604221140653 na atividade C
# Cliente 257 esperou 0.0 na fila da atividade C
# Cliente 257 gastou 1.3567097070376803 na atividade C
# Cliente 258 esperou 0.0 na fila da atividade C
# Cliente 258 gastou 1.2239864359148669 na atividade C
# Cliente 259 esperou 0.0 na fila da atividade C
# Cliente 259 gastou 2.0880867692062566 na atividade C
# Cliente 260 esperou 0.0 na fila da atividade C
# Cliente 260 gastou 21.14892092254786 na atividade C
# Cliente 261 esperou 13.148920922547859 na fila da atividade C
# Cliente 261 gastou 0.3843006858355693 na atividade C
# Cliente 262 esperou 5.533221608383428 na fila da atividade C
# Cliente 262 gastou 2.5365005863582155 na atividade C
# Cliente 263 esperou 0.06972219474164376 na fila da atividade C
# Cliente 263 gastou 2.4345990979272756 na atividade C
# Cliente 264 esperou 0.0 na fila da atividade C
# Cliente 264 gastou 7.670590509894282 na atividade C
# Cliente 265 esperou 0.0 na fila da atividade C
# Cliente 265 gastou 3.1556135148075555 na atividade C
# Cliente 266 esperou 0.0 na fila da atividade C
# Cliente 266 gastou 0.8474088972948266 na atividade C
# Cliente 267 esperou 0.0 na fila da atividade C
# Cliente 267 gastou 5.863261439931648 na atividade C
# Cliente 268 esperou 0.0 na fila da atividade C
# Cliente 268 gastou 17.929190152844058 na atividade C
# Cliente 269 esperou 9.929190152844058 na fila da atividade C
# Cliente 269 gastou 2.3299964838779488 na atividade C
# Cliente 270 esperou 4.259186636722006 na fila da atividade C
# Cliente 270 gastou 4.439247013739532 na atividade C
# Cliente 271 esperou 0.6984336504615385 na fila da atividade C
# Cliente 271 gastou 5.819155521448465 na atividade C
# Cliente 272 esperou 0.0 na fila da atividade C
# Cliente 272 gastou 2.5566170176989544 na atividade C
# Cliente 273 esperou 0.0 na fila da atividade C
# Cliente 273 gastou 0.5920223487269141 na atividade C
# Cliente 274 esperou 0.0 na fila da atividade C
# Cliente 274 gastou 3.261810251179668 na atividade C
# Cliente 275 esperou 0.0 na fila da atividade C
# Cliente 275 gastou 1.0506635777032898 na atividade C
# Cliente 276 esperou 0.0 na fila da atividade C
# Cliente 276 gastou 6.928640982963316 na atividade C
# Cliente 277 esperou 0.0 na fila da atividade C
# Cliente 277 gastou 5.046833678920393 na atividade C
# Cliente 278 esperou 0.0 na fila da atividade C
# Cliente 278 gastou 0.672718516916575 na atividade C
# Cliente 279 esperou 0.0 na fila da atividade C
# Cliente 279 gastou 0.2562476524253725 na atividade C
# Cliente 280 esperou 0.0 na fila da atividade C
# Cliente 280 gastou 3.1463020134592625 na atividade C
# Cliente 281 esperou 0.0 na fila da atividade C
# Cliente 281 gastou 3.4706016042573538 na atividade C
# Cliente 282 esperou 0.0 na fila da atividade C
# Cliente 282 gastou 6.604264064212202 na atividade C
# Cliente 283 esperou 0.0 na fila da atividade C
# Cliente 283 gastou 7.936994592923384 na atividade C
# Cliente 284 esperou 0.0 na fila da atividade C
# Cliente 284 gastou 0.47394486639905153 na atividade C
# Cliente 285 esperou 0.0 na fila da atividade C
# Cliente 285 gastou 1.1516258894803286 na atividade C
# Cliente 286 esperou 0.0 na fila da atividade C
# Cliente 286 gastou 3.935893159862644 na atividade C
# Cliente 287 esperou 0.0 na fila da atividade C
# Cliente 287 gastou 3.436214700248911 na atividade C
# Cliente 288 esperou 0.0 na fila da atividade C
# Cliente 288 gastou 8.957240963297863 na atividade C
# Cliente 289 esperou 0.9572409632978633 na fila da atividade C
# Cliente 289 gastou 3.2334521235088687 na atividade C
# Cliente 290 esperou 0.0 na fila da atividade C
# Cliente 290 gastou 7.824364706875258 na atividade C
# Cliente 291 esperou 0.0 na fila da atividade C
# Cliente 291 gastou 0.3315514569753759 na atividade C
# Cliente 292 esperou 0.0 na fila da atividade C
# Cliente 292 gastou 12.790025392590906 na atividade C
# Cliente 293 esperou 4.7900253925909055 na fila da atividade C
# Cliente 293 gastou 25.32332841683501 na atividade C
# Cliente 294 esperou 22.113353809425917 na fila da atividade C
# Cliente 294 gastou 3.6142031917747772 na atividade C
# Cliente 295 esperou 17.727557001200694 na fila da atividade C
# Cliente 295 gastou 7.239027786429233 na atividade C
# Cliente 296 esperou 16.966584787629927 na fila da atividade C
# Cliente 296 gastou 0.8139049849642106 na atividade C
# Cliente 297 esperou 9.780489772594137 na fila da atividade C
# Cliente 297 gastou 11.333658004761219 na atividade C
# Cliente 298 esperou 13.114147777355356 na fila da atividade C
# Cliente 298 gastou 0.18056619527624207 na atividade C
# Cliente 299 esperou 5.294713972631598 na fila da atividade C
# Cliente 299 gastou 2.986621576388643 na atividade C
# Cliente 300 esperou 0.28133554902024116 na fila da atividade C
# Cliente 300 gastou 0.38674042689171984 na atividade C
# Cliente 301 esperou 0.0 na fila da atividade C
# Cliente 301 gastou 0.6929927835631133 na atividade C
# Cliente 302 esperou 0.0 na fila da atividade C
# Cliente 302 gastou 7.227733246990283 na atividade C
# Cliente 303 esperou 0.0 na fila da atividade C
# Cliente 303 gastou 1.6478441386902887 na atividade C
# Cliente 304 esperou 0.0 na fila da atividade C
# Cliente 304 gastou 0.5063773786841921 na atividade C
# Cliente 305 esperou 0.0 na fila da atividade C
# Cliente 305 gastou 3.0693812126783087 na atividade C
# Cliente 306 esperou 0.0 na fila da atividade C
# Cliente 306 gastou 1.1333463513337847 na atividade C
# Cliente 307 esperou 0.0 na fila da atividade C
# Cliente 307 gastou 2.587398159199438 na atividade C
# Cliente 308 esperou 0.0 na fila da atividade C
# Cliente 308 gastou 3.2827572716150826 na atividade C
# Cliente 309 esperou 0.0 na fila da atividade C
# Cliente 309 gastou 3.444632091186577 na atividade C
# Cliente 310 esperou 0.0 na fila da atividade C
# Cliente 310 gastou 2.669513196632579 na atividade C
# Cliente 311 esperou 0.0 na fila da atividade C
# Cliente 311 gastou 0.6436853779832745 na atividade C
# Cliente 312 esperou 0.0 na fila da atividade C
# Cliente 312 gastou 0.6708550696439488 na atividade C
# Cliente 313 esperou 0.0 na fila da atividade C
# Cliente 313 gastou 5.830390727017857 na atividade C
# Cliente 314 esperou 0.0 na fila da atividade C
# Cliente 314 gastou 17.54979976019331 na atividade C
# Cliente 315 esperou 9.54979976019331 na fila da atividade C
# Cliente 315 gastou 7.2616439051766974 na atividade C
# Cliente 316 esperou 8.811443665370007 na fila da atividade C
# Cliente 316 gastou 0.7886957185219217 na atividade C
# Cliente 317 esperou 1.6001393838919284 na fila da atividade C
# Cliente 317 gastou 13.032800509479785 na atividade C
# Cliente 318 esperou 6.632939893371713 na fila da atividade C
# Cliente 318 gastou 2.4561335551584307 na atividade C
# Cliente 319 esperou 1.0890734485301437 na fila da atividade C
# Cliente 319 gastou 9.90596099975437 na atividade C
# Cliente 320 esperou 2.995034448284514 na fila da atividade C
# Cliente 320 gastou 6.205910451890304 na atividade C
# Cliente 321 esperou 1.200944900174818 na fila da atividade C
# Cliente 321 gastou 11.23539419221288 na atividade C
# Cliente 322 esperou 4.436339092387698 na fila da atividade C
# Cliente 322 gastou 3.0348189363635356 na atividade C
# Cliente 323 esperou 0.0 na fila da atividade C
# Cliente 323 gastou 1.3107636416161768 na atividade C
# Cliente 324 esperou 0.0 na fila da atividade C
# Cliente 324 gastou 0.7101730715412486 na atividade C
# Cliente 325 esperou 0.0 na fila da atividade C
# Cliente 325 gastou 8.501635877036279 na atividade C
# Cliente 326 esperou 0.5016358770362785 na fila da atividade C
# Cliente 326 gastou 7.610035737456201 na atividade C
# Cliente 327 esperou 0.11167161449247942 na fila da atividade C
# Cliente 327 gastou 3.4312542169518565 na atividade C
# Cliente 328 esperou 0.0 na fila da atividade C
# Cliente 328 gastou 31.62768269993194 na atividade C
# Cliente 329 esperou 23.62768269993194 na fila da atividade C
# Cliente 329 gastou 10.654559451307705 na atividade C
# Cliente 330 esperou 26.282242151239643 na fila da atividade C
# Cliente 330 gastou 2.518400560178179 na atividade C
# Cliente 331 esperou 20.800642711417822 na fila da atividade C
# Cliente 331 gastou 3.905628019849246 na atividade C
# Cliente 332 esperou 16.706270731267068 na fila da atividade C
# Cliente 332 gastou 9.62511157778863 na atividade C
# Cliente 333 esperou 18.331382309055698 na fila da atividade C
# Cliente 333 gastou 1.2362074151246816 na atividade C
# Cliente 334 esperou 11.56758972418038 na fila da atividade C
# Cliente 334 gastou 2.0988901076652837 na atividade C
# Cliente 335 esperou 5.666479831845663 na fila da atividade C
# Cliente 335 gastou 0.9005712156922527 na atividade C
# Cliente 336 esperou 0.0 na fila da atividade C
# Cliente 336 gastou 10.644447090146059 na atividade C
# Cliente 337 esperou 2.644447090146059 na fila da atividade C
# Cliente 337 gastou 1.985335643763392 na atividade C
# Cliente 338 esperou 0.0 na fila da atividade C
# Cliente 338 gastou 4.896979161034778 na atividade C
# Cliente 339 esperou 0.0 na fila da atividade C
# Cliente 339 gastou 1.5325472146678294 na atividade C
# Cliente 340 esperou 0.0 na fila da atividade C
# Cliente 340 gastou 4.747953086578036 na atividade C
# Cliente 341 esperou 0.0 na fila da atividade C
# Cliente 341 gastou 1.7200772866967782 na atividade C
# Cliente 342 esperou 0.0 na fila da atividade C
# Cliente 342 gastou 2.1091487943517677 na atividade C
# Cliente 343 esperou 0.0 na fila da atividade C
# Cliente 343 gastou 1.9323032370380133 na atividade C
# Cliente 344 esperou 0.0 na fila da atividade C
# Cliente 344 gastou 0.10679808147187941 na atividade C
# Cliente 345 esperou 0.0 na fila da atividade C
# Cliente 345 gastou 5.829131736718409 na atividade C
# Cliente 346 esperou 0.0 na fila da atividade C
# Cliente 346 gastou 6.911190694957895 na atividade C
# Cliente 347 esperou 0.0 na fila da atividade C
# Cliente 347 gastou 2.474372580897125 na atividade C
# Cliente 348 esperou 0.0 na fila da atividade C
# Cliente 348 gastou 10.186672117457874 na atividade C
# Cliente 349 esperou 2.1866721174578743 na fila da atividade C
# Cliente 349 gastou 4.843035933924966 na atividade C
# Cliente 350 esperou 0.0 na fila da atividade C
# Cliente 350 gastou 2.9293569254209615 na atividade C
# Cliente 351 esperou 0.0 na fila da atividade C
# Cliente 351 gastou 10.660285226827 na atividade C
# Cliente 352 esperou 2.660285226827 na fila da atividade C
# Cliente 352 gastou 2.986512518058589 na atividade C
# Cliente 353 esperou 0.0 na fila da atividade C
# Cliente 353 gastou 0.7411131033236416 na atividade C
# Cliente 354 esperou 0.0 na fila da atividade C
# Cliente 354 gastou 3.051571620341747 na atividade C
# Cliente 355 esperou 0.0 na fila da atividade C
# Cliente 355 gastou 3.776893474694589 na atividade C
# Cliente 356 esperou 0.0 na fila da atividade C
# Cliente 356 gastou 1.3105146914322177 na atividade C
# Cliente 357 esperou 0.0 na fila da atividade C
# Cliente 357 gastou 3.264551706462953 na atividade C
# Cliente 358 esperou 0.0 na fila da atividade C
# Cliente 358 gastou 3.742483004902624 na atividade C
# Cliente 359 esperou 0.0 na fila da atividade C
# Cliente 359 gastou 2.92039687428678 na atividade C
# Cliente 360 esperou 0.0 na fila da atividade C
# Cliente 360 gastou 8.069002437066047 na atividade C
# Cliente 361 esperou 0.0690024370660467 na fila da atividade C
# Cliente 361 gastou 7.917423455788139 na atividade C
# Cliente 362 esperou 0.0 na fila da atividade C
# Cliente 362 gastou 6.288406334469528 na atividade C
# Cliente 363 esperou 0.0 na fila da atividade C
# Cliente 363 gastou 4.595947207048084 na atividade C
# Cliente 364 esperou 0.0 na fila da atividade C
# Cliente 364 gastou 2.1093500938827674 na atividade C
# Cliente 365 esperou 0.0 na fila da atividade C
# Cliente 365 gastou 4.96765738707154 na atividade C
# Cliente 366 esperou 0.0 na fila da atividade C
# Cliente 366 gastou 0.7956467732897181 na atividade C
# Cliente 367 esperou 0.0 na fila da atividade C
# Cliente 367 gastou 1.7805961249787288 na atividade C
# Cliente 368 esperou 0.0 na fila da atividade C
# Cliente 368 gastou 2.833142735318688 na atividade C
# Cliente 369 esperou 0.0 na fila da atividade C
# Cliente 369 gastou 4.840662659165446 na atividade C
# Cliente 370 esperou 0.0 na fila da atividade C
# Cliente 370 gastou 4.914784899036022 na atividade C
# Cliente 371 esperou 0.0 na fila da atividade C
# Cliente 371 gastou 1.4910432617607512 na atividade C
# Cliente 372 esperou 0.0 na fila da atividade C
# Cliente 372 gastou 18.735176358342414 na atividade C
# Cliente 373 esperou 10.735176358342414 na fila da atividade C
# Cliente 373 gastou 3.663169584515799 na atividade C
# Cliente 374 esperou 6.398345942858214 na fila da atividade C
# Cliente 374 gastou 2.7989054644199314 na atividade C
# Cliente 375 esperou 1.197251407278145 na fila da atividade C
# Cliente 375 gastou 4.2734085004203735 na atividade C
# Cliente 376 esperou 0.0 na fila da atividade C
# Cliente 376 gastou 3.0258676168600687 na atividade C
# Cliente 377 esperou 0.0 na fila da atividade C
# Cliente 377 gastou 5.4138261608177345 na atividade C
# Cliente 378 esperou 0.0 na fila da atividade C
# Cliente 378 gastou 1.5956947160225354 na atividade C
# Cliente 379 esperou 0.0 na fila da atividade C
# Cliente 379 gastou 4.476788393757033 na atividade C
# Cliente 380 esperou 0.0 na fila da atividade C
# Cliente 380 gastou 15.110192071791516 na atividade C
# Cliente 381 esperou 7.110192071791516 na fila da atividade C
# Cliente 381 gastou 5.920625136465787 na atividade C
# Cliente 382 esperou 5.030817208257304 na fila da atividade C
# Cliente 382 gastou 11.824207404921253 na atividade C
# Cliente 383 esperou 8.855024613178557 na fila da atividade C
# Cliente 383 gastou 4.832871141228225 na atividade C
# Cliente 384 esperou 5.687895754406782 na fila da atividade C
# Cliente 384 gastou 6.844576340128697 na atividade C
# Cliente 385 esperou 4.532472094535478 na fila da atividade C
# Cliente 385 gastou 0.7137279212420253 na atividade C
# Cliente 386 esperou 0.0 na fila da atividade C
# Cliente 386 gastou 1.1033085851436226 na atividade C
# Cliente 387 esperou 0.0 na fila da atividade C
# Cliente 387 gastou 1.5521762435851088 na atividade C
# Cliente 388 esperou 0.0 na fila da atividade C
# Cliente 388 gastou 4.0832877448342515 na atividade C
# Cliente 389 esperou 0.0 na fila da atividade C
# Cliente 389 gastou 2.4000727037305296 na atividade C
# Cliente 390 esperou 0.0 na fila da atividade C
# Cliente 390 gastou 1.8830957395161931 na atividade C
# Cliente 391 esperou 0.0 na fila da atividade C
# Cliente 391 gastou 1.361864969915132 na atividade C
# Cliente 392 esperou 0.0 na fila da atividade C
# Cliente 392 gastou 2.0059840658855137 na atividade C
# Cliente 393 esperou 0.0 na fila da atividade C
# Cliente 393 gastou 2.414879403705072 na atividade C
# Cliente 394 esperou 0.0 na fila da atividade C
# Cliente 394 gastou 8.308410852544966 na atividade C
# Cliente 395 esperou 0.3084108525449665 na fila da atividade C
# Cliente 395 gastou 1.1260225151204395 na atividade C
# Cliente 396 esperou 0.0 na fila da atividade C
# Cliente 396 gastou 1.7416818577030426 na atividade C
# Cliente 397 esperou 0.0 na fila da atividade C
# Cliente 397 gastou 5.008639941864203 na atividade C
# Cliente 398 esperou 0.0 na fila da atividade C
# Cliente 398 gastou 5.8654959252658045 na atividade C
# Cliente 399 esperou 0.0 na fila da atividade C
# Cliente 399 gastou 2.677991661503711 na atividade C
# Cliente 400 esperou 0.0 na fila da atividade C
# Cliente 400 gastou 3.075215859162654 na atividade C
# Cliente 401 esperou 0.0 na fila da atividade C
# Cliente 401 gastou 1.255488102484378 na atividade C
# Cliente 402 esperou 0.0 na fila da atividade C
# Cliente 402 gastou 3.527978170908227 na atividade C
# Cliente 403 esperou 0.0 na fila da atividade C
# Cliente 403 gastou 1.5694820702105972 na atividade C
# Cliente 404 esperou 0.0 na fila da atividade C
# Cliente 404 gastou 0.7572107062228497 na atividade C
# Cliente 405 esperou 0.0 na fila da atividade C
# Cliente 405 gastou 4.02967976733953 na atividade C
# Cliente 406 esperou 0.0 na fila da atividade C
# Cliente 406 gastou 13.938607606079131 na atividade C
# Cliente 407 esperou 5.938607606079131 na fila da atividade C
# Cliente 407 gastou 3.807828710861031 na atividade C
# Cliente 408 esperou 1.7464363169401622 na fila da atividade C
# Cliente 408 gastou 5.332745468246685 na atividade C
# Cliente 409 esperou 0.0 na fila da atividade C
# Cliente 409 gastou 6.4748362833011015 na atividade C
# Cliente 410 esperou 0.0 na fila da atividade C
# Cliente 410 gastou 1.0024985365107568 na atividade C
# Cliente 411 esperou 0.0 na fila da atividade C
# Cliente 411 gastou 1.2023392885294015 na atividade C
# Cliente 412 esperou 0.0 na fila da atividade C
# Cliente 412 gastou 4.50651788885807 na atividade C
# Cliente 413 esperou 0.0 na fila da atividade C
# Cliente 413 gastou 11.071554944952368 na atividade C
# Cliente 414 esperou 3.071554944952368 na fila da atividade C
# Cliente 414 gastou 13.583506699810641 na atividade C
# Cliente 415 esperou 8.655061644763009 na fila da atividade C
# Cliente 415 gastou 3.8494873254467166 na atividade C
# Cliente 416 esperou 4.504548970209726 na fila da atividade C
# Cliente 416 gastou 6.228538199007289 na atividade C
# Cliente 417 esperou 2.733087169217015 na fila da atividade C
# Cliente 417 gastou 1.3561532160520073 na atividade C
# Cliente 418 esperou 0.0 na fila da atividade C
# Cliente 418 gastou 2.704502177827635 na atividade C
# Cliente 419 esperou 0.0 na fila da atividade C
# Cliente 419 gastou 14.447554226269403 na atividade C
# Cliente 420 esperou 6.447554226269403 na fila da atividade C
# Cliente 420 gastou 0.18686512049089288 na atividade C
# Cliente 421 esperou 0.0 na fila da atividade C
# Cliente 421 gastou 2.175576210658619 na atividade C
# Cliente 422 esperou 0.0 na fila da atividade C
# Cliente 422 gastou 1.9913229227495322 na atividade C
# Cliente 423 esperou 0.0 na fila da atividade C
# Cliente 423 gastou 4.004427098721862 na atividade C
# Cliente 424 esperou 0.0 na fila da atividade C
# Cliente 424 gastou 3.983631880660141 na atividade C
# Cliente 425 esperou 0.0 na fila da atividade C
# Cliente 425 gastou 3.109607927622619 na atividade C
# Cliente 426 esperou 0.0 na fila da atividade C
# Cliente 426 gastou 10.539219273513481 na atividade C
# Cliente 427 esperou 2.5392192735134813 na fila da atividade C
# Cliente 427 gastou 1.0375235774940847 na atividade C
# Cliente 428 esperou 0.0 na fila da atividade C
# Cliente 428 gastou 3.5424772369569837 na atividade C
# Cliente 429 esperou 0.0 na fila da atividade C
# Cliente 429 gastou 12.659700467399489 na atividade C
# Cliente 430 esperou 4.659700467399489 na fila da atividade C
# Cliente 430 gastou 5.35898186070699 na atividade C
# Cliente 431 esperou 2.018682328106479 na fila da atividade C
# Cliente 431 gastou 8.335071168622562 na atividade C
# Cliente 432 esperou 2.353753496729041 na fila da atividade C
# Cliente 432 gastou 0.4127812120927956 na atividade C
# Cliente 433 esperou 0.0 na fila da atividade C
# Cliente 433 gastou 4.357107915396227 na atividade C
# Cliente 434 esperou 0.0 na fila da atividade C
# Cliente 434 gastou 0.37825611793459757 na atividade C
# Cliente 435 esperou 0.0 na fila da atividade C
# Cliente 435 gastou 1.9724314012205468 na atividade C
# Cliente 436 esperou 0.0 na fila da atividade C
# Cliente 436 gastou 5.7047450143491005 na atividade C
# Cliente 437 esperou 0.0 na fila da atividade C
# Cliente 437 gastou 1.3193479444521472 na atividade C
# Cliente 438 esperou 0.0 na fila da atividade C
# Cliente 438 gastou 1.3398470572956285 na atividade C
# Cliente 439 esperou 0.0 na fila da atividade C
# Cliente 439 gastou 11.768340571702083 na atividade C
# Cliente 440 esperou 3.7683405717020833 na fila da atividade C
# Cliente 440 gastou 10.660197382972456 na atividade C
# Cliente 441 esperou 6.428537954674539 na fila da atividade C
# Cliente 441 gastou 3.9696887401787535 na atividade C
# Cliente 442 esperou 2.3982266948532924 na fila da atividade C
# Cliente 442 gastou 8.02578261118515 na atividade C
# Cliente 443 esperou 2.4240093060384424 na fila da atividade C
# Cliente 443 gastou 9.620234908410112 na atividade C
# Cliente 444 esperou 4.044244214448554 na fila da atividade C
# Cliente 444 gastou 15.463103646066884 na atividade C
# Cliente 445 esperou 11.507347860515438 na fila da atividade C
# Cliente 445 gastou 0.5865770759792213 na atividade C
# Cliente 446 esperou 4.093924936494659 na fila da atividade C
# Cliente 446 gastou 0.11789490750106779 na atividade C
# Cliente 447 esperou 0.0 na fila da atividade C
# Cliente 447 gastou 1.206400290701822 na atividade C
# Cliente 448 esperou 0.0 na fila da atividade C
# Cliente 448 gastou 2.032171326443404 na atividade C
# Cliente 449 esperou 0.0 na fila da atividade C
# Cliente 449 gastou 1.434046380114978 na atividade C
# Cliente 450 esperou 0.0 na fila da atividade C
# Cliente 450 gastou 2.27214775055927 na atividade C
# Cliente 451 esperou 0.0 na fila da atividade C
# Cliente 451 gastou 7.227180644515556 na atividade C
# Cliente 452 esperou 0.0 na fila da atividade C
# Cliente 452 gastou 8.976900235160883 na atividade C
# Cliente 453 esperou 0.9769002351608833 na fila da atividade C
# Cliente 453 gastou 9.526932583382404 na atividade C
# Cliente 454 esperou 2.5038328185432874 na fila da atividade C
# Cliente 454 gastou 1.0214062846857814 na atividade C
# Cliente 455 esperou 0.0 na fila da atividade C
# Cliente 455 gastou 5.244227116676939 na atividade C
# Cliente 456 esperou 0.0 na fila da atividade C
# Cliente 456 gastou 16.623457164449974 na atividade C
# Cliente 457 esperou 8.623457164449974 na fila da atividade C
# Cliente 457 gastou 1.5846294878729168 na atividade C
# Cliente 458 esperou 2.2080866523228906 na fila da atividade C
# Cliente 458 gastou 0.7420517626956098 na atividade C
# Cliente 459 esperou 0.0 na fila da atividade C
# Cliente 459 gastou 1.866554129893757 na atividade C
# Cliente 460 esperou 0.0 na fila da atividade C
# Cliente 460 gastou 4.9975558392520725 na atividade C
# ...
# Cliente 7347 gastou 9.847848571087525 na atividade C
# Cliente 7348 esperou 7.032200724861468 na fila da atividade C
# Cliente 7348 gastou 0.8239279390181764 na atividade C
# Cliente 7349 esperou 0.0 na fila da atividade C
# Cliente 7349 gastou 0.5171623729474959 na atividade C
# Cliente 7350 esperou 0.0 na fila da atividade C
# Cliente 7350 gastou 1.1889173618255882 na atividade C
# Cliente 7351 esperou 0.0 na fila da atividade C
# Cliente 7351 gastou 4.0002867423099815 na atividade C
# Cliente 7352 esperou 0.0 na fila da atividade C
# Cliente 7352 gastou 1.1260895905143116 na atividade C
# Cliente 7353 esperou 0.0 na fila da atividade C
# Cliente 7353 gastou 2.6288544100607396 na atividade C
# Cliente 7354 esperou 0.0 na fila da atividade C
# Cliente 7354 gastou 2.6463879190268926 na atividade C
# Cliente 7355 esperou 0.0 na fila da atividade C
# Cliente 7355 gastou 6.084351134981262 na atividade C
# Cliente 7356 esperou 0.0 na fila da atividade C
# Cliente 7356 gastou 1.846618440176826 na atividade C
# Cliente 7357 esperou 0.0 na fila da atividade C
# Cliente 7357 gastou 8.382225605710119 na atividade C
# Cliente 7358 esperou 0.38222560571011854 na fila da atividade C
# Cliente 7358 gastou 6.7000739508948755 na atividade C
# Cliente 7359 esperou 0.0 na fila da atividade C
# Cliente 7359 gastou 0.911230303652701 na atividade C
# Cliente 7360 esperou 0.0 na fila da atividade C
# Cliente 7360 gastou 2.3834569860700867 na atividade C
# Cliente 7361 esperou 0.0 na fila da atividade C
# Cliente 7361 gastou 0.5831018584649428 na atividade C
# Cliente 7362 esperou 0.0 na fila da atividade C
# Cliente 7362 gastou 1.0496076605995768 na atividade C
# Cliente 7363 esperou 0.0 na fila da atividade C
# Cliente 7363 gastou 5.636494309968839 na atividade C
# Cliente 7364 esperou 0.0 na fila da atividade C
# Cliente 7364 gastou 15.54877531285456 na atividade C
# Cliente 7365 esperou 7.548775312854559 na fila da atividade C
# Cliente 7365 gastou 3.3864350963922334 na atividade C
# Cliente 7366 esperou 2.9352104092467926 na fila da atividade C
# Cliente 7366 gastou 5.403570756890986 na atividade C
# Cliente 7367 esperou 0.3387811661377782 na fila da atividade C
# Cliente 7367 gastou 9.859752895972633 na atividade C
# Cliente 7368 esperou 2.1985340621104115 na fila da atividade C
# Cliente 7368 gastou 18.03013073070906 na atividade C
# Cliente 7369 esperou 12.228664792819472 na fila da atividade C
# Cliente 7369 gastou 2.276596744908602 na atividade C
# Cliente 7370 esperou 6.5052615377280745 na fila da atividade C
# Cliente 7370 gastou 8.398045082372846 na atividade C
# Cliente 7371 esperou 6.9033066201009206 na fila da atividade C
# Cliente 7371 gastou 2.481229147546401 na atividade C
# Cliente 7372 esperou 1.3845357676473213 na fila da atividade C
# Cliente 7372 gastou 1.4681994867569301 na atividade C
# Cliente 7373 esperou 0.0 na fila da atividade C
# Cliente 7373 gastou 8.835071272616915 na atividade C
# Cliente 7374 esperou 0.8350712726169149 na fila da atividade C
# Cliente 7374 gastou 0.9105012426152825 na atividade C
# Cliente 7375 esperou 0.0 na fila da atividade C
# Cliente 7375 gastou 0.431225564723718 na atividade C
# Cliente 7376 esperou 0.0 na fila da atividade C
# Cliente 7376 gastou 13.957544856406457 na atividade C
# Cliente 7377 esperou 5.957544856406457 na fila da atividade C
# Cliente 7377 gastou 0.4755261781756417 na atividade C
# Cliente 7378 esperou 0.0 na fila da atividade C
# Cliente 7378 gastou 0.03314939478877932 na atividade C
# Cliente 7379 esperou 0.0 na fila da atividade C
# Cliente 7379 gastou 3.109586476959521 na atividade C
# Cliente 7380 esperou 0.0 na fila da atividade C
# Cliente 7380 gastou 1.3710430842547794 na atividade C
# Cliente 7381 esperou 0.0 na fila da atividade C
# Cliente 7381 gastou 1.0793070725994767 na atividade C
# Cliente 7382 esperou 0.0 na fila da atividade C
# Cliente 7382 gastou 1.4109935150190722 na atividade C
# Cliente 7383 esperou 0.0 na fila da atividade C
# Cliente 7383 gastou 2.7844919318304164 na atividade C
# Cliente 7384 esperou 0.0 na fila da atividade C
# Cliente 7384 gastou 7.522851110436022 na atividade C
# Cliente 7385 esperou 0.0 na fila da atividade C
# Cliente 7385 gastou 1.7986844098195434 na atividade C
# Cliente 7386 esperou 0.0 na fila da atividade C
# Cliente 7386 gastou 2.016245535640337 na atividade C
# Cliente 7387 esperou 0.0 na fila da atividade C
# Cliente 7387 gastou 0.6923648799784132 na atividade C
# Cliente 7388 esperou 0.0 na fila da atividade C
# Cliente 7388 gastou 1.4914502680840087 na atividade C
# Cliente 7389 esperou 0.0 na fila da atividade C
# Cliente 7389 gastou 1.7063108215588727 na atividade C
# Cliente 7390 esperou 0.0 na fila da atividade C
# Cliente 7390 gastou 7.799549000141269 na atividade C
# Cliente 7391 esperou 0.0 na fila da atividade C
# Cliente 7391 gastou 0.39546713553136215 na atividade C
# Cliente 7392 esperou 0.0 na fila da atividade C
# Cliente 7392 gastou 4.355230944798677 na atividade C
# Cliente 7393 esperou 0.0 na fila da atividade C
# Cliente 7393 gastou 0.4135674337812816 na atividade C
# Cliente 7394 esperou 0.0 na fila da atividade C
# Cliente 7394 gastou 3.399747983647103 na atividade C
# Cliente 7395 esperou 0.0 na fila da atividade C
# Cliente 7395 gastou 2.3226246080739656 na atividade C
# Cliente 7396 esperou 0.0 na fila da atividade C
# Cliente 7396 gastou 3.2473585438128794 na atividade C
# Cliente 7397 esperou 0.0 na fila da atividade C
# Cliente 7397 gastou 0.6969056481248117 na atividade C
# Cliente 7398 esperou 0.0 na fila da atividade C
# Cliente 7398 gastou 9.800959852997039 na atividade C
# Cliente 7399 esperou 1.800959852997039 na fila da atividade C
# Cliente 7399 gastou 4.036613594580558 na atividade C
# Cliente 7400 esperou 0.0 na fila da atividade C
# Cliente 7400 gastou 3.738945131219225 na atividade C
# Cliente 7401 esperou 0.0 na fila da atividade C
# Cliente 7401 gastou 8.605932690799818 na atividade C
# Cliente 7402 esperou 0.6059326907998184 na fila da atividade C
# Cliente 7402 gastou 5.412246460131428 na atividade C
# Cliente 7403 esperou 0.0 na fila da atividade C
# Cliente 7403 gastou 7.789444244655897 na atividade C
# Cliente 7404 esperou 0.0 na fila da atividade C
# Cliente 7404 gastou 1.1022010907254298 na atividade C
# Cliente 7405 esperou 0.0 na fila da atividade C
# Cliente 7405 gastou 2.980929296303657 na atividade C
# Cliente 7406 esperou 0.0 na fila da atividade C
# Cliente 7406 gastou 6.768963198868732 na atividade C
# Cliente 7407 esperou 0.0 na fila da atividade C
# Cliente 7407 gastou 2.311985920663574 na atividade C
# Cliente 7408 esperou 0.0 na fila da atividade C
# Cliente 7408 gastou 0.7827789292787202 na atividade C
# Cliente 7409 esperou 0.0 na fila da atividade C
# Cliente 7409 gastou 3.3450100187401404 na atividade C
# Cliente 7410 esperou 0.0 na fila da atividade C
# Cliente 7410 gastou 6.838536124261736 na atividade C
# Cliente 7411 esperou 0.0 na fila da atividade C
# Cliente 7411 gastou 6.889370273667737 na atividade C
# Cliente 7412 esperou 0.0 na fila da atividade C
# Cliente 7412 gastou 1.2217792542796815 na atividade C
# Cliente 7413 esperou 0.0 na fila da atividade C
# Cliente 7413 gastou 1.2520207717461744 na atividade C
# Cliente 7414 esperou 0.0 na fila da atividade C
# Cliente 7414 gastou 11.06384653961868 na atividade C
# Cliente 7415 esperou 3.0638465396186803 na fila da atividade C
# Cliente 7415 gastou 0.8901613532943884 na atividade C
# Cliente 7416 esperou 0.0 na fila da atividade C
# Cliente 7416 gastou 7.577249835398106 na atividade C
# Cliente 7417 esperou 0.0 na fila da atividade C
# Cliente 7417 gastou 1.3563024849208887 na atividade C
# Cliente 7418 esperou 0.0 na fila da atividade C
# Cliente 7418 gastou 25.45396203029668 na atividade C
# Cliente 7419 esperou 17.45396203029668 na fila da atividade C
# Cliente 7419 gastou 4.365721927359118 na atividade C
# Cliente 7420 esperou 13.819683957655798 na fila da atividade C
# Cliente 7420 gastou 1.1132518604717916 na atividade C
# Cliente 7421 esperou 6.932935818127589 na fila da atividade C
# Cliente 7421 gastou 0.028273484807868954 na atividade C
# Cliente 7422 esperou 0.0 na fila da atividade C
# Cliente 7422 gastou 2.9207191757814144 na atividade C
# Cliente 7423 esperou 0.0 na fila da atividade C
# Cliente 7423 gastou 1.4715045861303224 na atividade C
# Cliente 7424 esperou 0.0 na fila da atividade C
# Cliente 7424 gastou 2.9577394513544277 na atividade C
# Cliente 7425 esperou 0.0 na fila da atividade C
# Cliente 7425 gastou 6.934886615577852 na atividade C
# Cliente 7426 esperou 0.0 na fila da atividade C
# Cliente 7426 gastou 0.9905588096225983 na atividade C
# Cliente 7427 esperou 0.0 na fila da atividade C
# Cliente 7427 gastou 7.101808247134613 na atividade C
# Cliente 7428 esperou 0.0 na fila da atividade C
# Cliente 7428 gastou 1.6299612946604611 na atividade C
# Cliente 7429 esperou 0.0 na fila da atividade C
# Cliente 7429 gastou 2.251450393589039 na atividade C
# Cliente 7430 esperou 0.0 na fila da atividade C
# Cliente 7430 gastou 7.388656824921782 na atividade C
# Cliente 7431 esperou 0.0 na fila da atividade C
# Cliente 7431 gastou 9.226014895306434 na atividade C
# Cliente 7432 esperou 1.2260148953064345 na fila da atividade C
# Cliente 7432 gastou 0.49392247069772566 na atividade C
# Cliente 7433 esperou 0.0 na fila da atividade C
# Cliente 7433 gastou 0.7241386261594016 na atividade C
# Cliente 7434 esperou 0.0 na fila da atividade C
# Cliente 7434 gastou 2.4388327105043572 na atividade C
# Cliente 7435 esperou 0.0 na fila da atividade C
# Cliente 7435 gastou 0.7923713399504777 na atividade C
# Cliente 7436 esperou 0.0 na fila da atividade C
# Cliente 7436 gastou 3.9617191468787496 na atividade C
# Cliente 7437 esperou 0.0 na fila da atividade C
# Cliente 7437 gastou 5.0301136025518645 na atividade C
# Cliente 7438 esperou 0.0 na fila da atividade C
# Cliente 7438 gastou 1.9127245101481094 na atividade C
# Cliente 7439 esperou 0.0 na fila da atividade C
# Cliente 7439 gastou 0.45941810125805205 na atividade C
# Cliente 7440 esperou 0.0 na fila da atividade C
# Cliente 7440 gastou 0.9690998890146147 na atividade C
# Cliente 7441 esperou 0.0 na fila da atividade C
# Cliente 7441 gastou 9.392990570086113 na atividade C
# Cliente 7442 esperou 1.3929905700861127 na fila da atividade C
# Cliente 7442 gastou 5.77236460653512 na atividade C
# Cliente 7443 esperou 0.0 na fila da atividade C
# Cliente 7443 gastou 3.5053801163157914 na atividade C
# Cliente 7444 esperou 0.0 na fila da atividade C
# Cliente 7444 gastou 6.001195848846692 na atividade C
# Cliente 7445 esperou 0.0 na fila da atividade C
# Cliente 7445 gastou 5.05426047155197 na atividade C
# Cliente 7446 esperou 0.0 na fila da atividade C
# Cliente 7446 gastou 3.691738280482241 na atividade C
# Cliente 7447 esperou 0.0 na fila da atividade C
# Cliente 7447 gastou 16.355818585863744 na atividade C
# Cliente 7448 esperou 8.355818585863744 na fila da atividade C
# Cliente 7448 gastou 9.906540323099762 na atividade C
# Cliente 7449 esperou 10.262358908963506 na fila da atividade C
# Cliente 7449 gastou 1.6557883203713573 na atividade C
# Cliente 7450 esperou 3.9181472293348634 na fila da atividade C
# Cliente 7450 gastou 4.687382988282479 na atividade C
# Cliente 7451 esperou 0.6055302176173427 na fila da atividade C
# Cliente 7451 gastou 3.123250216798624 na atividade C
# Cliente 7452 esperou 0.0 na fila da atividade C
# Cliente 7452 gastou 15.58728770284506 na atividade C
# Cliente 7453 esperou 7.58728770284506 na fila da atividade C
# Cliente 7453 gastou 0.6298686829177313 na atividade C
# Cliente 7454 esperou 0.21715638576279161 na fila da atividade C
# Cliente 7454 gastou 15.152801371616079 na atividade C
# Cliente 7455 esperou 7.36995775737887 na fila da atividade C
# Cliente 7455 gastou 3.2715411386307096 na atividade C
# Cliente 7456 esperou 2.6414988960095798 na fila da atividade C
# Cliente 7456 gastou 0.6221045166312251 na atividade C
# Cliente 7457 esperou 0.0 na fila da atividade C
# Cliente 7457 gastou 0.7169819992777775 na atividade C
# Cliente 7458 esperou 0.0 na fila da atividade C
# Cliente 7458 gastou 2.7097868712007767 na atividade C
# Cliente 7459 esperou 0.0 na fila da atividade C
# Cliente 7459 gastou 0.6848428294979385 na atividade C
# Cliente 7460 esperou 0.0 na fila da atividade C
# Cliente 7460 gastou 0.24292606920789694 na atividade C
# Cliente 7461 esperou 0.0 na fila da atividade C
# Cliente 7461 gastou 2.15463194440963 na atividade C
# Cliente 7462 esperou 0.0 na fila da atividade C
# Cliente 7462 gastou 6.490988153760554 na atividade C
# Cliente 7463 esperou 0.0 na fila da atividade C
# Cliente 7463 gastou 2.802896508765116 na atividade C
# Cliente 7464 esperou 0.0 na fila da atividade C
# Cliente 7464 gastou 7.3703958698388305 na atividade C
# Cliente 7465 esperou 0.0 na fila da atividade C
# Cliente 7465 gastou 4.703837007145921 na atividade C
# Cliente 7466 esperou 0.0 na fila da atividade C
# Cliente 7466 gastou 1.408953250895138 na atividade C
# Cliente 7467 esperou 0.0 na fila da atividade C
# Cliente 7467 gastou 20.522269638851867 na atividade C
# Cliente 7468 esperou 12.522269638851867 na fila da atividade C
# Cliente 7468 gastou 10.870653809266514 na atividade C
# Cliente 7469 esperou 15.392923448118381 na fila da atividade C
# Cliente 7469 gastou 2.3642651257905527 na atividade C
# Cliente 7470 esperou 9.757188573908934 na fila da atividade C
# Cliente 7470 gastou 6.544161638230435 na atividade C
# Cliente 7471 esperou 8.301350212139369 na fila da atividade C
# Cliente 7471 gastou 0.2778231829361175 na atividade C
# Cliente 7472 esperou 0.579173395075486 na fila da atividade C
# Cliente 7472 gastou 13.489237483110628 na atividade C
# Cliente 7473 esperou 6.068410878186114 na fila da atividade C
# Cliente 7473 gastou 1.785770251728536 na atividade C
# Cliente 7474 esperou 0.0 na fila da atividade C
# Cliente 7474 gastou 1.7808507828231086 na atividade C
# Cliente 7475 esperou 0.0 na fila da atividade C
# Cliente 7475 gastou 0.5115441582311178 na atividade C
# Cliente 7476 esperou 0.0 na fila da atividade C
# Cliente 7476 gastou 3.4667420995538123 na atividade C
# Cliente 7477 esperou 0.0 na fila da atividade C
# Cliente 7477 gastou 7.266236328192463 na atividade C
# Cliente 7478 esperou 0.0 na fila da atividade C
# Cliente 7478 gastou 1.00782692185021 na atividade C
# Cliente 7479 esperou 0.0 na fila da atividade C
# Cliente 7479 gastou 6.682786905737885 na atividade C
# Cliente 7480 esperou 0.0 na fila da atividade C
# Cliente 7480 gastou 2.935760964821384 na atividade C
# Cliente 7481 esperou 0.0 na fila da atividade C
# Cliente 7481 gastou 2.217524668412807 na atividade C
# Cliente 7482 esperou 0.0 na fila da atividade C
# Cliente 7482 gastou 1.7629851829769905 na atividade C
# Cliente 7483 esperou 0.0 na fila da atividade C
# Cliente 7483 gastou 16.527520102084964 na atividade C
# Cliente 7484 esperou 8.527520102084964 na fila da atividade C
# Cliente 7484 gastou 1.002685890554858 na atividade C
# Cliente 7485 esperou 1.5302059926398215 na fila da atividade C
# Cliente 7485 gastou 8.366284619551152 na atividade C
# Cliente 7486 esperou 1.8964906121909735 na fila da atividade C
# Cliente 7486 gastou 8.094440924578521 na atividade C
# Cliente 7487 esperou 1.9909315367694944 na fila da atividade C
# Cliente 7487 gastou 2.2853069623888587 na atividade C
# Cliente 7488 esperou 0.0 na fila da atividade C
# Cliente 7488 gastou 0.9106093170048553 na atividade C
# Cliente 7489 esperou 0.0 na fila da atividade C
# Cliente 7489 gastou 0.0988890604567132 na atividade C
# Cliente 7490 esperou 0.0 na fila da atividade C
# Cliente 7490 gastou 8.008180721742974 na atividade C
# Cliente 7491 esperou 0.008180721742974129 na fila da atividade C
# Cliente 7491 gastou 5.764058979002584 na atividade C
# Cliente 7492 esperou 0.0 na fila da atividade C
# Cliente 7492 gastou 6.034702578130236 na atividade C
# Cliente 7493 esperou 0.0 na fila da atividade C
# Cliente 7493 gastou 5.980145242312574 na atividade C
# Cliente 7494 esperou 0.0 na fila da atividade C
# Cliente 7494 gastou 0.7788583318033488 na atividade C
# Cliente 7495 esperou 0.0 na fila da atividade C
# Cliente 7495 gastou 2.2248120213262155 na atividade C
# Cliente 7496 esperou 0.0 na fila da atividade C
# Cliente 7496 gastou 0.13716684628889197 na atividade C
# Cliente 7497 esperou 0.0 na fila da atividade C
# Cliente 7497 gastou 10.702813557087211 na atividade C
# Cliente 7498 esperou 2.702813557087211 na fila da atividade C
# Cliente 7498 gastou 3.3578812063497026 na atividade C

# %%
import numpy as np

print(f"Em média, um cliente o serviço C dura {np.mean(tempo_gasto_C)} minutos")
print(f"Em média, um cliente espera {np.mean(tempo_esperando_C)} minutos pelo serviço C")
# Out:
# Em média, um cliente o serviço C dura 5.010625652120995 minutos
# Em média, um cliente espera 2.8010460979929586 minutos pelo serviço C

# %% [markdown]
# # Exercício Prático 2

# %% [markdown]
# ### Modelo M/M/1
#
# Vamos modelar um sistema faz parte do curso de Pesquisa Operacional III, o sistema de filas M/M/1.
#
# - Taxa de chegadas $\lambda = 0,5$
# - Taxa de atendimento $\mu = 1$
#
# Guarde o valor do tempo de espera em fila e do tempo no sistema (tempo de ciclo).
#
# Simule por 60000 minutos.
#
# Os resultados batem com o esperado? Faça os cálculos com as fórmulas clássicas de Teoria das Filas?

# %%
def fila_MM1 (env, nome, atendente):
    pass
